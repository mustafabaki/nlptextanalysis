# %% [markdown]
# # Import and Edit Data

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/drive/MyDrive/turkish_wikipedia_dump_20200401.csv')

# %%
data.head()
# Out:
#    id  ...                                               text
# 0  10  ...  \nCengiz Han\n\nCengiz Han ("Cenghis Khan", "Ç...
# 1  16  ...  \nFilm (anlam ayrımı)\n\nFilm şu anlamlara gel...
# 2  22  ...  \nMustafa Suphi\n\nMehmet Mustafa Suphi (4 Ağu...
# 3  24  ...  \nLinux\n\nLinux (telaffuz: "Lin-uks"); bilgis...
# 4  30  ...  \nBolşevizm\n\nBolşevik, "çoğunluktan yana" an...
#
# [5 rows x 4 columns]

# %%
df=data['text']
df
# Out:
# 0         \nCengiz Han\n\nCengiz Han ("Cenghis Khan", "Ç...
# 1         \nFilm (anlam ayrımı)\n\nFilm şu anlamlara gel...
# 2         \nMustafa Suphi\n\nMehmet Mustafa Suphi (4 Ağu...
# 3         \nLinux\n\nLinux (telaffuz: "Lin-uks"); bilgis...
# 4         \nBolşevizm\n\nBolşevik, "çoğunluktan yana" an...
#                                 ...
# 287816    \nSam Houser\n\nSam Houser (d. 1971) İngiliz v...
# 287817    \nHaeckel's Tale\n\n"Haeckel's Tale", "Masters...
# 287818    \nGrafik roman\n\nGrafik roman (veya elektroni...
# 287819    \nSonuççuluk\n\nSonuççuluk ya da sonuçsalcılık...
# 287820    \nSağ kalma suçluluğu\n\nSağ kalma suçluluğu (...
# Name: text, Length: 287821, dtype: object

# %% [markdown]
# # Import Necessary Libraries (some of them is optional)

# %%
import numpy as np
import nltk
import re
import warnings
from collections import Counter
import nltk
nltk.download('stopwords')
WPT = nltk.WordPunctTokenizer()
stop_word_list = nltk.corpus.stopwords.words('turkish')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# !pip install gensim
import gensim
from gensim.utils import simple_preprocess
#from gensim.parsing.preprocessing import STOPWORDS           #Does not support Turkish yet.
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np
np.random.seed(400)
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (3.6.0)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.4.1)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.19.5)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (5.0.0)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.15.0)

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %% [markdown]
# **Checking Stemmer**

# %%
import pandas as pd
from snowballstemmer import TurkishStemmer
stemmer=TurkishStemmer()
original_words = ['Başarılı', 'insanlar', 'adamlar', 'öldüler', 'içindekiler','kapısındaki', 'yiyecekler,', 'çıkaranlar', 
           'lahanalar', 'takımların','sırası', 'futbolcuların', 'yedikleri']
singles = [stemmer.stemWord(plural) for plural in original_words]

pd.DataFrame(data={'original word':original_words, 'stemmed':singles })
# Out:
#     original word      stemmed
# 0        Başarılı      Başarıl
# 1        insanlar           in
# 2         adamlar         adam
# 3         öldüler           öl
# 4     içindekiler     içindeki
# 5     kapısındaki        kapıs
# 6     yiyecekler,  yiyecekler,
# 7      çıkaranlar      çıkaran
# 8       lahanalar       lahana
# 9      takımların          tak
# 10         sırası        sıras
# 11  futbolcuların     futbolcu
# 12      yedikleri        yedik

# %% [markdown]
# **Stemming and Tokenizing Functions**

# %%
def lemmatize_stemming(text):       # Lemmetizing is removed because it is not appropriate for turkish
    return stemmer.stemWord(text)

# Tokenize and lemmatize
def preprocess(text):
    result=[]
    for token in gensim.utils.simple_preprocess(text) :
        if token not in stop_word_list and len(token) > 3:
            result.append(lemmatize_stemming(token))
     
    return result

# %% [markdown]
# **Testing Functions**

# %%
doc_sample = 'Bu disk çok fazla kez hata verdi. Mümkünse bunu başka bir tane ile değiştirmek istiyorum.'

print("Original document: ")
words = []
for word in doc_sample.split(' '):
    words.append(word)
print(words)
print("\n\nTokenized and stemmed document: ")
print(preprocess(doc_sample))

# %% [markdown]
# # Clean the Data

# %%
import pprint
data['text'].fillna('').astype(str)
df=data['text']
df.astype(str)
print(df)
df = df.astype(str) 
df = df.map(lambda x: re.sub('[,\.!?();:$%&#"]', '', x))
df = df.replace('\n','', regex=True)                     # depends on the data
df = df.replace('\'','', regex=True)                     # depends on the data
df = df.replace('-','', regex=True)                      # depends on the data
df = df.replace('’','', regex=True)                      # depends on the data
df[0]
# Out:
# 0         \nCengiz Han\n\nCengiz Han ("Cenghis Khan", "Ç...
# 1         \nFilm (anlam ayrımı)\n\nFilm şu anlamlara gel...
# 2         \nMustafa Suphi\n\nMehmet Mustafa Suphi (4 Ağu...
# 3         \nLinux\n\nLinux (telaffuz: "Lin-uks"); bilgis...
# 4         \nBolşevizm\n\nBolşevik, "çoğunluktan yana" an...
#                                 ...
# 287816    \nSam Houser\n\nSam Houser (d. 1971) İngiliz v...
# 287817    \nHaeckel's Tale\n\n"Haeckel's Tale", "Masters...
# 287818    \nGrafik roman\n\nGrafik roman (veya elektroni...
# 287819    \nSonuççuluk\n\nSonuççuluk ya da sonuçsalcılık...
# 287820    \nSağ kalma suçluluğu\n\nSağ kalma suçluluğu (...
# Name: text, Length: 287821, dtype: object
# 'Cengiz HanCengiz Han Cenghis Khan Çinggis Haan ya da doğum adıyla Temuçin anlamı demirci Moğolca Чингис Хаан ya da Tengiz anlamı deniz  d 1162 – ö 18 Ağustos 1227 Moğol komutan hükümdar ve Moğol İmparatorluğunun kurucusudur Cengiz Han 13 Yüzyılın başında Orta Asyadaki tüm göçebe bozkır kavimlerini birleştirerek bir ulus haline getirdi ve o ulusu Moğol siyasi kimliği çatısı altında topladı Dünya tarihinin en büyük askeri liderlerinden biri olarak kabul edilen Cengiz Han hükümdarlığı döneminde 12061227 arasında Kuzey Çindeki Batı Xia ve Jin Hanedanı Türkistandaki Kara Hıtay Maveraünnehir Harezm Horasan ve İrandaki Harzemşahlar ile Kafkasyada Gürcüler Deşti Kıpçaktaki Rus Knezlikleri ve Kıpçaklar ile İdil Bulgarları üzerine gerçekleştirilen seferler sonucunda Pasifik Okyanusundan Hazar Denizine ve Karadenizin kuzeyine kadar uzanan bir imparatorluk kurduBozkır geleneğinden gelen onlu teşkilatı kullanarak Meritokratik liyâkata bağlı bir ordu meydana getiren Cengiz Hanın büyük bir asker olarak ün kazanmasının temelinde kurduğu posta teşkilatı ve casus ağı ile istihbarat sanatına verdiği büyük değer önemli bir yer tutar Seferleri sonucunda pek çok şehir tahrip olmuş ve milyonlarca insan da katledilmişti ancak Cengiz Han Yasası adı ile metinleştirilen kurallar ile işkenceyi yasaklayıp zanaatkarlar doktorlar belli bilgi becerisi olan eğitimli kişiler ve her dinden din adamlarına hangi milletten olursa olsun aralarında bir ayrım yapılmaksızın saygı gösterilmesi ve vergiden muaf tutulmalarını kanunlaştırmıştır Cengiz Han halkının yazıya sahip olmasını sağlamak için Uygurlardan önemli bahşıları başkenti Karakuruma çağırmış ve Moğolca için Uygur alfabesini uyarlatarak bunu çocuklarına da öğretmesini istemiştir1227 yılında Kuzey Çindeki Tangutlar üzerine çıktığı sefer esnasında rahatsızlanarak hayatını kaybetti Kurmuş olduğu imparatorluk günümüzde Rusya hariç tüm ülkelerden daha geniş topraklar üzerine yayılmış vaziyette olup ölümünden sonra oğulları ve torunları döneminde daha da genişleyerek insanlık tarihinin gördüğü bitişik sınırlara sahip en büyük imparatorluk haline geldiCengiz Hanın şeceresi yarı mitolojik bir şekilde sis perdesi arkasındadır Onun atalarının ve kendisinin doğuş efsanesi Moğol mitolojisinin önemli belgelerindendir Yazılış tarihi itibarı ile Cengiz Hanın yaşadığı döneme en yakın olanı Şamanizm etkilerinin görüldüğü 1240 yılında Moğolca olarak kaleme alınmış olan Moğolların Gizli Tarihi adlı esere göre Cengiz Handan 10 nesil önce yaşayan Alangoya Cengiz Han soyunun efsanevi büyük annesi olarak kabul edilmiştir Moğolların Gizli Tarihinde yer alan efsaneye göre Alangoya dul kaldıktan sonra evlenmediği halde üç oğlu daha olmuştur Cengiz Han ve onun mensup olduğu Börçiginler bu çocuklardan “Bodoncar” adlı en küçük olanının soyundan gelmektedir Alangoya efsanesi yalnızca Cengiz Hanı değil onunla birlikte “Nirun” yani ışığın çocukları adı verilen bir yığın boyu ilgilendirse de Cengiz Han soyunun en büyük efsanesi olarak kabul edilmiştir Nirun boylarından öncelikle Cengiz Hanın boyu Borciginler ardından Tayciutlar Barlaslar Derbenler Salciutlar ve başka birkaç boy daha sayılabilir 1140 yılında Moğol kabilelerinden Börçiginlere mensup Kabul bütün Moğolların ilk lideri olarak “Han” unvanını almıştır Cengiz Hanın babası Yesügey Bahadır onun torunudurKabul Han ve onun halefi Ambakay Han zamanında Moğollar Çindeki Jin İmparatorluğu ile mücadele edecek kadar kuvvetlenseler de Tatarlar Çinlleri hoşnut etmek için Ambakayı Çine teslim ettiler Ambakay hiç alışılmadık bir şekilde “tahta eşek şekli” denen bir duruma sokularak çarmıha gerilip infaz edildi Cengiz Hanın büyük amcası Kutua bu hakarete Çin üzerine ve Tatarlara bir dizi saldırı düzenleyerek cevap verdi ve bu akınlar sonunda “Moğol Herkülü” unvanını kazandı Fakat 1160 yılında detayları bilinmeyen bir dizi olay sonunda Kuzey Çinin hakimi Jin Hanedanı Moğolları hezimete uğrattı Moğollar bir süre karmaşa içinde dağıldılar Sefalet içinde yüzen bu karmaşık haldeki Moğolların içerisi ...

# %% [markdown]
# **Tokenizing and Stemming the Original Data**

# %%
processed_docs = []
# !pip install progressbar2
from progressbar import ProgressBar
bar = ProgressBar()

for doc in bar(abc):
    processed_docs.append(preprocess(doc))
# Out:
# Requirement already satisfied: progressbar2 in /usr/local/lib/python3.7/dist-packages (3.38.0)
# Requirement already satisfied: python-utils>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from progressbar2) (2.5.6)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from progressbar2) (1.15.0)
# 100% (100000 of 100000) |################| Elapsed Time: 1:12:29 Time:  1:12:29

# %% [markdown]
# # Adding to the Dictionary

# %%
dictionary = gensim.corpora.Dictionary(processed_docs)

# %%
count = 0                         #Testing if it is created
for k, v in dictionary.iteritems():
    print(k, v)
    count += 1
    if count > 10:
        break
# Out:
# 0
# 1 a
# 2 abak
# 3 abdde
# 4 abdurrahma
# 5 ablas
# 6 acıl
# 7 acımadık
# 8 acımamış
# 9 acımas
# 10 ad

# %%
'''
Remove very rare and very common words: (Probably not working for Turkish but I tried)
'''
dictionary.filter_extremes(no_below=15, no_above=0.1, keep_n= 100000)

# %%
'''
Create the Bag-of-words model for each document i.e for each document we create a dictionary reporting how many
words and how many times those words appear. Save this to 'bow_corpus'
'''
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]

# %%
'''
Preview BOW for our sample preprocessed document
'''
document_num = 20
bow_doc_x = bow_corpus[document_num]

for i in range(len(bow_doc_x)):
    print("Word {} (\"{}\") appears {} time.".format(bow_doc_x[i][0], 
                                                     dictionary[bow_doc_x[i][0]], 
                                                     bow_doc_x[i][1]))
# Out:
# Word 8 ("ada") appears 2 time.
# Word 9 ("adam") appears 2 time.
# Word 17 ("aile") appears 3 time.
# Word 19 ("ak") appears 10 time.
# Word 23 ("akrabalık") appears 2 time.
# Word 26 ("aks") appears 10 time.
# Word 36 ("akış") appears 1 time.
# Word 43 ("alan") appears 11 time.
# Word 47 ("aldık") appears 1 time.
# Word 52 ("alma") appears 34 time.
# Word 57 ("alt") appears 14 time.
# Word 59 ("alına") appears 4 time.
# Word 60 ("alınabilir") appears 1 time.
# Word 62 ("alır") appears 5 time.
# Word 66 ("amaç") appears 4 time.
# Word 69 ("america") appears 1 time.
# Word 70 ("an") appears 2 time.
# Word 74 ("anla") appears 35 time.
# Word 75 ("anlam") appears 16 time.
# Word 85 ("anlaşma") appears 6 time.
# Word 96 ("ar") appears 6 time.
# Word 98 ("aracılık") appears 9 time.
# Word 103 ("arap") appears 2 time.
# Word 104 ("aras") appears 14 time.
# Word 108 ("araştırma") appears 6 time.
# Word 110 ("araştırır") appears 3 time.
# Word 111 ("ardı") appears 1 time.
# Word 112 ("ardıl") appears 1 time.
# Word 113 ("arka") appears 2 time.
# Word 114 ("arkadaş") appears 2 time.
# Word 127 ("asker") appears 2 time.
# Word 133 ("asıl") appears 3 time.
# Word 162 ("avrupa") appears 2 time.
# Word 165 ("ay") appears 2 time.
# Word 169 ("ayr") appears 1 time.
# Word 170 ("ayrı") appears 8 time.
# Word 175 ("ayrılır") appears 2 time.
# Word 184 ("açı") appears 6 time.
# Word 185 ("açık") appears 1 time.
# Word 194 ("ağır") appears 3 time.
# Word 202 ("ba") appears 1 time.
# Word 206 ("bacak") appears 1 time.
# Word 212 ("bak") appears 5 time.
# Word 223 ("basit") appears 2 time.
# Word 225 ("baskı") appears 2 time.
# Word 227 ("baskıs") appears 1 time.
# Word 231 ("bat") appears 1 time.
# Word 238 ("bazı") appears 2 time.
# Word 240 ("bağla") appears 4 time.
# Word 245 ("bağlanma") appears 2 time.
# Word 247 ("bağlılık") appears 1 time.
# Word 248 ("bağımlılık") appears 1 time.
# Word 249 ("bağımsız") appears 2 time.
# Word 254 ("başarıl") appears 1 time.
# Word 256 ("başka") appears 8 time.
# Word 266 ("başlamış") appears 1 time.
# Word 269 ("başlatıla") appears 1 time.
# Word 270 ("başlaya") appears 1 time.
# Word 282 ("belge") appears 1 time.
# Word 285 ("belirlemek") appears 1 time.
# Word 288 ("belli") appears 6 time.
# Word 294 ("ber") appears 3 time.
# Word 298 ("bey") appears 1 time.
# Word 303 ("bil") appears 22 time.
# Word 310 ("bilimci") appears 5 time.
# Word 311 ("biline") appears 5 time.
# Word 315 ("bilinmeye") appears 2 time.
# Word 317 ("biliyor") appears 1 time.
# Word 318 ("bilmedik") appears 1 time.
# Word 320 ("bin") appears 2 time.
# Word 325 ("bir") appears 4 time.
# Word 326 ("birader") appears 1 time.
# Word 327 ("birbir") appears 9 time.
# Word 329 ("birer") appears 1 time.
# Word 330 ("birim") appears 8 time.
# Word 331 ("biris") appears 2 time.
# Word 332 ("birleş") appears 2 time.
# Word 335 ("birleştire") appears 1 time.
# Word 341 ("biz") appears 2 time.
# Word 343 ("biç") appears 21 time.
# Word 344 ("bo") appears 1 time.
# Word 347 ("boy") appears 1 time.
# Word 352 ("boyut") appears 5 time.
# Word 356 ("bu") appears 7 time.
# Word 360 ("bugu") appears 3 time.
# Word 361 ("bugünkü") appears 1 time.
# Word 372 ("bulunamamış") appears 1 time.
# Word 375 ("bulunduk") appears 3 time.
# Word 376 ("bulunmak") appears 4 time.
# Word 380 ("bun") appears 8 time.
# Word 381 ("bur") appears 1 time.
# Word 382 ("bura") appears 8 time.
# Word 388 ("bö") appears 8 time.
# Word 390 ("bölges") appears 1 time.
# Word 391 ("böyleç") appears 2 time.
# Word 394 ("büt") appears 10 time.
# Word 405 ("canlı") appears 5 time.
# Word 427 ("dahi") appears 1 time.
# Word 429 ("dair") appears 2 time.
# Word 431 ("dal") appears 1 time.
# Word 441 ("davranış") appears 6 time.
# Word 465 ("demek") appears 2 time.
# Word 470 ("dene") appears 2 time.
# Word 471 ("denile") appears 1 time.
# Word 477 ("derece") appears 2 time.
# Word 478 ("dereç") appears 2 time.
# Word 479 ("dergi") appears 1 time.
# Word 485 ("destek") appears 2 time.
# Word 490 ("deva") appears 4 time.
# Word 495 ("devlet") appears 2 time.
# Word 497 ("değer") appears 3 time.
# Word 500 ("değil") appears 14 time.
# Word 501 ("değiş") appears 26 time.
# Word 502 ("değişik") appears 3 time.
# Word 510 ("dikkat") appears 4 time.
# Word 512 ("dil") appears 369 time.
# Word 522 ("diz") appears 2 time.
# Word 525 ("doktor") appears 1 time.
# Word 528 ("dol") appears 1 time.
# Word 529 ("dola") appears 3 time.
# Word 536 ("doğal") appears 21 time.
# Word 538 ("doğru") appears 4 time.
# Word 539 ("doğruluk") appears 2 time.
# Word 540 ("doğu") appears 1 time.
# Word 544 ("doğuş") appears 1 time.
# Word 545 ("dur") appears 44 time.
# Word 550 ("durum") appears 14 time.
# Word 554 ("duya") appears 2 time.
# Word 556 ("duygu") appears 3 time.
# Word 557 ("duyma") appears 5 time.
# Word 561 ("dö") appears 1 time.
# Word 568 ("dönem") appears 2 time.
# Word 577 ("dört") appears 2 time.
# Word 582 ("düzenle") appears 3 time.
# Word 584 ("düzenlene") appears 1 time.
# Word 587 ("düzenli") appears 3 time.
# Word 588 ("düzey") appears 1 time.
# Word 589 ("düş") appears 9 time.
# Word 590 ("düşe") appears 1 time.
# Word 599 ("düşünce") appears 10 time.
# Word 606 ("düşünür") appears 1 time.
# Word 607 ("düşünüyor") appears 1 time.
# Word 610 ("dış") appears 7 time.
# Word 612 ("dışarı") appears 2 time.
# Word 613 ("e") appears 6 time.
# Word 616 ("edebilir") appears 1 time.
# Word 617 ("edebiyat") appears 4 time.
# Word 622 ("eder") appears 10 time.
# Word 623 ("ederek") appears 1 time.
# Word 625 ("edil") appears 1 time.
# Word 626 ("edildik") appears 1 time.
# Word 627 ("edile") appears 7 time.
# Word 630 ("edilir") appears 5 time.
# Word 633 ("edilme") appears 1 time.
# Word 645 ("egemenlik") appears 1 time.
# Word 648 ("el") appears 14 time.
# Word 679 ("eser") appears 2 time.
# Word 681 ("esna") appears 5 time.
# Word 684 ("etki") appears 12 time.
# Word 685 ("etkil") appears 1 time.
# Word 686 ("etkile") appears 1 time.
# Word 688 ("etkilemiş") appears 1 time.
# Word 691 ("etkis") appears 7 time.
# Word 692 ("etme") appears 5 time.
# Word 694 ("etmek") appears 7 time.
# Word 698 ("etmez") appears 1 time.
# Word 700 ("etmiş") appears 1 time.
# Word 701 ("etnik") appears 2 time.
# Word 703 ("ettik") appears 2 time.
# Word 709 ("ev") appears 1 time.
# Word 722 ("evrak") appears 1 time.
# Word 728 ("eğitimli") appears 1 time.
# Word 737 ("fakat") appears 3 time.
# Word 741 ("fark") appears 5 time.
# Word 742 ("farklı") appears 22 time.
# Word 747 ("faydalanarak") appears 1 time.
# Word 748 ("faz") appears 2 time.
# Word 750 ("fazlas") appears 1 time.
# Word 751 ("federasyo") appears 2 time.
# Word 766 ("fiziksel") appears 2 time.
# Word 779 ("gel") appears 2 time.
# Word 780 ("geldik") appears 3 time.
# Word 782 ("gelecek") appears 2 time.
# Word 784 ("gelenek") appears 1 time.
# Word 789 ("gelir") appears 1 time.
# Word 791 ("geliş") appears 7 time.
# Word 792 ("gelişe") appears 2 time.
# Word 793 ("gelişmes") appears 3 time.
# Word 795 ("gelme") appears 1 time.
# Word 798 ("gelmek") appears 4 time.
# Word 801 ("genellik") appears 3 time.
# Word 803 ("genetik") appears 2 time.
# Word 804 ("geniş") appears 3 time.
# Word 809 ("genç") appears 1 time.
# Word 811 ("geographiç") appears 1 time.
# Word 812 ("ger") appears 4 time.
# Word 814 ("gerekir") appears 3 time.
# Word 816 ("gerektik") appears 1 time.
# Word 817 ("gerginlik") appears 1 time.
# Word 818 ("geri") appears 1 time.
# Word 819 ("gerçek") appears 5 time.
# Word 827 ("getiril") appears 4 time.
# Word 831 ("getirilmes") appears 1 time.
# Word 835 ("getirmek") appears 1 time.
# Word 838 ("geç") appears 1 time.
# Word 840 ("geçecek") appears 1 time.
# Word 856 ("geçirmek") appears 1 time.
# Word 860 ("geçmiş") appears 2 time.
# Word 863 ("gider") appears 1 time.
# Word 864 ("giderek") appears 1 time.
# Word 876 ("giriş") appears 2 time.
# Word 878 ("girmek") appears 1 time.
# Word 886 ("gizli") appears 1 time.
# Word 889 ("grup") appears 5 time.
# Word 892 ("göl") appears 1 time.
# Word 899 ("göre") appears 2 time.
# Word 901 ("görev") appears 3 time.
# Word 906 ("görmez") appears 1 time.
# Word 915 ("görünmez") appears 5 time.
# Word 918 ("görür") appears 1 time.
# Word 919 ("görüş") appears 7 time.
# Word 923 ("göstere") appears 3 time.
# Word 924 ("gösterecek") appears 1 time.
# Word 925 ("gösteren") appears 1 time.
# Word 929 ("gösterir") appears 5 time.
# Word 931 ("göstermek") appears 3 time.
# Word 938 ("göz") appears 2 time.
# Word 945 ("gün") appears 9 time.
# Word 947 ("güney") appears 2 time.
# Word 950 ("güvenilir") appears 1 time.
# Word 952 ("güzel") appears 2 time.
# Word 954 ("güç") appears 4 time.
# Word 957 ("güçlü") appears 1 time.
# Word 975 ("hal") appears 2 time.
# Word 978 ("halde") appears 1 time.
# Word 981 ("hale") appears 3 time.
# Word 984 ("halk") appears 21 time.
# Word 985 ("halkı") appears 1 time.
# Word 992 ("hangi") appears 2 time.
# Word 1000 ("hareke") appears 2 time.
# Word 1001 ("hareket") appears 29 time.
# Word 1009 ("hariç") appears 1 time.
# Word 1013 ("hastalık") appears 1 time.
# Word 1014 ("hat") appears 10 time.
# Word 1024 ("hayat") appears 2 time.
# Word 1027 ("hayvan") appears 1 time.
# Word 1031 ("hazine") appears 2 time.
# Word 1038 ("he") appears 2 time.
# Word 1047 ("herhangi") appears 2 time.
# Word 1051 ("hesap") appears 2 time.
# Word 1055 ("hikâye") appears 1 time.
# Word 1063 ("hizmet") appears 4 time.
# Word 1064 ("hiçbir") appears 1 time.
# Word 1084 ("hâlâ") appears 4 time.
# Word 1096 ("i") appears 1 time.
# Word 1106 ("ifa") appears 16 time.
# Word 1107 ("ifade") appears 15 time.
# Word 1111 ("ihtiyaç") appears 4 time.
# Word 1114 ("iki") appears 3 time.
# Word 1119 ("iktidar") appears 2 time.
# Word 1133 ("ilgil") appears 5 time.
# Word 1136 ("ilgilenme") appears 1 time.
# Word 1138 ("ilişki") appears 8 time.
# Word 1139 ("ilişkis") appears 1 time.
# Word 1149 ("in") appears 24 time.
# Word 1153 ("inanç") appears 1 time.
# Word 1158 ("insa") appears 15 time.
# Word 1159 ("insan") appears 3 time.
# Word 1160 ("insanlık") appears 3 time.
# Word 1169 ("is") appears 2 time.
# Word 1171 ("isimli") appears 4 time.
# Word 1174 ("ismi") appears 2 time.
# Word 1188 ("istiyor") appears 1 time.
# Word 1192 ("itibar") appears 1 time.
# Word 1193 ("itibare") appears 3 time.
# Word 1201 ("iz") appears 4 time.
# Word 1207 ("içeri") appears 13 time.
# Word 1208 ("içerik") appears 4 time.
# Word 1210 ("içeris") appears 3 time.
# Word 1213 ("iş") appears 2 time.
# Word 1214 ("işaret") appears 63 time.
# Word 1218 ("işle") appears 2 time.
# Word 1222 ("japo") appears 1 time.
# Word 1224 ("k") appears 4 time.
# Word 1229 ("kabiliyet") appears 1 time.
# Word 1230 ("kabul") appears 20 time.
# Word 1242 ("kalacak") appears 1 time.
# Word 1253 ("kale") appears 1 time.
# Word 1258 ("kalma") appears 2 time.
# Word 1259 ("kalmadık") appears 1 time.
# Word 1273 ("kanun") appears 1 time.
# Word 1285 ("kapı") appears 1 time.
# Word 1291 ("karakteris") appears 1 time.
# Word 1302 ("karmaşık") appears 1 time.
# Word 1309 ("karşı") appears 6 time.
# Word 1317 ("karşılık") appears 3 time.
# Word 1318 ("karşılıklı") appears 3 time.
# Word 1319 ("karşıs") appears 1 time.
# Word 1325 ("katkı") appears 4 time.
# Word 1339 ("kavra") appears 12 time.
# Word 1351 ("kaynak") appears 2 time.
# Word 1354 ("kayıt") appears 4 time.
# Word 1355 ("kaza") appears 1 time.
# Word 1378 ("kel") appears 31 time.
# Word 1380 ("kelimes") appears 2 time.
# Word 1385 ("kendis") appears 3 time.
# Word 1396 ("kesinlik") appears 1 time.
# Word 1408 ("kimse") appears 2 time.
# Word 1410 ("kiş") appears 7 time.
# Word 1411 ("kişi") appears 4 time.
# Word 1413 ("kişisel") appears 6 time.
# Word 1420 ("kol") appears 2 time.
# Word 1421 ("kolay") appears 5 time.
# Word 1429 ("kontrol") appears 2 time.
# Word 1430 ("konu") appears 5 time.
# Word 1433 ("konum") appears 1 time.
# Word 1434 ("konus") appears 10 time.
# Word 1435 ("konuşma") appears 61 time.
# Word 1441 ("korku") appears 1 time.
# Word 1457 ("krallık") appears 1 time.
# Word 1459 ("kulak") appears 1 time.
# Word 1461 ("kulla") appears 3 time.
# Word 1462 ("kullana") appears 2 time.
# Word 1466 ("kullandık") appears 7 time.
# Word 1467 ("kullanma") appears 2 time.
# Word 1469 ("kullanıla") appears 10 time.
# Word 1470 ("kullanıldık") appears 2 time.
# Word 1475 ("kur") appears 2 time.
# Word 1477 ("kural") appears 19 time.
# Word 1506 ("kutsal") appears 1 time.
# Word 1511 ("kuzey") appears 1 time.
# Word 1512 ("kuş") appears 1 time.
# Word 1515 ("kuşatma") appears 1 time.
# Word 1520 ("kök") appears 1 time.
# Word 1521 ("köken") appears 4 time.
# Word 1524 ("köpek") appears 2 time.
# Word 1526 ("köt") appears 1 time.
# Word 1528 ("kül") appears 5 time.
# Word 1529 ("kültür") appears 5 time.
# Word 1530 ("kültürel") appears 4 time.
# Word 1534 ("küçük") appears 9 time.
# Word 1535 ("kı") appears 1 time.
# Word 1546 ("kıs") appears 1 time.
# Word 1547 ("kısmı") appears 5 time.
# Word 1553 ("kıyıs") appears 1 time.
# Word 1566 ("ma") appears 3 time.
# Word 1569 ("madde") appears 1 time.
# Word 1570 ("maddes") appears 1 time.
# Word 1579 ("makale") appears 2 time.
# Word 1582 ("mal") appears 1 time.
# Word 1584 ("malzeme") appears 1 time.
# Word 1591 ("mart") appears 4 time.
# Word 1592 ("maruz") appears 1 time.
# Word 1601 ("mağlup") appears 1 time.
# Word 1622 ("meslek") appears 1 time.
# Word 1631 ("meyda") appears 8 time.
# Word 1640 ("millet") appears 2 time.
# Word 1642 ("milyo") appears 1 time.
# Word 1646 ("miras") appears 1 time.
# Word 1650 ("modern") appears 2 time.
# Word 1682 ("mümk") appears 14 time.
# Word 1700 ("national") appears 3 time.
# Word 1703 ("nede") appears 1 time.
# Word 1704 ("neden") appears 1 time.
# Word 1712 ("nere") appears 1 time.
# Word 1713 ("nesil") appears 3 time.
# Word 1714 ("nesl") appears 1 time.
# Word 1718 ("ngiltere") appears 1 time.
# Word 1722 ("nitelik") appears 2 time.
# Word 1723 ("niyet") appears 1 time.
# Word 1728 ("nokta") appears 2 time.
# Word 1729 ("noktas") appears 2 time.
# Word 1731 ("nsa") appears 2 time.
# Word 1737 ("o") appears 2 time.
# Word 1738 ("ok") appears 2 time.
# Word 1741 ("okyanus") appears 1 time.
# Word 1743 ("olabilecek") appears 1 time.
# Word 1745 ("olacak") appears 3 time.
# Word 1749 ("olan") appears 2 time.
# Word 1750 ("olay") appears 1 time.
# Word 1752 ("oldukça") appears 1 time.
# Word 1753 ("olma") appears 12 time.
# Word 1755 ("olmadık") appears 5 time.
# Word 1756 ("olmak") appears 4 time.
# Word 1759 ("olmas") appears 3 time.
# Word 1760 ("olmaya") appears 15 time.
# Word 1761 ("olmayacak") appears 1 time.
# Word 1768 ("olur") appears 4 time.
# Word 1769 ("oluşa") appears 6 time.
# Word 1771 ("oluştuk") appears 1 time.
# Word 1772 ("oluştur") appears 1 time.
# Word 1773 ("oluştura") appears 2 time.
# Word 1775 ("oluşturduk") appears 3 time.
# Word 1776 ("oluşturma") appears 7 time.
# Word 1778 ("oluşturul") appears 4 time.
# Word 1780 ("oluşum") appears 3 time.
# Word 1781 ("on") appears 4 time.
# Word 1786 ("ora") appears 4 time.
# Word 1791 ("orijinal") appears 1 time.
# Word 1796 ("ortak") appears 6 time.
# Word 1806 ("oynadık") appears 1 time.
# Word 1813 ("p") appears 11 time.
# Word 1817 ("paris") appears 2 time.
# Word 1821 ("parça") appears 2 time.
# Word 1824 ("parças") appears 1 time.
# Word 1825 ("pasifik") appears 1 time.
# Word 1831 ("pla") appears 1 time.
# Word 1832 ("plan") appears 1 time.
# Word 1833 ("planla") appears 1 time.
# Word 1834 ("politik") appears 4 time.
# Word 1847 ("psikolojik") appears 1 time.
# Word 1861 ("rağme") appears 1 time.
# Word 1873 ("rica") appears 1 time.
# Word 1879 ("rusya") appears 1 time.
# Word 1888 ("sadeç") appears 12 time.
# Word 1908 ("sanat") appears 2 time.
# Word 1917 ("savaş") appears 1 time.
# Word 1926 ("saye") appears 7 time.
# Word 1929 ("sayı") appears 4 time.
# Word 1931 ("sayılabilir") appears 1 time.
# Word 1932 ("sayılır") appears 1 time.
# Word 1937 ("sağlama") appears 2 time.
# Word 1939 ("sağlamış") appears 1 time.
# Word 1941 ("se") appears 5 time.
# Word 1942 ("sebep") appears 4 time.
# Word 1946 ("sek") appears 1 time.
# Word 1969 ("ses") appears 12 time.
# Word 1974 ("seviye") appears 1 time.
# Word 1993 ("sinir") appears 1 time.
# Word 1996 ("siste") appears 16 time.
# Word 1997 ("sistem") appears 10 time.
# Word 2005 ("sokak") appears 1 time.
# Word 2009 ("sonbahar") appears 1 time.
# Word 2013 ("sonuç") appears 13 time.
# Word 2023 ("stanbul") appears 5 time.
# Word 2044 ("söylemek") appears 1 time.
# Word 2051 ("söz") appears 4 time.
# Word 2056 ("sür") appears 4 time.
# Word 2061 ("süre") appears 1 time.
# Word 2064 ("sürekli") appears 4 time.
# Word 2066 ("süreç") appears 12 time.
# Word 2076 ("süslü") appears 1 time.
# Word 2079 ("sık") appears 2 time.
# Word 2081 ("sınır") appears 2 time.
# Word 2083 ("sır") appears 14 time.
# Word 2089 ("t") appears 4 time.
# Word 2090 ("ta") appears 1 time.
# Word 2093 ("tabii") appears 2 time.
# Word 2094 ("taciz") appears 1 time.
# Word 2097 ("tahm") appears 1 time.
# Word 2103 ("takdir") appears 1 time.
# Word 2104 ("takip") appears 2 time.
# Word 2112 ("talep") appears 3 time.
# Word 2114 ("tamam") appears 2 time.
# Word 2115 ("tamame") appears 4 time.
# Word 2126 ("tanına") appears 1 time.
# Word 2136 ("tarihî") appears 4 time.
# Word 2138 ("tartışma") appears 1 time.
# Word 2139 ("tarz") appears 1 time.
# Word 2143 ("tasvir") appears 1 time.
# Word 2154 ("taş") appears 1 time.
# Word 2158 ("taşımak") appears 1 time.
# Word 2165 ("taşıya") appears 4 time.
# Word 2166 ("taşıyıcıs") appears 1 time.
# Word 2171 ("tehdit") appears 1 time.
# Word 2173 ("tehlike") appears 3 time.
# Word 2176 ("teknik") appears 6 time.
# Word 2178 ("tekrar") appears 1 time.
# Word 2179 ("telaffuz") appears 3 time.
# Word 2181 ("temel") appears 12 time.
# Word 2183 ("temsil") appears 5 time.
# Word 2192 ("terç") appears 4 time.
# Word 2196 ("tespit") appears 3 time.
# Word 2204 ("teşvik") appears 1 time.
# Word 2213 ("topl") appears 6 time.
# Word 2214 ("topla") appears 1 time.
# Word 2224 ("topluluk") appears 1 time.
# Word 2232 ("tut") appears 1 time.
# Word 2252 ("türkiye") appears 1 time.
# Word 2256 ("türkçe") appears 1 time.
# Word 2265 ("ulaşmak") appears 2 time.
# Word 2270 ("ulusal") appears 4 time.
# Word 2271 ("uluslararas") appears 11 time.
# Word 2276 ("unsur") appears 6 time.
# Word 2284 ("uyar") appears 1 time.
# Word 2289 ("uygu") appears 4 time.
# Word 2290 ("uygula") appears 2 time.
# Word 2296 ("uz") appears 4 time.
# Word 2298 ("uzak") appears 2 time.
# Word 2313 ("uğraş") appears 1 time.
# Word 2314 ("uğraşa") appears 2 time.
# Word 2316 ("va") appears 4 time.
# Word 2326 ("varlık") appears 5 time.
# Word 2337 ("verdik") appears 1 time.
# Word 2338 ("vere") appears 2 time.
# Word 2343 ("verile") appears 3 time.
# Word 2344 ("verilme") appears 1 time.
# Word 2347 ("verir") appears 1 time.
# Word 2349 ("verme") appears 1 time.
# Word 2351 ("vermek") appears 1 time.
# Word 2366 ("y") appears 1 time.
# Word 2368 ("yak") appears 4 time.
# Word 2375 ("yaklaş") appears 2 time.
# Word 2377 ("yaklaşık") appears 3 time.
# Word 2387 ("yan") appears 1 time.
# Word 2394 ("yapma") appears 1 time.
# Word 2396 ("yapmak") appears 1 time.
# Word 2402 ("yapıl") appears 1 time.
# Word 2407 ("yapılmas") appears 1 time.
# Word 2410 ("yar") appears 4 time.
# Word 2416 ("yararla") appears 1 time.
# Word 2421 ("yardımcı") appears 3 time.
# Word 2423 ("yarı") appears 2 time.
# Word 2429 ("yasal") appears 1 time.
# Word 2442 ("yaz") appears 30 time.
# Word 2443 ("yazar") appears 3 time.
# Word 2444 ("yazma") appears 3 time.
# Word 2447 ("yazı") appears 8 time.
# Word 2448 ("yazıl") appears 10 time.
# Word 2450 ("yazılış") appears 1 time.
# Word 2451 ("yazıs") appears 9 time.
# Word 2452 ("yazışma") appears 3 time.
# Word 2457 ("yaş") appears 7 time.
# Word 2458 ("yaşa") appears 2 time.
# Word 2459 ("yaşadık") appears 1 time.
# Word 2460 ("yaşam") appears 1 time.
# Word 2467 ("yaşar") appears 3 time.
# Word 2468 ("yaşaya") appears 5 time.
# Word 2477 ("yeni") appears 11 time.
# Word 2481 ("yenilik") appears 1 time.
# Word 2482 ("yerel") appears 2 time.
# Word 2484 ("yerleşik") appears 1 time.
# Word 2485 ("yerli") appears 1 time.
# Word 2489 ("yeter") appears 1 time.
# Word 2495 ("yirmi") appears 2 time.
# Word 2498 ("yol") appears 11 time.
# Word 2508 ("yukar") appears 1 time.
# Word 2513 ("yön") appears 4 time.
# Word 2516 ("yönelik") appears 3 time.
# Word 2517 ("yönet") appears 2 time.
# Word 2531 ("yük") appears 10 time.
# Word 2539 ("yüz") appears 10 time.
# Word 2542 ("yüzyıl") appears 9 time.
# Word 2547 ("yıldız") appears 1 time.
# Word 2548 ("yıllık") appears 1 time.
# Word 2551 ("z") appears 1 time.
# Word 2553 ("zaman") appears 5 time.
# Word 2554 ("zamanki") appears 1 time.
# Word 2573 ("zor") appears 4 time.
# Word 2576 ("zorluk") appears 1 time.
# Word 2580 ("ç") appears 2 time.
# Word 2588 ("çalış") appears 2 time.
# Word 2590 ("çalışma") appears 7 time.
# Word 2592 ("çalışır") appears 3 time.
# Word 2605 ("çağdaş") appears 4 time.
# Word 2618 ("çevre") appears 6 time.
# Word 2619 ("çevres") appears 1 time.
# Word 2620 ("çeşitli") appears 2 time.
# Word 2622 ("çi") appears 1 time.
# Word 2629 ("çocuk") appears 4 time.
# Word 2630 ("çok") appears 1 time.
# Word 2637 ("çık") appears 4 time.
# Word 2638 ("çıka") appears 1 time.
# Word 2639 ("çıkar") appears 6 time.
# Word 2643 ("çıkarma") appears 1 time.
# Word 2646 ("çıkarıla") appears 1 time.
# Word 2648 ("çıkma") appears 1 time.
# Word 2649 ("çıktık") appears 4 time.
# Word 2651 ("çıkış") appears 1 time.
# Word 2657 ("öl") appears 2 time.
# Word 2664 ("öldürme") appears 1 time.
# Word 2676 ("ölçü") appears 3 time.
# Word 2677 ("ölüm") appears 5 time.
# Word 2680 ("ön") appears 4 time.
# Word 2681 ("öncek") appears 2 time.
# Word 2682 ("öncelik") appears 3 time.
# Word 2683 ("öncü") appears 1 time.
# Word 2686 ("öne") appears 3 time.
# Word 2693 ("örnek") appears 20 time.
# Word 2699 ("özel") appears 10 time.
# Word 2702 ("öğre") appears 3 time.
# Word 2704 ("öğrendik") appears 1 time.
# Word 2706 ("öğrenme") appears 2 time.
# Word 2711 ("ülke") appears 10 time.
# Word 2713 ("ünlü") appears 2 time.
# Word 2722 ("üçüncü") appears 1 time.
# Word 2729 ("ş") appears 1 time.
# Word 2743 ("şart") appears 1 time.
# Word 2746 ("şehir") appears 1 time.
# Word 2751 ("şekil") appears 11 time.
# Word 2752 ("şekl") appears 2 time.
# Word 2753 ("şekli") appears 2 time.
# Word 2755 ("şey") appears 4 time.
# Word 2759 ("şiddet") appears 1 time.
# Word 2766 ("şubat") appears 1 time.
# Word 2772 ("film") appears 1 time.
# Word 2773 ("gelebilir") appears 1 time.
# Word 2784 ("birinci") appears 2 time.
# Word 2793 ("ders") appears 1 time.
# Word 2797 ("doğrultu") appears 1 time.
# Word 2806 ("gazete") appears 1 time.
# Word 2808 ("genel") appears 15 time.
# Word 2814 ("görüle") appears 2 time.
# Word 2831 ("katılır") appears 1 time.
# Word 2833 ("kinci") appears 2 time.
# Word 2868 ("tan") appears 3 time.
# Word 2880 ("türki") appears 2 time.
# Word 2888 ("yürütme") appears 1 time.
# Word 2893 ("öğrenim") appears 2 time.
# Word 2894 ("üstlenir") appears 1 time.
# Word 2897 ("adlandırılır") appears 1 time.
# Word 2903 ("alınarak") appears 1 time.
# Word 2908 ("araç") appears 21 time.
# Word 2911 ("ayrıntıl") appears 1 time.
# Word 2912 ("aça") appears 2 time.
# Word 2914 ("aşama") appears 2 time.
# Word 2916 ("bakım") appears 4 time.
# Word 2917 ("başarıs") appears 1 time.
# Word 2920 ("belir") appears 5 time.
# Word 2921 ("belirleyiç") appears 1 time.
# Word 2924 ("benzer") appears 5 time.
# Word 2926 ("bilgisayar") appears 6 time.
# Word 2927 ("bilinir") appears 1 time.
# Word 2928 ("biliş") appears 1 time.
# Word 2931 ("bulunmamak") appears 1 time.
# Word 2936 ("dayal") appears 1 time.
# Word 2945 ("değişiklik") appears 5 time.
# Word 2954 ("düşük") appears 1 time.
# Word 2968 ("gelişim") appears 7 time.
# Word 2969 ("gelişme") appears 5 time.
# Word 2984 ("gösterilebilir") appears 4 time.
# Word 2985 ("hakkı") appears 4 time.
# Word 2992 ("hızlı") appears 1 time.
# Word 3014 ("kelime") appears 30 time.
# Word 3015 ("kit") appears 3 time.
# Word 3018 ("kon") appears 2 time.
# Word 3019 ("konferans") appears 2 time.
# Word 3023 ("kullanıcı") appears 2 time.
# Word 3024 ("kullanılabilir") appears 1 time.
# Word 3026 ("kullanım") appears 7 time.
# Word 3027 ("kullanır") appears 3 time.
# Word 3037 ("kısaç") appears 1 time.
# Word 3038 ("kısıtlı") appears 3 time.
# Word 3057 ("mevcut") appears 8 time.
# Word 3065 ("model") appears 2 time.
# Word 3069 ("nesne") appears 1 time.
# Word 3070 ("ngiliz") appears 5 time.
# Word 3071 ("ngilizce") appears 1 time.
# Word 3075 ("oluşturula") appears 1 time.
# Word 3076 ("oluşur") appears 6 time.
# Word 3084 ("oyun") appears 1 time.
# Word 3094 ("popü") appears 2 time.
# Word 3096 ("proje") appears 1 time.
# Word 3097 ("projes") appears 1 time.
# Word 3101 ("richardı") appears 1 time.
# Word 3110 ("sembol") appears 1 time.
# Word 3116 ("sorun") appears 1 time.
# Word 3119 ("standart") appears 5 time.
# Word 3132 ("sözcük") appears 9 time.
# Word 3138 ("sınırsız") appears 2 time.
# Word 3141 ("tanım") appears 1 time.
# Word 3152 ("tür") appears 3 time.
# Word 3153 ("ulaşılabilir") appears 1 time.
# Word 3156 ("uygulama") appears 1 time.
# Word 3158 ("uzma") appears 4 time.
# Word 3166 ("yapıs") appears 1 time.
# Word 3169 ("yaygı") appears 1 time.
# Word 3180 ("çap") appears 1 time.
# Word 3185 ("özgür") appears 1 time.
# Word 3189 ("üre") appears 1 time.
# Word 3193 ("üretilmes") appears 1 time.
# Word 3195 ("ürün") appears 1 time.
# Word 3199 ("adlandırıla") appears 7 time.
# Word 3200 ("aktif") appears 1 time.
# Word 3201 ("aleksandr") appears 1 time.
# Word 3213 ("azınlık") appears 1 time.
# Word 3215 ("birleşik") appears 1 time.
# Word 3219 ("bölünme") appears 2 time.
# Word 3226 ("değişmez") appears 1 time.
# Word 3230 ("edebilecek") appears 1 time.
# Word 3235 ("esnek") appears 1 time.
# Word 3241 ("felsefe") appears 2 time.
# Word 3242 ("fiil") appears 2 time.
# Word 3244 ("fikir") appears 3 time.
# Word 3245 ("filozof") appears 3 time.
# Word 3252 ("hazira") appears 1 time.
# Word 3259 ("işleyiş") appears 1 time.
# Word 3270 ("kendilik") appears 5 time.
# Word 3276 ("kongres") appears 1 time.
# Word 3279 ("kurulma") appears 1 time.
# Word 3311 ("sosyal") appears 7 time.
# Word 3316 ("sınıf") appears 4 time.
# Word 3323 ("temsilcis") appears 1 time.
# Word 3330 ("tutum") appears 1 time.
# Word 3341 ("yapar") appears 2 time.
# Word 3343 ("yapı") appears 11 time.
# Word 3344 ("yapıla") appears 2 time.
# Word 3349 ("çaba") appears 4 time.
# Word 3352 ("çerçeve") appears 5 time.
# Word 3353 ("çoğunluk") appears 9 time.
# Word 3371 ("adorno") appears 1 time.
# Word 3374 ("ajanlık") appears 1 time.
# Word 3383 ("almanya") appears 3 time.
# Word 3386 ("alınma") appears 2 time.
# Word 3392 ("amerika") appears 4 time.
# Word 3397 ("anayasal") appears 1 time.
# Word 3399 ("anlama") appears 2 time.
# Word 3400 ("anlamak") appears 1 time.
# Word 3401 ("anlamlı") appears 1 time.
# Word 3420 ("asıllı") appears 1 time.
# Word 3429 ("avusturya") appears 3 time.
# Word 3446 ("aşa") appears 1 time.
# Word 3447 ("aşak") appears 1 time.
# Word 3448 ("aşağı") appears 3 time.
# Word 3454 ("bap") appears 2 time.
# Word 3465 ("başlık") appears 2 time.
# Word 3468 ("belirgi") appears 3 time.
# Word 3471 ("belirli") appears 11 time.
# Word 3474 ("belirttik") appears 1 time.
# Word 3485 ("bilim") appears 5 time.
# Word 3486 ("bilimsel") appears 8 time.
# Word 3490 ("bireysel") appears 1 time.
# Word 3495 ("biçim") appears 9 time.
# Word 3500 ("bozulma") appears 1 time.
# Word 3505 ("bulgu") appears 1 time.
# Word 3507 ("bulunur") appears 2 time.
# Word 3514 ("bölüm") appears 2 time.
# Word 3518 ("bütün") appears 1 time.
# Word 3525 ("canlılık") appears 1 time.
# Word 3539 ("cümle") appears 6 time.
# Word 3548 ("dayana") appears 1 time.
# Word 3564 ("denir") appears 1 time.
# Word 3573 ("değişim") appears 13 time.
# Word 3576 ("dikka") appears 1 time.
# Word 3592 ("dönük") appears 1 time.
# Word 3594 ("dönüşme") appears 1 time.
# Word 3599 ("düze") appears 2 time.
# Word 3606 ("düşünüle") appears 1 time.
# Word 3609 ("edilebilecek") appears 1 time.
# Word 3611 ("edip") appears 1 time.
# Word 3614 ("ediç") appears 1 time.
# Word 3619 ("ekono") appears 1 time.
# Word 3626 ("eleştir") appears 1 time.
# Word 3629 ("eleştiri") appears 2 time.
# Word 3633 ("eleştirmek") appears 1 time.
# Word 3642 ("enstitü") appears 1 time.
# Word 3643 ("enstitüs") appears 1 time.
# Word 3647 ("eriç") appears 1 time.
# Word 3652 ("etkinlik") appears 1 time.
# Word 3655 ("eyle") appears 1 time.
# Word 3656 ("eylem") appears 2 time.
# Word 3657 ("eğil") appears 3 time.
# Word 3658 ("eğilim") appears 2 time.
# Word 3663 ("farklılık") appears 8 time.
# Word 3667 ("felsefes") appears 1 time.
# Word 3673 ("form") appears 1 time.
# Word 3679 ("fransa") appears 1 time.
# Word 3680 ("fransız") appears 4 time.
# Word 3683 ("friedrich") appears 1 time.
# Word 3687 ("gaze") appears 2 time.
# Word 3690 ("geliştir") appears 2 time.
# Word 3692 ("geliştirmiş") appears 1 time.
# Word 3696 ("gerekli") appears 1 time.
# Word 3699 ("gereksiz") appears 1 time.
# Word 3702 ("gerçekleşe") appears 1 time.
# Word 3706 ("gerçeklik") appears 3 time.
# Word 3710 ("geçerli") appears 3 time.
# Word 3712 ("geçiç") appears 1 time.
# Word 3713 ("geçiş") appears 1 time.
# Word 3716 ("girer") appears 1 time.
# Word 3727 ("göreç") appears 1 time.
# Word 3729 ("görmek") appears 1 time.
# Word 3730 ("görülmes") appears 1 time.
# Word 3736 ("günlük") appears 6 time.
# Word 3737 ("güve") appears 1 time.
# Word 3747 ("has") appears 1 time.
# Word 3758 ("heinrich") appears 1 time.
# Word 3774 ("ifades") appears 2 time.
# Word 3780 ("iletiş") appears 28 time.
# Word 3784 ("ilişkil") appears 2 time.
# Word 3785 ("ilke") appears 2 time.
# Word 3786 ("ilkel") appears 1 time.
# Word 3807 ("içsel") appears 1 time.
# Word 3809 ("işlev") appears 2 time.
# Word 3828 ("kanıt") appears 2 time.
# Word 3829 ("kap") appears 1 time.
# Word 3830 ("kapasite") appears 1 time.
# Word 3831 ("kapasites") appears 1 time.
# Word 3837 ("kapsamlı") appears 1 time.
# Word 3839 ("karl") appears 1 time.
# Word 3841 ("karşılamak") appears 1 time.
# Word 3846 ("kavram") appears 4 time.
# Word 3849 ("kavramsal") appears 2 time.
# Word 3851 ("kaybı") appears 1 time.
# Word 3852 ("kaynaklana") appears 1 time.
# Word 3862 ("kitap") appears 1 time.
# Word 3876 ("konuşa") appears 9 time.
# Word 3883 ("koşul") appears 5 time.
# Word 3887 ("kullan") appears 3 time.
# Word 3889 ("kura") appears 1 time.
# Word 3903 ("kılma") appears 1 time.
# Word 3906 ("kısm") appears 4 time.
# Word 3918 ("ludwigi") appears 2 time.
# Word 3957 ("nesnel") appears 2 time.
# Word 3960 ("ngil") appears 1 time.
# Word 3969 ("normal") appears 1 time.
# Word 3970 ("not") appears 2 time.
# Word 3971 ("nsan") appears 6 time.
# Word 3977 ("okuma") appears 2 time.
# Word 3978 ("okunuş") appears 1 time.
# Word 3981 ("olgu") appears 8 time.
# Word 3982 ("olmaksız") appears 1 time.
# Word 3983 ("oluş") appears 6 time.
# Word 3989 ("oluşturur") appears 5 time.
# Word 3992 ("organizasyo") appears 1 time.
# Word 4003 ("paul") appears 2 time.
# Word 4004 ("periyodik") appears 1 time.
# Word 4009 ("planlama") appears 1 time.
# Word 4010 ("plansız") appears 1 time.
# Word 4016 ("potansiyel") appears 1 time.
# Word 4017 ("pozisyo") appears 1 time.
# Word 4019 ("pratik") appears 1 time.
# Word 4020 ("prensip") appears 1 time.
# Word 4023 ("progra") appears 3 time.
# Word 4024 ("program") appears 2 time.
# Word 4042 ("safha") appears 1 time.
# Word 4060 ("savunulmas") appears 1 time.
# Word 4061 ("sayılabilecek") appears 1 time.
# Word 4076 ("seyahat") appears 1 time.
# Word 4118 ("sıralama") appears 1 time.
# Word 4123 ("talya") appears 1 time.
# Word 4125 ("tamamlandık") appears 1 time.
# Word 4127 ("tanımlaya") appears 2 time.
# Word 4135 ("tartışmal") appears 2 time.
# Word 4138 ("tartışılır") appears 1 time.
# Word 4139 ("tarzı") appears 2 time.
# Word 4151 ("teor") appears 3 time.
# Word 4152 ("teori") appears 9 time.
# Word 4153 ("teorik") appears 2 time.
# Word 4156 ("ters") appears 1 time.
# Word 4158 ("tez") appears 1 time.
# Word 4167 ("toplumsal") appears 6 time.
# Word 4173 ("u") appears 3 time.
# Word 4181 ("uyarı") appears 1 time.
# Word 4184 ("uğramas") appears 1 time.
# Word 4197 ("wilhelm") appears 3 time.
# Word 4205 ("yapa") appears 2 time.
# Word 4216 ("yayımla") appears 2 time.
# Word 4219 ("yayımlana") appears 2 time.
# Word 4231 ("yazılma") appears 1 time.
# Word 4254 ("yukarı") appears 1 time.
# Word 4260 ("yöntem") appears 1 time.
# Word 4262 ("yürütmek") appears 1 time.
# Word 4271 ("zih") appears 1 time.
# Word 4276 ("zorunluluk") appears 2 time.
# Word 4277 ("çabas") appears 1 time.
# Word 4278 ("çak") appears 2 time.
# Word 4290 ("çeker") appears 1 time.
# Word 4300 ("çeşit") appears 2 time.
# Word 4317 ("önce") appears 7 time.
# Word 4325 ("öz") appears 1 time.
# Word 4326 ("özgü") appears 11 time.
# Word 4327 ("özne") appears 1 time.
# Word 4328 ("öğe") appears 5 time.
# Word 4329 ("öğrenci") appears 1 time.
# Word 4334 ("üniversite") appears 1 time.
# Word 4335 ("üret") appears 1 time.
# Word 4336 ("üretile") appears 1 time.
# Word 4343 ("şair") appears 1 time.
# Word 4344 ("şe") appears 1 time.
# Word 4347 ("şiir") appears 1 time.
# Word 4353 ("atıl") appears 3 time.
# Word 4375 ("gerçekleşme") appears 1 time.
# Word 4384 ("gösterme") appears 1 time.
# Word 4397 ("karakter") appears 1 time.
# Word 4400 ("kuşak") appears 4 time.
# Word 4413 ("radyo") appears 1 time.
# Word 4418 ("sağ") appears 1 time.
# Word 4439 ("yönelme") appears 1 time.
# Word 4448 ("üniversites") appears 2 time.
# Word 4449 ("üretim") appears 2 time.
# Word 4450 ("üstle") appears 1 time.
# Word 4457 ("bilgis") appears 7 time.
# Word 4471 ("htiyaç") appears 1 time.
# Word 4477 ("katma") appears 1 time.
# Word 4480 ("kılavuz") appears 2 time.
# Word 4482 ("olabilir") appears 9 time.
# Word 4488 ("res") appears 1 time.
# Word 4493 ("sunar") appears 2 time.
# Word 4494 ("tasar") appears 1 time.
# Word 4560 ("belirle") appears 2 time.
# Word 4579 ("biraz") appears 1 time.
# Word 4608 ("dalga") appears 1 time.
# Word 4637 ("dâhil") appears 1 time.
# Word 4643 ("düzenlenme") appears 2 time.
# Word 4655 ("elektronik") appears 1 time.
# Word 4659 ("engelli") appears 12 time.
# Word 4664 ("etkilemek") appears 2 time.
# Word 4666 ("etmen") appears 1 time.
# Word 4681 ("fikr") appears 1 time.
# Word 4713 ("güncel") appears 3 time.
# Word 4714 ("güneş") appears 1 time.
# Word 4717 ("güvenlik") appears 1 time.
# Word 4731 ("hizme") appears 1 time.
# Word 4776 ("kaybol") appears 2 time.
# Word 4797 ("kullanıl") appears 1 time.
# Word 4838 ("met") appears 1 time.
# Word 4885 ("oynamak") appears 1 time.
# Word 4890 ("oyuncu") appears 1 time.
# Word 4914 ("resmî") appears 6 time.
# Word 4919 ("rume") appears 1 time.
# Word 4990 ("televizyo") appears 3 time.
# Word 5006 ("tutmak") appears 1 time.
# Word 5018 ("vazgeçil") appears 1 time.
# Word 5028 ("yabancı") appears 10 time.
# Word 5037 ("yayınlamış") appears 1 time.
# Word 5039 ("yazılmak") appears 1 time.
# Word 5043 ("yenil") appears 1 time.
# Word 5048 ("yuna") appears 4 time.
# Word 5050 ("yö") appears 1 time.
# Word 5052 ("yürürlük") appears 2 time.
# Word 5060 ("çarşı") appears 1 time.
# Word 5063 ("çeyrek") appears 1 time.
# Word 5073 ("ünle") appears 1 time.
# Word 5096 ("gerektire") appears 1 time.
# Word 5125 ("metin") appears 3 time.
# Word 5126 ("obje") appears 1 time.
# Word 5127 ("olanak") appears 3 time.
# Word 5146 ("alınmas") appears 2 time.
# Word 5157 ("biyolojik") appears 1 time.
# Word 5165 ("ekip") appears 1 time.
# Word 5189 ("kraliyet") appears 2 time.
# Word 5191 ("kurs") appears 1 time.
# Word 5214 ("sonras") appears 1 time.
# Word 5215 ("sözlük") appears 3 time.
# Word 5225 ("uzmanlık") appears 4 time.
# Word 5252 ("deyiş") appears 1 time.
# Word 5259 ("edilebilmes") appears 1 time.
# Word 5265 ("gösterilme") appears 2 time.
# Word 5292 ("ngilter") appears 1 time.
# Word 5309 ("sahne") appears 1 time.
# Word 5347 ("başlangıç") appears 3 time.
# Word 5351 ("büyüyerek") appears 1 time.
# Word 5358 ("ne") appears 1 time.
# Word 5380 ("ayıra") appears 3 time.
# Word 5381 ("ayırt") appears 2 time.
# Word 5382 ("aşağıdaki") appears 2 time.
# Word 5391 ("boşluk") appears 1 time.
# Word 5403 ("düzenleye") appears 1 time.
# Word 5415 ("etke") appears 1 time.
# Word 5420 ("gereksinim") appears 2 time.
# Word 5421 ("getirir") appears 2 time.
# Word 5423 ("gidermek") appears 1 time.
# Word 5435 ("imal") appears 1 time.
# Word 5439 ("içerir") appears 1 time.
# Word 5447 ("karş") appears 3 time.
# Word 5450 ("kaydetmek") appears 1 time.
# Word 5455 ("koordinasyo") appears 1 time.
# Word 5458 ("kullanılır") appears 4 time.
# Word 5466 ("matematiksel") appears 2 time.
# Word 5473 ("okunabile") appears 1 time.
# Word 5475 ("okunma") appears 1 time.
# Word 5480 ("programla") appears 2 time.
# Word 5490 ("simge") appears 1 time.
# Word 5491 ("sinyal") appears 4 time.
# Word 5493 ("sviçre") appears 2 time.
# Word 5510 ("world") appears 2 time.
# Word 5511 ("yavaş") appears 4 time.
# Word 5518 ("yürütüle") appears 1 time.
# Word 5521 ("çalışıp") appears 1 time.
# Word 5561 ("başlayarak") appears 1 time.
# Word 5597 ("ernst") appears 1 time.
# Word 5601 ("evre") appears 2 time.
# Word 5605 ("formül") appears 1 time.
# Word 5608 ("geliştiril") appears 2 time.
# Word 5611 ("georgu") appears 1 time.
# Word 5621 ("hâller") appears 1 time.
# Word 5624 ("ilgilenir") appears 1 time.
# Word 5654 ("konuşula") appears 10 time.
# Word 5663 ("latince") appears 2 time.
# Word 5665 ("mekanizma") appears 1 time.
# Word 5683 ("olas") appears 1 time.
# Word 5684 ("olasılık") appears 3 time.
# Word 5716 ("tanımla") appears 3 time.
# Word 5717 ("tanımlama") appears 2 time.
# Word 5719 ("teoris") appears 2 time.
# Word 5733 ("vasıta") appears 1 time.
# Word 5742 ("yayımlamış") appears 1 time.
# Word 5746 ("yunanis") appears 1 time.
# Word 5754 ("önerme") appears 1 time.
# Word 5764 ("alındık") appears 1 time.
# Word 5765 ("anlayış") appears 2 time.
# Word 5768 ("ayrılabilir") appears 1 time.
# Word 5775 ("birtak") appears 1 time.
# Word 5784 ("edebî") appears 1 time.
# Word 5791 ("gözlem") appears 1 time.
# Word 5796 ("hintavrup") appears 3 time.
# Word 5797 ("ilişk") appears 1 time.
# Word 5810 ("lati") appears 3 time.
# Word 5820 ("roma") appears 3 time.
# Word 5821 ("romal") appears 1 time.
# Word 5826 ("sözlü") appears 12 time.
# Word 5828 ("tanımlanmas") appears 1 time.
# Word 5831 ("tecrübe") appears 1 time.
# Word 5835 ("türemiş") appears 1 time.
# Word 5837 ("türkçes") appears 5 time.
# Word 5848 ("yapıt") appears 1 time.
# Word 5849 ("yaza") appears 1 time.
# Word 5853 ("öykü") appears 1 time.
# Word 5857 ("arthur") appears 1 time.
# Word 5876 ("kurum") appears 2 time.
# Word 5892 ("acı") appears 1 time.
# Word 5893 ("afrika") appears 2 time.
# Word 5894 ("ait") appears 1 time.
# Word 5895 ("aktar") appears 3 time.
# Word 5896 ("aktarıl") appears 1 time.
# Word 5897 ("aktarıldık") appears 1 time.
# Word 5898 ("aktarılma") appears 1 time.
# Word 5899 ("aktarılmas") appears 1 time.
# Word 5900 ("aktarılır") appears 1 time.
# Word 5901 ("aktüel") appears 1 time.
# Word 5902 ("alet") appears 1 time.
# Word 5903 ("algılana") appears 1 time.
# Word 5904 ("algılanabilir") appears 1 time.
# Word 5905 ("algılanma") appears 1 time.
# Word 5906 ("algılayarak") appears 1 time.
# Word 5907 ("algısal") appears 2 time.
# Word 5908 ("alman") appears 1 time.
# Word 5909 ("almancas") appears 1 time.
# Word 5910 ("alınmaz") appears 1 time.
# Word 5911 ("alıç") appears 3 time.
# Word 5912 ("alıştırma") appears 2 time.
# Word 5913 ("anadil") appears 4 time.
# Word 5914 ("analoji") appears 1 time.
# Word 5915 ("anayasa") appears 1 time.
# Word 5916 ("anlamlılık") appears 1 time.
# Word 5917 ("anlamsal") appears 3 time.
# Word 5918 ("anlatılmak") appears 1 time.
# Word 5919 ("anlaya") appears 1 time.
# Word 5920 ("anlayabilmek") appears 1 time.
# Word 5921 ("anlayacak") appears 1 time.
# Word 5922 ("anlayamaz") appears 1 time.
# Word 5923 ("anlaşmak") appears 2 time.
# Word 5924 ("anlaşıl") appears 1 time.
# Word 5925 ("anlaşıla") appears 1 time.
# Word 5926 ("anlaşılabilir") appears 4 time.
# Word 5927 ("anlaşılma") appears 1 time.
# Word 5928 ("anlaşılmas") appears 1 time.
# Word 5929 ("anlaşılır") appears 3 time.
# Word 5930 ("antropologu") appears 1 time.
# Word 5931 ("arabuluculuk") appears 1 time.
# Word 5932 ("aramiç") appears 1 time.
# Word 5933 ("araştırarak") appears 2 time.
# Word 5934 ("araştırmacıs") appears 1 time.
# Word 5935 ("arttırılabilir") appears 1 time.
# Word 5936 ("attik") appears 1 time.
# Word 5937 ("atıf") appears 1 time.
# Word 5938 ("avcı") appears 1 time.
# Word 5939 ("aydınlatma") appears 1 time.
# Word 5940 ("ayin") appears 1 time.
# Word 5941 ("ayrılmaz") appears 1 time.
# Word 5942 ("ayrılış") appears 1 time.
# Word 5943 ("az") appears 2 time.
# Word 5944 ("azaltmak") appears 1 time.
# Word 5945 ("açar") appears 1 time.
# Word 5946 ("açıkla") appears 2 time.
# Word 5947 ("açıklamak") appears 2 time.
# Word 5948 ("açıklanabilir") appears 1 time.
# Word 5949 ("açıklaya") appears 1 time.
# Word 5950 ("açıklayıç") appears 1 time.
# Word 5951 ("açıs") appears 2 time.
# Word 5952 ("ağlama") appears 1 time.
# Word 5953 ("ağz") appears 3 time.
# Word 5954 ("aşamas") appears 1 time.
# Word 5955 ("bakıldık") appears 3 time.
# Word 5956 ("bakış") appears 5 time.
# Word 5957 ("bale") appears 3 time.
# Word 5958 ("bales") appears 1 time.
# Word 5959 ("basiç") appears 1 time.
# Word 5960 ("bastırılmas") appears 1 time.
# Word 5961 ("basım") appears 1 time.
# Word 5962 ("baze") appears 2 time.
# Word 5963 ("bağlam") appears 3 time.
# Word 5964 ("bağlantıl") appears 2 time.
# Word 5965 ("bağlantıs") appears 1 time.
# Word 5966 ("bebeklik") appears 1 time.
# Word 5967 ("belirleme") appears 2 time.
# Word 5968 ("belirlemes") appears 1 time.
# Word 5969 ("belirleye") appears 1 time.
# Word 5970 ("belirsizlik") appears 1 time.
# Word 5971 ("belirti") appears 1 time.
# Word 5972 ("belirtilmel") appears 1 time.
# Word 5973 ("belirtilmes") appears 1 time.
# Word 5974 ("benimsemek") appears 1 time.
# Word 5975 ("benimsemes") appears 1 time.
# Word 5976 ("benlik") appears 3 time.
# Word 5977 ("benzerlik") appears 3 time.
# Word 5978 ("benzetilerek") appears 1 time.
# Word 5979 ("bildirilmes") appears 1 time.
# Word 5980 ("bildirim") appears 2 time.
# Word 5981 ("bildirir") appears 1 time.
# Word 5982 ("bilen") appears 1 time.
# Word 5983 ("bilinemez") appears 1 time.
# Word 5984 ("bilinç") appears 5 time.
# Word 5985 ("bilinçli") appears 3 time.
# Word 5986 ("bilip") appears 1 time.
# Word 5987 ("bilir") appears 1 time.
# Word 5988 ("birey") appears 3 time.
# Word 5989 ("bireysellik") appears 1 time.
# Word 5990 ("birikerek") appears 1 time.
# Word 5991 ("birisidir") appears 1 time.
# Word 5992 ("biyoloji") appears 1 time.
# Word 5993 ("biçimsel") appears 3 time.
# Word 5994 ("blair") appears 1 time.
# Word 5995 ("bolivya") appears 1 time.
# Word 5996 ("bosto") appears 1 time.
# Word 5997 ("bozulmas") appears 1 time.
# Word 5998 ("branice") appears 1 time.
# Word 5999 ("braniç") appears 1 time.
# Word 6000 ("breto") appears 3 time.
# Word 6001 ("brother") appears 1 time.
# Word 6002 ("bulundurarak") appears 1 time.
# Word 6003 ("bulundurulur") appears 1 time.
# Word 6004 ("bulunmal") appears 1 time.
# Word 6005 ("bâzı") appears 7 time.
# Word 6006 ("bölgesel") appears 3 time.
# Word 6007 ("bük") appears 1 time.
# Word 6008 ("bütünsel") appears 1 time.
# Word 6009 ("bırakmak") appears 1 time.
# Word 6010 ("bırakılmas") appears 1 time.
# Word 6011 ("bırakır") appears 2 time.
# Word 6012 ("cami") appears 1 time.
# Word 6013 ("canlandırmak") appears 1 time.
# Word 6014 ("canlanma") appears 2 time.
# Word 6015 ("cinsiyet") appears 1 time.
# Word 6016 ("computer") appears 1 time.
# Word 6017 ("cornwall") appears 1 time.
# Word 6018 ("daim") appears 3 time.
# Word 6019 ("daktilo") appears 1 time.
# Word 6020 ("danimarka") appears 2 time.
# Word 6021 ("dans") appears 5 time.
# Word 6022 ("dayanmak") appears 1 time.
# Word 6023 ("dayanır") appears 3 time.
# Word 6024 ("dağcı") appears 1 time.
# Word 6025 ("destekliyor") appears 1 time.
# Word 6026 ("deyim") appears 1 time.
# Word 6027 ("değişir") appears 2 time.
# Word 6028 ("değişkenlik") appears 2 time.
# Word 6029 ("değişmek") appears 1 time.
# Word 6030 ("değişmes") appears 2 time.
# Word 6031 ("değişmezlik") appears 1 time.
# Word 6032 ("değiştirir") appears 1 time.
# Word 6033 ("di") appears 1 time.
# Word 6034 ("dikkatli") appears 1 time.
# Word 6035 ("dilsel") appears 17 time.
# Word 6036 ("dilsiz") appears 5 time.
# Word 6037 ("dinleyici") appears 2 time.
# Word 6038 ("dinleyiç") appears 7 time.
# Word 6039 ("diyalekt") appears 1 time.
# Word 6040 ("diş") appears 2 time.
# Word 6041 ("dokunma") appears 1 time.
# Word 6042 ("doğar") appears 2 time.
# Word 6043 ("doğma") appears 1 time.
# Word 6044 ("doğmak") appears 1 time.
# Word 6045 ("doğurur") appears 1 time.
# Word 6046 ("du") appears 1 time.
# Word 6047 ("dudak") appears 6 time.
# Word 6048 ("durağa") appears 1 time.
# Word 6049 ("duruş") appears 1 time.
# Word 6050 ("duyar") appears 1 time.
# Word 6051 ("duymadık") appears 1 time.
# Word 6052 ("duymaya") appears 4 time.
# Word 6053 ("duyul") appears 1 time.
# Word 6054 ("dönüşür") appears 1 time.
# Word 6055 ("dürtü") appears 1 time.
# Word 6056 ("düsseldorf") appears 1 time.
# Word 6057 ("düzeltil") appears 1 time.
# Word 6058 ("düzeltme") appears 3 time.
# Word 6059 ("düzeltmek") appears 1 time.
# Word 6060 ("düzenlenir") appears 1 time.
# Word 6061 ("düzensizlik") appears 2 time.
# Word 6062 ("düzyaz") appears 1 time.
# Word 6063 ("düşünsel") appears 2 time.
# Word 6064 ("düşünülemez") appears 1 time.
# Word 6065 ("düşürme") appears 1 time.
# Word 6066 ("ebeveyn") appears 1 time.
# Word 6067 ("edebilmek") appears 1 time.
# Word 6068 ("edilebilir") appears 4 time.
# Word 6069 ("edilmemiş") appears 1 time.
# Word 6070 ("edilmez") appears 1 time.
# Word 6071 ("edin") appears 2 time.
# Word 6072 ("eklenerek") appears 1 time.
# Word 6073 ("elbet") appears 1 time.
# Word 6074 ("elips") appears 1 time.
# Word 6075 ("englandı") appears 1 time.
# Word 6076 ("esnaf") appears 1 time.
# Word 6077 ("esperanto") appears 7 time.
# Word 6078 ("etken") appears 3 time.
# Word 6079 ("etkilendik") appears 1 time.
# Word 6080 ("etkileye") appears 1 time.
# Word 6081 ("etmedik") appears 1 time.
# Word 6082 ("etmel") appears 1 time.
# Word 6083 ("etnoloj") appears 1 time.
# Word 6084 ("evet") appears 1 time.
# Word 6085 ("eyalet") appears 3 time.
# Word 6086 ("eşanlamlı") appears 1 time.
# Word 6087 ("eşya") appears 1 time.
# Word 6088 ("eşzamanlı") appears 3 time.
# Word 6089 ("faktör") appears 1 time.
# Word 6090 ("farklılaşma") appears 1 time.
# Word 6091 ("fazlalık") appears 1 time.
# Word 6092 ("federal") appears 1 time.
# Word 6093 ("federation") appears 2 time.
# Word 6094 ("ferdinandı") appears 2 time.
# Word 6095 ("filme") appears 1 time.
# Word 6096 ("finansal") appears 1 time.
# Word 6097 ("fonetik") appears 2 time.
# Word 6098 ("fortra") appears 1 time.
# Word 6099 ("fransızca") appears 1 time.
# Word 6100 ("fıkra") appears 2 time.
# Word 6101 ("fısıl") appears 1 time.
# Word 6102 ("gelişerek") appears 1 time.
# Word 6103 ("geliştire") appears 1 time.
# Word 6104 ("gelmez") appears 1 time.
# Word 6105 ("george") appears 3 time.
# Word 6106 ("gerekmek") appears 1 time.
# Word 6107 ("gereksin") appears 1 time.
# Word 6108 ("geril") appears 2 time.
# Word 6109 ("gerçekleşmek") appears 1 time.
# Word 6110 ("geçebilir") appears 1 time.
# Word 6111 ("gitgi") appears 1 time.
# Word 6112 ("gurup") appears 2 time.
# Word 6113 ("göndere") appears 1 time.
# Word 6114 ("görsel") appears 4 time.
# Word 6115 ("görülebile") appears 2 time.
# Word 6116 ("görülebilir") appears 1 time.
# Word 6117 ("görülmez") appears 1 time.
# Word 6118 ("görülür") appears 2 time.
# Word 6119 ("görünüş") appears 3 time.
# Word 6120 ("gösterebilir") appears 1 time.
# Word 6121 ("gösterge") appears 9 time.
# Word 6122 ("gösterile") appears 3 time.
# Word 6123 ("gösteriyor") appears 2 time.
# Word 6124 ("gövdes") appears 2 time.
# Word 6125 ("gözle") appears 1 time.
# Word 6126 ("gözlemlene") appears 2 time.
# Word 6127 ("güneybat") appears 1 time.
# Word 6128 ("gürül") appears 1 time.
# Word 6129 ("güvence") appears 3 time.
# Word 6130 ("gırtlak") appears 2 time.
# Word 6131 ("hamburgu") appears 2 time.
# Word 6132 ("hapisha") appears 1 time.
# Word 6133 ("hareketlilik") appears 2 time.
# Word 6134 ("hareketsiz") appears 1 time.
# Word 6135 ("havai") appears 1 time.
# Word 6136 ("hayali") appears 1 time.
# Word 6137 ("hayva") appears 9 time.
# Word 6138 ("hazines") appears 2 time.
# Word 6139 ("hece") appears 1 time.
# Word 6140 ("heidegger") appears 1 time.
# Word 6141 ("helenis") appears 1 time.
# Word 6142 ("hesaplanabilir") appears 1 time.
# Word 6143 ("hipotez") appears 2 time.
# Word 6144 ("hissedilebilir") appears 1 time.
# Word 6145 ("hoffmann") appears 1 time.
# Word 6146 ("humboldt") appears 3 time.
# Word 6147 ("hâkim") appears 1 time.
# Word 6148 ("hıristiyan") appears 1 time.
# Word 6149 ("iletim") appears 1 time.
# Word 6150 ("iletişim") appears 1 time.
# Word 6151 ("imges") appears 1 time.
# Word 6152 ("imla") appears 1 time.
# Word 6153 ("imlâ") appears 3 time.
# Word 6154 ("incele") appears 1 time.
# Word 6155 ("inme") appears 1 time.
# Word 6156 ("institu") appears 1 time.
# Word 6157 ("international") appears 1 time.
# Word 6158 ("israel") appears 1 time.
# Word 6159 ("iste") appears 1 time.
# Word 6160 ("itiç") appears 1 time.
# Word 6161 ("iyileştirme") appears 2 time.
# Word 6162 ("izlenebilir") appears 1 time.
# Word 6163 ("içgüdüsel") appears 1 time.
# Word 6164 ("işitme") appears 5 time.
# Word 6165 ("jack") appears 1 time.
# Word 6166 ("jav") appears 1 time.
# Word 6167 ("jest") appears 2 time.
# Word 6168 ("kabartma") appears 1 time.
# Word 6169 ("kabulü") appears 1 time.
# Word 6170 ("kade") appears 2 time.
# Word 6171 ("kalıcılık") appears 1 time.
# Word 6172 ("kalıt") appears 6 time.
# Word 6173 ("kamusal") appears 1 time.
# Word 6174 ("kana") appears 1 time.
# Word 6175 ("kanto") appears 1 time.
# Word 6176 ("karşılaştırmal") appears 1 time.
# Word 6177 ("kattık") appears 1 time.
# Word 6178 ("kaybedilme") appears 1 time.
# Word 6179 ("kaybolma") appears 1 time.
# Word 6180 ("kaybolmas") appears 1 time.
# Word 6181 ("kaymas") appears 2 time.
# Word 6182 ("kazanmak") appears 2 time.
# Word 6183 ("kelt") appears 2 time.
# Word 6184 ("kenar") appears 1 time.
# Word 6185 ("kesiç") appears 2 time.
# Word 6186 ("keyfi") appears 1 time.
# Word 6187 ("kim") appears 1 time.
# Word 6188 ("kiril") appears 1 time.
# Word 6189 ("kleist") appears 1 time.
# Word 6190 ("kodlama") appears 1 time.
# Word 6191 ("koin") appears 4 time.
# Word 6192 ("kolaylaştırmak") appears 1 time.
# Word 6193 ("kombinasyo") appears 1 time.
# Word 6194 ("komisyo") appears 4 time.
# Word 6195 ("konsepti") appears 1 time.
# Word 6196 ("kontluk") appears 1 time.
# Word 6197 ("kontrolü") appears 1 time.
# Word 6198 ("konul") appears 3 time.
# Word 6199 ("konuşan") appears 1 time.
# Word 6200 ("konuşmadık") appears 1 time.
# Word 6201 ("konuşmaç") appears 13 time.
# Word 6202 ("konuştuk") appears 3 time.
# Word 6203 ("konuşulduk") appears 1 time.
# Word 6204 ("konuşuyor") appears 1 time.
# Word 6205 ("koordinel") appears 1 time.
# Word 6206 ("kopenhagı") appears 2 time.
# Word 6207 ("koreograf") appears 1 time.
# Word 6208 ("koreografi") appears 1 time.
# Word 6209 ("korkus") appears 1 time.
# Word 6210 ("korunma") appears 1 time.
# Word 6211 ("koruya") appears 1 time.
# Word 6212 ("koymuş") appears 1 time.
# Word 6213 ("kriter") appears 1 time.
# Word 6214 ("kullanamaz") appears 1 time.
# Word 6215 ("kullanılmaya") appears 2 time.
# Word 6216 ("kullanılıyor") appears 1 time.
# Word 6217 ("kurgusal") appears 1 time.
# Word 6218 ("kursu") appears 2 time.
# Word 6219 ("köke") appears 4 time.
# Word 6220 ("kısme") appears 1 time.
# Word 6221 ("kısıtlama") appears 1 time.
# Word 6222 ("kıyasla") appears 1 time.
# Word 6223 ("kıyaslanabilir") appears 1 time.
# Word 6224 ("language") appears 4 time.
# Word 6225 ("lars") appears 2 time.
# Word 6226 ("lehçe") appears 7 time.
# Word 6227 ("lehçes") appears 1 time.
# Word 6228 ("letiş") appears 1 time.
# Word 6229 ("lisa") appears 1 time.
# Word 6230 ("lisp") appears 1 time.
# Word 6231 ("lorenz") appears 1 time.
# Word 6232 ("luther") appears 3 time.
# Word 6233 ("malze") appears 1 time.
# Word 6234 ("mantık") appears 1 time.
# Word 6235 ("mantıkçı") appears 2 time.
# Word 6236 ("maori") appears 1 time.
# Word 6237 ("masraf") appears 1 time.
# Word 6238 ("matematikçi") appears 1 time.
# Word 6239 ("maym") appears 1 time.
# Word 6240 ("mecaz") appears 1 time.
# Word 6241 ("medeniyet") appears 1 time.
# Word 6242 ("melodis") appears 1 time.
# Word 6243 ("memeli") appears 1 time.
# Word 6244 ("mesela") appears 22 time.
# Word 6245 ("mimik") appears 5 time.
# Word 6246 ("mola") appears 2 time.
# Word 6247 ("morfolojik") appears 1 time.
# Word 6248 ("mu") appears 1 time.
# Word 6249 ("muhtemele") appears 1 time.
# Word 6250 ("müesses") appears 1 time.
# Word 6251 ("nadire") appears 2 time.
# Word 6252 ("nasihat") appears 1 time.
# Word 6253 ("ncil") appears 4 time.
# Word 6254 ("nedensel") appears 1 time.
# Word 6255 ("negatif") appears 2 time.
# Word 6256 ("nes") appears 1 time.
# Word 6257 ("nietzsche") appears 1 time.
# Word 6258 ("nikaragua") appears 1 time.
# Word 6259 ("nok") appears 1 time.
# Word 6260 ("normalde") appears 1 time.
# Word 6261 ("nov") appears 1 time.
# Word 6262 ("nsanlık") appears 2 time.
# Word 6263 ("okuna") appears 1 time.
# Word 6264 ("olgus") appears 1 time.
# Word 6265 ("olmal") appears 1 time.
# Word 6266 ("olmuşturbir") appears 1 time.
# Word 6267 ("olurbir") appears 1 time.
# Word 6268 ("oluşturulmas") appears 1 time.
# Word 6269 ("oluşturup") appears 1 time.
# Word 6270 ("omuz") appears 1 time.
# Word 6271 ("onar") appears 1 time.
# Word 6272 ("ortaçak") appears 2 time.
# Word 6273 ("orto") appears 1 time.
# Word 6274 ("orwell") appears 3 time.
# Word 6275 ("otori") appears 1 time.
# Word 6276 ("pao") appears 1 time.
# Word 6277 ("papağa") appears 1 time.
# Word 6278 ("paralel") appears 1 time.
# Word 6279 ("parlamentos") appears 1 time.
# Word 6280 ("perl") appears 1 time.
# Word 6281 ("personal") appears 1 time.
# Word 6282 ("peru") appears 1 time.
# Word 6283 ("peter") appears 1 time.
# Word 6284 ("politikas") appears 2 time.
# Word 6285 ("polonyal") appears 1 time.
# Word 6286 ("portekiz") appears 1 time.
# Word 6287 ("primat") appears 1 time.
# Word 6288 ("psikologu") appears 1 time.
# Word 6289 ("puşki") appears 1 time.
# Word 6290 ("rahatsız") appears 2 time.
# Word 6291 ("referans") appears 1 time.
# Word 6292 ("repertuar") appears 1 time.
# Word 6293 ("resmetme") appears 1 time.
# Word 6294 ("retorik") appears 2 time.
# Word 6295 ("rolf") appears 2 time.
# Word 6296 ("rome") appears 1 time.
# Word 6297 ("rudi") appears 3 time.
# Word 6298 ("salla") appears 1 time.
# Word 6299 ("sani") appears 1 time.
# Word 6300 ("sanskritçe") appears 1 time.
# Word 6301 ("sayılmak") appears 1 time.
# Word 6302 ("sağlanamaz") appears 1 time.
# Word 6303 ("sağlarbu") appears 1 time.
# Word 6304 ("sağlayabilecek") appears 1 time.
# Word 6305 ("sağır") appears 4 time.
# Word 6306 ("schopenhauer") appears 1 time.
# Word 6307 ("seferberlik") appears 1 time.
# Word 6308 ("semboliz") appears 1 time.
# Word 6309 ("sesli") appears 6 time.
# Word 6310 ("sessiz") appears 1 time.
# Word 6311 ("sevinç") appears 1 time.
# Word 6312 ("seviyes") appears 1 time.
# Word 6313 ("seyr") appears 1 time.
# Word 6314 ("sistematik") appears 1 time.
# Word 6315 ("sistemli") appears 2 time.
# Word 6316 ("siyase") appears 1 time.
# Word 6317 ("skoçya") appears 1 time.
# Word 6318 ("somut") appears 5 time.
# Word 6319 ("sosyolojik") appears 2 time.
# Word 6320 ("soylu") appears 1 time.
# Word 6321 ("srail") appears 2 time.
# Word 6322 ("statüs") appears 1 time.
# Word 6323 ("sutto") appears 7 time.
# Word 6324 ("sömürgecilik") appears 1 time.
# Word 6325 ("söylene") appears 1 time.
# Word 6326 ("söylenecek") appears 1 time.
# Word 6327 ("söylenti") appears 1 time.
# Word 6328 ("söylev") appears 1 time.
# Word 6329 ("sürdürmektedir") appears 1 time.
# Word 6330 ("süreklilik") appears 1 time.
# Word 6331 ("süryaniç") appears 1 time.
# Word 6332 ("sınıflandırma") appears 7 time.
# Word 6333 ("sınıflandırıla") appears 1 time.
# Word 6334 ("sınıflandırılır") appears 2 time.
# Word 6335 ("sınıflandırır") appears 1 time.
# Word 6336 ("tabu") appears 1 time.
# Word 6337 ("taklit") appears 4 time.
# Word 6338 ("talyanca") appears 1 time.
# Word 6339 ("tamamlanmamış") appears 1 time.
# Word 6340 ("tansiyo") appears 1 time.
# Word 6341 ("tanı") appears 1 time.
# Word 6342 ("tanımlanabile") appears 1 time.
# Word 6343 ("tanımlanabilir") appears 1 time.
# Word 6344 ("tanımlanır") appears 2 time.
# Word 6345 ("tanınma") appears 1 time.
# Word 6346 ("tanınmas") appears 1 time.
# Word 6347 ("taraflı") appears 1 time.
# Word 6348 ("tarafsız") appears 1 time.
# Word 6349 ("tasarlamış") appears 1 time.
# Word 6350 ("tasarlanmas") appears 1 time.
# Word 6351 ("tasarı") appears 1 time.
# Word 6352 ("taslak") appears 1 time.
# Word 6353 ("technical") appears 1 time.
# Word 6354 ("tehdidi") appears 1 time.
# Word 6355 ("tekdüz") appears 1 time.
# Word 6356 ("tekdüzelik") appears 2 time.
# Word 6357 ("tekil") appears 1 time.
# Word 6358 ("tema") appears 1 time.
# Word 6359 ("tempo") appears 1 time.
# Word 6360 ("terbiyes") appears 1 time.
# Word 6361 ("tercümes") appears 4 time.
# Word 6362 ("teşhis") appears 1 time.
# Word 6363 ("theater") appears 1 time.
# Word 6364 ("tipik") appears 2 time.
# Word 6365 ("tiyatro") appears 1 time.
# Word 6366 ("tiyatros") appears 1 time.
# Word 6367 ("to") appears 1 time.
# Word 6368 ("toki") appears 1 time.
# Word 6369 ("toplumsallık") appears 2 time.
# Word 6370 ("totaliter") appears 1 time.
# Word 6371 ("transkripsiyo") appears 1 time.
# Word 6372 ("tutarsızlık") appears 1 time.
# Word 6373 ("tutulur") appears 1 time.
# Word 6374 ("türeye") appears 1 time.
# Word 6375 ("tıbbî") appears 1 time.
# Word 6376 ("unutulma") appears 1 time.
# Word 6377 ("unutulmamal") appears 1 time.
# Word 6378 ("uy") appears 1 time.
# Word 6379 ("uyarıs") appears 1 time.
# Word 6380 ("uygulamal") appears 2 time.
# Word 6381 ("uça") appears 1 time.
# Word 6382 ("uğrar") appears 1 time.
# Word 6383 ("valerie") appears 1 time.
# Word 6384 ("varoluş") appears 1 time.
# Word 6385 ("varsa") appears 1 time.
# Word 6386 ("varsay") appears 1 time.
# Word 6387 ("varsayım") appears 1 time.
# Word 6388 ("vekâlet") appears 1 time.
# Word 6389 ("verilebilir") appears 1 time.
# Word 6390 ("verilecek") appears 1 time.
# Word 6391 ("veriç") appears 1 time.
# Word 6392 ("vermeksiz") appears 1 time.
# Word 6393 ("virgül") appears 1 time.
# Word 6394 ("voltaj") appears 1 time.
# Word 6395 ("vura") appears 1 time.
# Word 6396 ("vücudu") appears 1 time.
# Word 6397 ("vücut") appears 1 time.
# Word 6398 ("yanlış") appears 2 time.
# Word 6399 ("yans") appears 3 time.
# Word 6400 ("yansıma") appears 1 time.
# Word 6401 ("yapay") appears 15 time.
# Word 6402 ("yapılabil") appears 1 time.
# Word 6403 ("yapılandırıl") appears 1 time.
# Word 6404 ("yapılmak") appears 1 time.
# Word 6405 ("yapılır") appears 1 time.
# Word 6406 ("yapısal") appears 2 time.
# Word 6407 ("yararlanmas") appears 1 time.
# Word 6408 ("yaratıç") appears 1 time.
# Word 6409 ("yardım") appears 4 time.
# Word 6410 ("yayımlanmas") appears 1 time.
# Word 6411 ("yazılmas") appears 4 time.
# Word 6412 ("yaşayış") appears 1 time.
# Word 6413 ("yeryüz") appears 2 time.
# Word 6414 ("yeterlilik") appears 1 time.
# Word 6415 ("yetişkin") appears 1 time.
# Word 6416 ("yetiştirdik") appears 1 time.
# Word 6417 ("yozlaşma") appears 2 time.
# Word 6418 ("yunus") appears 2 time.
# Word 6419 ("yönelim") appears 1 time.
# Word 6420 ("yöresel") appears 2 time.
# Word 6421 ("yükle") appears 1 time.
# Word 6422 ("yükselmes") appears 1 time.
# Word 6423 ("zamansal") appears 3 time.
# Word 6424 ("zate") appears 1 time.
# Word 6425 ("zayıfla") appears 1 time.
# Word 6426 ("zekâsı") appears 1 time.
# Word 6427 ("zela") appears 2 time.
# Word 6428 ("zelanda") appears 1 time.
# Word 6429 ("zihinsel") appears 4 time.
# Word 6430 ("zorunlu") appears 4 time.
# Word 6431 ("çalışıla") appears 1 time.
# Word 6432 ("çalışılmak") appears 1 time.
# Word 6433 ("çalışılmas") appears 1 time.
# Word 6434 ("çarpar") appears 1 time.
# Word 6435 ("çarpmak") appears 1 time.
# Word 6436 ("çekim") appears 2 time.
# Word 6437 ("çerçev") appears 3 time.
# Word 6438 ("çevirme") appears 1 time.
# Word 6439 ("çevirmen") appears 4 time.
# Word 6440 ("çeşitlilik") appears 5 time.
# Word 6441 ("çiftçi") appears 1 time.
# Word 6442 ("çokluk") appears 1 time.
# Word 6443 ("çözümlenme") appears 1 time.
# Word 6444 ("çıkabilir") appears 2 time.
# Word 6445 ("ödünç") appears 26 time.
# Word 6446 ("öge") appears 1 time.
# Word 6447 ("önem") appears 1 time.
# Word 6448 ("öngör") appears 2 time.
# Word 6449 ("öngörür") appears 1 time.
# Word 6450 ("önle") appears 2 time.
# Word 6451 ("örül") appears 2 time.
# Word 6452 ("özetlene") appears 1 time.
# Word 6453 ("özürlü") appears 1 time.
# Word 6454 ("öğrenilir") appears 2 time.
# Word 6455 ("öğrenilmes") appears 1 time.
# Word 6456 ("öğrenir") appears 1 time.
# Word 6457 ("öğrenmes") appears 1 time.
# Word 6458 ("öğretmen") appears 1 time.
# Word 6459 ("ünlüs") appears 1 time.
# Word 6460 ("üslup") appears 1 time.
# Word 6461 ("ı") appears 1 time.
# Word 6462 ("şaret") appears 29 time.
# Word 6463 ("şarlma") appears 1 time.
# Word 6464 ("şekille") appears 1 time.
# Word 6465 ("şitme") appears 4 time.
# Word 6466 ("şive") appears 3 time.
# Word 6467 ("şunlardırbu") appears 1 time.
# Word 6468 ("şüphel") appears 1 time.
# Word 6469 ("şüphes") appears 1 time.

# %% [markdown]
# **Saving**

# %%
import pickle
pickle.dump(bow_corpus, open('corpus.pkl', 'wb'))
dictionary.save('dictionary.gensim')

# %% [markdown]
# # LDA Model

# %%
lda_model =  gensim.models.LdaMulticore(bow_corpus, 
                                   num_topics = 70, 
                                   id2word = dictionary,                                    
                                   passes = 10,
                                   workers = 2)

# %%
'''
For each topic, we will explore the words occuring in that topic and its relative weight
'''
for idx, topic in lda_model.print_topics(-1):
    print("Topic: {} \nWords: {}".format(idx, topic ))
    print("\n")
lda_model.save('model_70_topic.gensim')               #Saving the model
# Out:
# Topic: 0
# Words: 0.037*"maç" + 0.033*"tak" + 0.022*"ligi" + 0.021*"takım" + 0.020*"sezo" + 0.017*"futbol" + 0.016*"sezon" + 0.013*"forma" + 0.013*"millî" + 0.011*"kupa"
#
#
# Topic: 1
# Words: 0.027*"tür" + 0.020*"kuş" + 0.013*"küçük" + 0.011*"familya" + 0.010*"balık" + 0.009*"erkek" + 0.009*"uz" + 0.008*"diş" + 0.008*"hayva" + 0.008*"kuyruk"
#
#
# Topic: 2
# Words: 0.120*"sa" + 0.053*"sayı" + 0.032*"sayıs" + 0.025*"say" + 0.024*"ser" + 0.022*"örnekle" + 0.022*"bisiklet" + 0.019*"ortalama" + 0.017*"veri" + 0.017*"seri"
#
#
# Topic: 3
# Words: 0.022*"yahudi" + 0.021*"arap" + 0.019*"srail" + 0.017*"mısır" + 0.017*"muhammedi" + 0.014*"slam" + 0.011*"ra" + 0.011*"müslüma" + 0.010*"arapça" + 0.010*"irak"
#
#
# Topic: 4
# Words: 0.021*"ağaç" + 0.019*"bitki" + 0.013*"yaprak" + 0.010*"tür" + 0.010*"meyve" + 0.009*"yemek" + 0.009*"çiçek" + 0.006*"yiyecek" + 0.006*"yapıla" + 0.005*"genellik"
#
#
# Topic: 5
# Words: 0.049*"bar" + 0.041*"doğa" + 0.041*"tekirdak" + 0.038*"zonguldak" + 0.035*"siyasetçii" + 0.031*"sabancı" + 0.026*"holdingi" + 0.025*"ömer" + 0.024*"manis" + 0.019*"erde"
#
#
# Topic: 6
# Words: 0.034*"yemek" + 0.024*"g" + 0.022*"dük" + 0.021*"ev" + 0.017*"bol" + 0.016*"bayra" + 0.014*"gel" + 0.013*"gelenek" + 0.013*"manis" + 0.012*"düğün"
#
#
# Topic: 7
# Words: 0.068*"müzik" + 0.024*"dans" + 0.020*"tür" + 0.017*"ses" + 0.015*"dansı" + 0.013*"klasik" + 0.011*"çalgı" + 0.010*"tarz" + 0.009*"metal" + 0.009*"parça"
#
#
# Topic: 8
# Words: 0.106*"uzaklık" + 0.051*"trabzo" + 0.039*"tokat" + 0.036*"afyonkarahisar" + 0.032*"sivas" + 0.030*"gires" + 0.029*"yozgat" + 0.024*"taşımal" + 0.024*"adıyama" + 0.023*"karade"
#
#
# Topic: 9
# Words: 0.073*"talya" + 0.053*"fransız" + 0.045*"portekiz" + 0.032*"fransa" + 0.032*"kral" + 0.029*"fra" + 0.024*"bucak" + 0.021*"nüfuslu" + 0.021*"belediye" + 0.020*"yüzölçüm"
#
#
# Topic: 10
# Words: 0.031*"böl" + 0.020*"diz" + 0.019*"karakter" + 0.016*"bölüm" + 0.016*"dizi" + 0.014*"buffy" + 0.013*"sezo" + 0.009*"vampir" + 0.008*"arkadaş" + 0.008*"aşık"
#
#
# Topic: 11
# Words: 0.075*"film" + 0.022*"ödül" + 0.018*"filmi" + 0.014*"oyuncu" + 0.011*"sinema" + 0.009*"yönetme" + 0.008*"adlı" + 0.007*"karakter" + 0.006*"aday" + 0.005*"sahne"
#
#
# Topic: 12
# Words: 0.083*"çocuk" + 0.072*"kadı" + 0.048*"kız" + 0.044*"erkek" + 0.033*"aile" + 0.032*"yaş" + 0.028*"anne" + 0.024*"kardeş" + 0.024*"evlilik" + 0.018*"kadın"
#
#
# Topic: 13
# Words: 0.079*"kulüp" + 0.075*"spor" + 0.039*"futbol" + 0.035*"stady" + 0.027*"kurul" + 0.020*"çanakkale" + 0.018*"kişilik" + 0.016*"seyirci" + 0.014*"mücadel" + 0.014*"kurula"
#
#
# Topic: 14
# Words: 0.010*"yük" + 0.010*"şekil" + 0.008*"hareket" + 0.008*"ak" + 0.007*"kullanıla" + 0.006*"genellik" + 0.006*"hav" + 0.005*"doğru" + 0.005*"parça" + 0.005*"hız"
#
#
# Topic: 15
# Words: 0.060*"şarkı" + 0.029*"alp" + 0.021*"müzik" + 0.016*"adlı" + 0.012*"yarışma" + 0.011*"kanal" + 0.011*"klip" + 0.011*"albüm" + 0.010*"yay" + 0.009*"eurovision"
#
#
# Topic: 16
# Words: 0.058*"grup" + 0.039*"alp" + 0.020*"şarkı" + 0.015*"albüm" + 0.010*"rock" + 0.010*"liste" + 0.009*"müzik" + 0.007*"konser" + 0.007*"adlı" + 0.007*"parça"
#
#
# Topic: 17
# Words: 0.051*"kura" + 0.032*"allah" + 0.028*"melek" + 0.023*"hadis" + 0.022*"slam" + 0.019*"peygamber" + 0.014*"ayet" + 0.014*"t" + 0.012*"ima" + 0.011*"arapça"
#
#
# Topic: 18
# Words: 0.023*"şirket" + 0.013*"üret" + 0.011*"ticaret" + 0.010*"ülke" + 0.008*"hizmet" + 0.008*"par" + 0.008*"milyo" + 0.007*"ekonomik" + 0.007*"fiyat" + 0.007*"türkiye"
#
#
# Topic: 19
# Words: 0.332*"oy" + 0.137*"oyun" + 0.096*"oyuncu" + 0.021*"taş" + 0.019*"satranç" + 0.010*"oynana" + 0.010*"köşe" + 0.009*"kale" + 0.009*"tahta" + 0.008*"köydüreski"
#
#
# Topic: 20
# Words: 0.019*"türkme" + 0.018*"gelenek" + 0.017*"anadol" + 0.016*"aşiret" + 0.015*"sams" + 0.014*"boy" + 0.013*"görenek" + 0.013*"yemek" + 0.012*"türkmen" + 0.012*"sivas"
#
#
# Topic: 21
# Words: 0.039*"madde" + 0.015*"kimyasal" + 0.012*"asit" + 0.012*"gaz" + 0.011*"bileşik" + 0.010*"enerji" + 0.010*"el" + 0.009*"miktar" + 0.009*"kristal" + 0.009*"hidroje"
#
#
# Topic: 22
# Words: 0.010*"on" + 0.008*"fakat" + 0.007*"o" + 0.007*"eder" + 0.006*"p" + 0.006*"ada" + 0.005*"olur" + 0.005*"yol" + 0.005*"arkadaş" + 0.005*"karşı"
#
#
# Topic: 23
# Words: 0.018*"bina" + 0.014*"inşa" + 0.012*"cami" + 0.011*"mimar" + 0.010*"yapıl" + 0.010*"duvar" + 0.008*"edil" + 0.007*"saray" + 0.007*"taş" + 0.007*"yapı"
#
#
# Topic: 24
# Words: 0.056*"diyarbakır" + 0.051*"erzur" + 0.048*"kürt" + 0.038*"elazık" + 0.035*"mardı" + 0.033*"aşiret" + 0.024*"kürtçe" + 0.020*"malatya" + 0.018*"kocael" + 0.017*"erzinca"
#
#
# Topic: 25
# Words: 0.025*"savaş" + 0.016*"karşı" + 0.014*"devlet" + 0.011*"sovyet" + 0.008*"ülke" + 0.006*"rusya" + 0.006*"başladı" + 0.006*"hareket" + 0.005*"alma" + 0.005*"komünist"
#
#
# Topic: 26
# Words: 0.022*"devlet" + 0.018*"kan" + 0.016*"karar" + 0.015*"hak" + 0.014*"sayıl" + 0.013*"hukuk" + 0.010*"yasa" + 0.010*"kurul" + 0.009*"kabul" + 0.008*"hakkı"
#
#
# Topic: 27
# Words: 0.065*"sanat" + 0.044*"res" + 0.022*"sanatçı" + 0.019*"sergi" + 0.015*"fotoğraf" + 0.015*"eser" + 0.014*"çalışma" + 0.013*"güzel" + 0.012*"resim" + 0.012*"heykel"
#
#
# Topic: 28
# Words: 0.041*"stanbul" + 0.033*"tiyatro" + 0.017*"ankar" + 0.010*"çocuk" + 0.010*"türki" + 0.009*"devlet" + 0.009*"sinema" + 0.009*"üniversites" + 0.008*"mez" + 0.008*"görev"
#
#
# Topic: 29
# Words: 0.038*"dil" + 0.024*"halk" + 0.020*"rusya" + 0.017*"asya" + 0.014*"çi" + 0.014*"hazar" + 0.013*"or" + 0.012*"cumhuriyet" + 0.012*"yaşaya" + 0.011*"kır"
#
#
# Topic: 30
# Words: 0.120*"de" + 0.050*"gemi" + 0.029*"ge" + 0.025*"donanma" + 0.019*"ada" + 0.019*"boğaz" + 0.018*"aydı" + 0.016*"gem" + 0.015*"sınıf" + 0.015*"körfez"
#
#
# Topic: 31
# Words: 0.013*"olay" + 0.012*"ceza" + 0.010*"iddia" + 0.009*"polis" + 0.009*"örgüt" + 0.008*"karar" + 0.008*"kiş" + 0.008*"edil" + 0.007*"hapis" + 0.006*"suç"
#
#
# Topic: 32
# Words: 0.033*"yıldız" + 0.029*"ışık" + 0.026*"güneş" + 0.009*"gezege" + 0.007*"yaklaşık" + 0.006*"yüzey" + 0.006*"dalga" + 0.005*"ışın" + 0.005*"optik" + 0.005*"yak"
#
#
# Topic: 33
# Words: 0.047*"savaş" + 0.031*"asker" + 0.027*"kuvvet" + 0.019*"ordu" + 0.010*"komuta" + 0.009*"or" + 0.009*"görev" + 0.009*"karşı" + 0.009*"komutanlık" + 0.008*"taarruz"
#
#
# Topic: 34
# Words: 0.025*"amerika" + 0.024*"birleşik" + 0.018*"ngil" + 0.017*"amerik" + 0.013*"londra" + 0.013*"york" + 0.012*"ngiltere" + 0.011*"devlet" + 0.010*"japonya" + 0.009*"amerikal"
#
#
# Topic: 35
# Words: 0.034*"yarışma" + 0.027*"şampiyona" + 0.025*"yarış" + 0.025*"madalya" + 0.021*"puan" + 0.017*"olimpiyat" + 0.016*"kaza" + 0.016*"grand" + 0.014*"final" + 0.014*"şampiyo"
#
#
# Topic: 36
# Words: 0.034*"üniversites" + 0.027*"üniversite" + 0.019*"öğrenci" + 0.014*"çalışma" + 0.014*"öğret" + 0.012*"fakültes" + 0.011*"araştırma" + 0.011*"bölüm" + 0.010*"dernek" + 0.010*"yük"
#
#
# Topic: 37
# Words: 0.041*"yuna" + 0.029*"kilise" + 0.029*"kıbrıs" + 0.028*"yunanista" + 0.026*"bulgar" + 0.022*"sırp" + 0.020*"arnavut" + 0.019*"bulgarista" + 0.019*"makedonya" + 0.018*"bulgaris"
#
#
# Topic: 38
# Words: 0.081*"geçmiş" + 0.080*"taşımal" + 0.079*"geldik" + 0.079*"nere" + 0.057*"gelenek" + 0.055*"görenek" + 0.051*"yemek" + 0.041*"sır" + 0.039*"fakat" + 0.018*"nüfus"
#
#
# Topic: 39
# Words: 0.213*"anlam" + 0.148*"anla" + 0.089*"aşağı" + 0.077*"gelebilir" + 0.044*"buzul" + 0.043*"ayr" + 0.036*"gelmek" + 0.035*"ka" + 0.021*"olabilir" + 0.013*"şun"
#
#
# Topic: 40
# Words: 0.031*"hastalık" + 0.010*"tedav" + 0.010*"ilaç" + 0.009*"hasta" + 0.008*"bozukluk" + 0.007*"kanser" + 0.007*"etki" + 0.006*"sonuç" + 0.005*"risk" + 0.005*"tedavi"
#
#
# Topic: 41
# Words: 0.041*"kitap" + 0.027*"yazar" + 0.023*"eser" + 0.019*"şiir" + 0.017*"dergi" + 0.016*"adlı" + 0.015*"edebiyat" + 0.015*"roma" + 0.013*"yaz" + 0.010*"şair"
#
#
# Topic: 42
# Words: 0.046*"dil" + 0.034*"türkçe" + 0.031*"sözcük" + 0.025*"anlam" + 0.024*"kelime" + 0.014*"kullanıla" + 0.012*"vikipedi" + 0.011*"ter" + 0.010*"kullanılır" + 0.010*"ngiliz"
#
#
# Topic: 43
# Words: 0.036*"stanbul" + 0.023*"osmanlı" + 0.022*"paş" + 0.018*"mustaf" + 0.013*"mehmet" + 0.013*"ahmet" + 0.012*"kemal" + 0.011*"paşa" + 0.011*"efe" + 0.009*"atatürk"
#
#
# Topic: 44
# Words: 0.006*"temel" + 0.006*"değil" + 0.006*"örnek" + 0.006*"farklı" + 0.006*"konu" + 0.006*"bil" + 0.005*"şekil" + 0.005*"çalışma" + 0.005*"p" + 0.005*"in"
#
#
# Topic: 45
# Words: 0.037*"model" + 0.033*"araç" + 0.021*"motor" + 0.018*"silah" + 0.014*"may" + 0.013*"adet" + 0.012*"top" + 0.012*"tank" + 0.009*"otomobil" + 0.007*"kullanıl"
#
#
# Topic: 46
# Words: 0.033*"hücre" + 0.012*"canlı" + 0.010*"protein" + 0.007*"grup" + 0.007*"yapı" + 0.006*"bitki" + 0.006*"molekül" + 0.006*"asit" + 0.005*"meyda" + 0.005*"tür"
#
#
# Topic: 47
# Words: 0.088*"şehir" + 0.031*"nüfus" + 0.029*"şehri" + 0.026*"şehr" + 0.023*"kent" + 0.016*"beledi" + 0.015*"sınır" + 0.013*"kiş" + 0.013*"bulunmak" + 0.011*"demiryol"
#
#
# Topic: 48
# Words: 0.027*"osmanlı" + 0.014*"devlet" + 0.012*"sul" + 0.010*"ordu" + 0.010*"sefer" + 0.010*"kale" + 0.009*"haçlı" + 0.008*"oğlu" + 0.007*"el" + 0.006*"ordus"
#
#
# Topic: 49
# Words: 0.014*"bilgisayar" + 0.013*"siste" + 0.009*"sistem" + 0.008*"yazıl" + 0.007*"ver" + 0.007*"sür" + 0.007*"sayfa" + 0.006*"bellek" + 0.005*"windows" + 0.005*"progra"
#
#
# Topic: 50
# Words: 0.048*"uçak" + 0.038*"almanya" + 0.038*"alma" + 0.018*"hav" + 0.016*"uçuş" + 0.015*"çalışma" + 0.013*"berl" + 0.012*"uzay" + 0.009*"görev" + 0.008*"pilot"
#
#
# Topic: 51
# Words: 0.046*"müzik" + 0.018*"eser" + 0.016*"yaş" + 0.016*"orkestra" + 0.016*"harry" + 0.016*"oper" + 0.014*"piyano" + 0.013*"konser" + 0.011*"besteç" + 0.011*"festival"
#
#
# Topic: 52
# Words: 0.040*"parti" + 0.028*"genel" + 0.028*"görev" + 0.026*"başkanlık" + 0.023*"başka" + 0.021*"seçim" + 0.017*"türki" + 0.014*"partis" + 0.013*"milletvekil" + 0.012*"seçil"
#
#
# Topic: 53
# Words: 0.025*"vilayet" + 0.022*"azerbayca" + 0.021*"erme" + 0.017*"gürcista" + 0.017*"gürcü" + 0.016*"nüfus" + 0.016*"osmanlı" + 0.014*"artv" + 0.013*"ardaha" + 0.013*"ermenista"
#
#
# Topic: 54
# Words: 0.017*"tar" + 0.013*"hayvancılık" + 0.012*"yerleş" + 0.010*"mahalles" + 0.010*"uzaklık" + 0.009*"bulunmak" + 0.008*"yol" + 0.007*"nüfus" + 0.007*"halkı" + 0.007*"taşımal"
#
#
# Topic: 55
# Words: 0.016*"tanrı" + 0.009*"tapınak" + 0.008*"yuna" + 0.006*"kutsal" + 0.006*"antik" + 0.005*"in" + 0.005*"kral" + 0.005*"mısır" + 0.005*"kabul" + 0.005*"çak"
#
#
# Topic: 56
# Words: 0.036*"ro" + 0.017*"mparator" + 0.017*"imparator" + 0.016*"roma" + 0.013*"oğlu" + 0.009*"öl" + 0.009*"kral" + 0.008*"nero" + 0.008*"ardı" + 0.007*"karşı"
#
#
# Topic: 57
# Words: 0.028*"çubuk" + 0.018*"japo" + 0.018*"özel" + 0.014*"manga" + 0.014*"adlı" + 0.014*"form" + 0.013*"digimo" + 0.013*"oyuncak" + 0.011*"akış" + 0.011*"varyans"
#
#
# Topic: 58
# Words: 0.120*"hindista" + 0.068*"bebek" + 0.037*"hint" + 0.033*"cinsel" + 0.025*"pakis" + 0.020*"pakista" + 0.018*"ncil" + 0.017*"afganista" + 0.016*"bira" + 0.015*"partner"
#
#
# Topic: 59
# Words: 0.026*"yüzyıl" + 0.015*"mparatorluk" + 0.012*"dönem" + 0.011*"toprak" + 0.011*"savaş" + 0.010*"devlet" + 0.010*"krallık" + 0.010*"kral" + 0.009*"ro" + 0.008*"kent"
#
#
# Topic: 60
# Words: 0.028*"değer" + 0.024*"formula_" + 0.014*"dağıl" + 0.013*"olasılık" + 0.012*"örnek" + 0.011*"fonksiyo" + 0.011*"ifa" + 0.010*"sayı" + 0.008*"sonuç" + 0.008*"nokta"
#
#
# Topic: 61
# Words: 0.048*"or" + 0.041*"uşak" + 0.032*"çak" + 0.028*"riz" + 0.027*"skender" + 0.024*"yüzük" + 0.022*"kral" + 0.021*"hatay" + 0.016*"elf" + 0.016*"kartal"
#
#
# Topic: 62
# Words: 0.076*"ülke" + 0.033*"avrup" + 0.015*"afrik" + 0.015*"güney" + 0.013*"sveç" + 0.013*"almanya" + 0.012*"polonya" + 0.010*"belçika" + 0.009*"holla" + 0.009*"danimarka"
#
#
# Topic: 63
# Words: 0.029*"köydürköy" + 0.025*"dak" + 0.018*"göl" + 0.015*"kuzey" + 0.013*"baraj" + 0.012*"güney" + 0.011*"ikl" + 0.010*"yükseklik" + 0.009*"metre" + 0.009*"sınır"
#
#
# Topic: 64
# Words: 0.104*"uluslararas" + 0.045*"ulusal" + 0.043*"kuruluş" + 0.040*"millet" + 0.032*"birleş" + 0.031*"örgüt" + 0.024*"barış" + 0.021*"amaç" + 0.021*"topluluk" + 0.018*"üye"
#
#
# Topic: 65
# Words: 0.069*"ada" + 0.044*"spanya" + 0.031*"nüfus" + 0.029*"spanyol" + 0.028*"güney" + 0.019*"kuzey" + 0.017*"kiş" + 0.012*"özerk" + 0.012*"ülke" + 0.011*"sayım"
#
#
# Topic: 66
# Words: 0.086*"beyaz" + 0.062*"renk" + 0.058*"siyah" + 0.048*"bayrak" + 0.045*"kırmız" + 0.036*"mavi" + 0.034*"sar" + 0.030*"yeşil" + 0.021*"renkli" + 0.020*"rengi"
#
#
# Topic: 67
# Words: 0.023*"enerji" + 0.018*"fizik" + 0.018*"kuvvet" + 0.016*"parçacık" + 0.012*"dalga" + 0.009*"manyetik" + 0.009*"hareket" + 0.009*"deney" + 0.008*"elektro" + 0.008*"hız"
#
#
# Topic: 68
# Words: 0.246*"eyalet" + 0.049*"kana" + 0.043*"kanada" + 0.036*"kedi" + 0.031*"eyâlet" + 0.025*"kapla" + 0.023*"yerli" + 0.015*"kuzey" + 0.013*"kızılderil" + 0.011*"galiçya"
#
#
# Topic: 69
# Words: 0.068*"final" + 0.052*"yar" + 0.039*"turnuva" + 0.036*"açık" + 0.032*"sinop" + 0.030*"set" + 0.030*"köprü" + 0.029*"tenis" + 0.028*"tur" + 0.015*"çeyrek"

# %% [markdown]
# # Testing with Unseen Sentence

# %%
unseen_document = "linux"
print(unseen_document)
# Out:
# linux

# %%
# Data preprocessing step for the unseen document
bow_vector = dictionary.doc2bow(preprocess(unseen_document))

for index, score in sorted(lda_model[bow_vector], key=lambda tup: -1*tup[1]):
    print("Score: {}\t Topic: {}".format(score, lda_model.print_topic(index, 5)))
# Out:
# Score: 0.5071428418159485	 Topic: 0.014*"bilgisayar" + 0.013*"siste" + 0.009*"sistem" + 0.008*"yazıl" + 0.007*"ver"

# %% [markdown]
# **Note: Do not forget to clean the sentence entered. This was a test, so I did not add punctuations.**
