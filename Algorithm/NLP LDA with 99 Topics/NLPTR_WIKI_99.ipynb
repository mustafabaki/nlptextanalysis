# %% [markdown]
# # Import Data and Libraries

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/drive/MyDrive/turkish_wikipedia_dump_20200401.csv')

# %%
data.head()
# Out:
#    id  ...                                               text
# 0  10  ...  \nCengiz Han\n\nCengiz Han ("Cenghis Khan", "Ç...
# 1  16  ...  \nFilm (anlam ayrımı)\n\nFilm şu anlamlara gel...
# 2  22  ...  \nMustafa Suphi\n\nMehmet Mustafa Suphi (4 Ağu...
# 3  24  ...  \nLinux\n\nLinux (telaffuz: "Lin-uks"); bilgis...
# 4  30  ...  \nBolşevizm\n\nBolşevik, "çoğunluktan yana" an...
#
# [5 rows x 4 columns]

# %%
df=data['text']
df
# Out:
# 0         \nCengiz Han\n\nCengiz Han ("Cenghis Khan", "Ç...
# 1         \nFilm (anlam ayrımı)\n\nFilm şu anlamlara gel...
# 2         \nMustafa Suphi\n\nMehmet Mustafa Suphi (4 Ağu...
# 3         \nLinux\n\nLinux (telaffuz: "Lin-uks"); bilgis...
# 4         \nBolşevizm\n\nBolşevik, "çoğunluktan yana" an...
#                                 ...
# 287816    \nSam Houser\n\nSam Houser (d. 1971) İngiliz v...
# 287817    \nHaeckel's Tale\n\n"Haeckel's Tale", "Masters...
# 287818    \nGrafik roman\n\nGrafik roman (veya elektroni...
# 287819    \nSonuççuluk\n\nSonuççuluk ya da sonuçsalcılık...
# 287820    \nSağ kalma suçluluğu\n\nSağ kalma suçluluğu (...
# Name: text, Length: 287821, dtype: object

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import nltk
import re
import warnings
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
import nltk
nltk.download('stopwords')
WPT = nltk.WordPunctTokenizer()
stop_word_list = nltk.corpus.stopwords.words('turkish')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# !pip install gensim
import gensim
from gensim.utils import simple_preprocess
#from gensim.parsing.preprocessing import STOPWORDS           #Does not support Turkish yet.
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np
np.random.seed(400)
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (3.6.0)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.4.1)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.15.0)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.19.5)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (5.0.0)

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
import pandas as pd
from snowballstemmer import TurkishStemmer
stemmer=TurkishStemmer()

# %% [markdown]
# # Tokenizing and Stemmin Functions

# %%
def lemmatize_stemming(text):
    return stemmer.stemWord(text)       #lemmitize was removed because it is not working in turkish

# Tokenize and lemmatize
def preprocess(text):
    result=[]
    for token in gensim.utils.simple_preprocess(text) :
        if token not in stop_word_list and len(token) > 3:
            result.append(lemmatize_stemming(token))
     
    return result

# %% [markdown]
# # Data Cleaning

# %%
import pprint
data['text'].fillna('').astype(str)
df=data['text']
df.astype(str)
print(df)
df = df.astype(str) 
df = df.map(lambda x: re.sub('[,\.!?();:$%&#"]', '', x))
df = df.replace('\n','', regex=True)
df = df.replace('\'','', regex=True)
df = df.replace('-','', regex=True)
df = df.replace('’','', regex=True)
df[0]
# Out:
# 0         \nCengiz Han\n\nCengiz Han ("Cenghis Khan", "Ç...
# 1         \nFilm (anlam ayrımı)\n\nFilm şu anlamlara gel...
# 2         \nMustafa Suphi\n\nMehmet Mustafa Suphi (4 Ağu...
# 3         \nLinux\n\nLinux (telaffuz: "Lin-uks"); bilgis...
# 4         \nBolşevizm\n\nBolşevik, "çoğunluktan yana" an...
#                                 ...
# 287816    \nSam Houser\n\nSam Houser (d. 1971) İngiliz v...
# 287817    \nHaeckel's Tale\n\n"Haeckel's Tale", "Masters...
# 287818    \nGrafik roman\n\nGrafik roman (veya elektroni...
# 287819    \nSonuççuluk\n\nSonuççuluk ya da sonuçsalcılık...
# 287820    \nSağ kalma suçluluğu\n\nSağ kalma suçluluğu (...
# Name: text, Length: 287821, dtype: object
# 'Cengiz HanCengiz Han Cenghis Khan Çinggis Haan ya da doğum adıyla Temuçin anlamı demirci Moğolca Чингис Хаан ya da Tengiz anlamı deniz  d 1162 – ö 18 Ağustos 1227 Moğol komutan hükümdar ve Moğol İmparatorluğunun kurucusudur Cengiz Han 13 Yüzyılın başında Orta Asyadaki tüm göçebe bozkır kavimlerini birleştirerek bir ulus haline getirdi ve o ulusu Moğol siyasi kimliği çatısı altında topladı Dünya tarihinin en büyük askeri liderlerinden biri olarak kabul edilen Cengiz Han hükümdarlığı döneminde 12061227 arasında Kuzey Çindeki Batı Xia ve Jin Hanedanı Türkistandaki Kara Hıtay Maveraünnehir Harezm Horasan ve İrandaki Harzemşahlar ile Kafkasyada Gürcüler Deşti Kıpçaktaki Rus Knezlikleri ve Kıpçaklar ile İdil Bulgarları üzerine gerçekleştirilen seferler sonucunda Pasifik Okyanusundan Hazar Denizine ve Karadenizin kuzeyine kadar uzanan bir imparatorluk kurduBozkır geleneğinden gelen onlu teşkilatı kullanarak Meritokratik liyâkata bağlı bir ordu meydana getiren Cengiz Hanın büyük bir asker olarak ün kazanmasının temelinde kurduğu posta teşkilatı ve casus ağı ile istihbarat sanatına verdiği büyük değer önemli bir yer tutar Seferleri sonucunda pek çok şehir tahrip olmuş ve milyonlarca insan da katledilmişti ancak Cengiz Han Yasası adı ile metinleştirilen kurallar ile işkenceyi yasaklayıp zanaatkarlar doktorlar belli bilgi becerisi olan eğitimli kişiler ve her dinden din adamlarına hangi milletten olursa olsun aralarında bir ayrım yapılmaksızın saygı gösterilmesi ve vergiden muaf tutulmalarını kanunlaştırmıştır Cengiz Han halkının yazıya sahip olmasını sağlamak için Uygurlardan önemli bahşıları başkenti Karakuruma çağırmış ve Moğolca için Uygur alfabesini uyarlatarak bunu çocuklarına da öğretmesini istemiştir1227 yılında Kuzey Çindeki Tangutlar üzerine çıktığı sefer esnasında rahatsızlanarak hayatını kaybetti Kurmuş olduğu imparatorluk günümüzde Rusya hariç tüm ülkelerden daha geniş topraklar üzerine yayılmış vaziyette olup ölümünden sonra oğulları ve torunları döneminde daha da genişleyerek insanlık tarihinin gördüğü bitişik sınırlara sahip en büyük imparatorluk haline geldiCengiz Hanın şeceresi yarı mitolojik bir şekilde sis perdesi arkasındadır Onun atalarının ve kendisinin doğuş efsanesi Moğol mitolojisinin önemli belgelerindendir Yazılış tarihi itibarı ile Cengiz Hanın yaşadığı döneme en yakın olanı Şamanizm etkilerinin görüldüğü 1240 yılında Moğolca olarak kaleme alınmış olan Moğolların Gizli Tarihi adlı esere göre Cengiz Handan 10 nesil önce yaşayan Alangoya Cengiz Han soyunun efsanevi büyük annesi olarak kabul edilmiştir Moğolların Gizli Tarihinde yer alan efsaneye göre Alangoya dul kaldıktan sonra evlenmediği halde üç oğlu daha olmuştur Cengiz Han ve onun mensup olduğu Börçiginler bu çocuklardan “Bodoncar” adlı en küçük olanının soyundan gelmektedir Alangoya efsanesi yalnızca Cengiz Hanı değil onunla birlikte “Nirun” yani ışığın çocukları adı verilen bir yığın boyu ilgilendirse de Cengiz Han soyunun en büyük efsanesi olarak kabul edilmiştir Nirun boylarından öncelikle Cengiz Hanın boyu Borciginler ardından Tayciutlar Barlaslar Derbenler Salciutlar ve başka birkaç boy daha sayılabilir 1140 yılında Moğol kabilelerinden Börçiginlere mensup Kabul bütün Moğolların ilk lideri olarak “Han” unvanını almıştır Cengiz Hanın babası Yesügey Bahadır onun torunudurKabul Han ve onun halefi Ambakay Han zamanında Moğollar Çindeki Jin İmparatorluğu ile mücadele edecek kadar kuvvetlenseler de Tatarlar Çinlleri hoşnut etmek için Ambakayı Çine teslim ettiler Ambakay hiç alışılmadık bir şekilde “tahta eşek şekli” denen bir duruma sokularak çarmıha gerilip infaz edildi Cengiz Hanın büyük amcası Kutua bu hakarete Çin üzerine ve Tatarlara bir dizi saldırı düzenleyerek cevap verdi ve bu akınlar sonunda “Moğol Herkülü” unvanını kazandı Fakat 1160 yılında detayları bilinmeyen bir dizi olay sonunda Kuzey Çinin hakimi Jin Hanedanı Moğolları hezimete uğrattı Moğollar bir süre karmaşa içinde dağıldılar Sefalet içinde yüzen bu karmaşık haldeki Moğolların içerisi ...

# %%
import pprint
word_count = Counter(" ".join(df).split()).most_common(100)
word_frequency = pd.DataFrame(word_count, columns = ['Word', 'Frequency'])
print(word_frequency)
# Out:
#       Word  Frequency
# 0       ve    1325647
# 1      bir     772565
# 2   olarak     322024
# 3      ile     307882
# 4       bu     219862
# ..     ...        ...
# 95    Ocak      26742
# 96     iyi      26525
# 97     tek      26487
# 98   Ancak      26441
# 99   Mayıs      26436
#
# [100 rows x 2 columns]

# %% [markdown]
# **Stopword List**

# %%
stp = pd.read_csv('/content/drive/MyDrive/stopwords.csv')
stop_word_list.extend(stp['stopwords'])
stop_word_list
# Out:
# ['acaba',
#  'ama',
#  'aslında',
#  'az',
#  'bazı',
#  'belki',
#  'biri',
#  'birkaç',
#  'birşey',
#  'biz',
#  'bu',
#  'çok',
#  'çünkü',
#  'da',
#  'daha',
#  'de',
#  'defa',
#  'diye',
#  'eğer',
#  'en',
#  'gibi',
#  'hem',
#  'hep',
#  'hepsi',
#  'her',
#  'hiç',
#  'için',
#  'ile',
#  'ise',
#  'kez',
#  'ki',
#  'kim',
#  'mı',
#  'mu',
#  'mü',
#  'nasıl',
#  'ne',
#  'neden',
#  'nerde',
#  'nerede',
#  'nereye',
#  'niçin',
#  'niye',
#  'o',
#  'sanki',
#  'şey',
#  'siz',
#  'şu',
#  'tüm',
#  've',
#  'veya',
#  'ya',
#  'yani',
#  'abartılı',
#  'abartısız',
#  'abdestli',
#  'abdestsiz',
#  'abes',
#  'abidik gubidik',
#  'abuk sabuk',
#  'abur cubur',
#  'aç açına',
#  'aç biilaç',
#  'aç karnına',
#  'aç',
#  'acaba',
#  'accelerando',
#  'acele',
#  'aceleten',
#  'acemice',
#  'acep',
#  'acı acı',
#  'açık açık',
#  'açık',
#  'açıkça',
#  'açıkçası',
#  'açıktan açığa',
#  'açıktan',
#  'acilen',
#  'acımasız',
#  'acımasızca',
#  'âcizane',
#  'adam adama',
#  'adam başına',
#  'adam boyu',
#  'adam kıtlığında',
#  'adam yokluğunda',
#  'adamakıllı',
#  'adamca',
#  'adamcasına',
#  'adedî',
#  'âdeta',
#  'adetçe',
#  'adı üstünde',
#  'adilane',
#  'adım adım',
#  'adımbaşı',
#  'adına',
#  'adıyla sanıyla',
#  'adlı adıyla',
#  'affettuoso',
#  'afra tafra',
#  'ağır ağır',
#  'ağır aksak',
#  'ağır',
#  'ağırca',
#  'agitato',
#  'ağız ağıza',
#  'ağızdan ağıza',
#  'ağızdan',
#  'ağrısız',
#  'ağzı açık',
#  'ahbapça',
#  'aheste aheste',
#  'aheste beste',
#  'aheste',
#  'ahir',
#  'ahiren',
#  'ahlakça',
#  'ahlaken',
#  'ahlaksızca',
#  'ahmakça',
#  'ailece',
#  'ailecek',
#  'akabinde',
#  'akıbet',
#  'akilane',
#  'akıllı uslu',
#  'akıllıca',
#  'akın akın',
#  'aklen',
#  'aklı sıra',
#  'aklınca',
#  'akşam ezanı',
#  'akşam saati',
#  'akşam vakti',
#  'akşama doğru',
#  'akşama sabaha',
#  'akşamdan akşama',
#  'akşamdan',
#  'akşamları',
#  'akşamleyin',
#  'akşamlı sabahlı',
#  'akşamlık sabahlık',
#  'akşamüstü',
#  'akşamüzeri',
#  'aksi aksi',
#  'aksi hâlde',
#  'aksi takdirde',
#  'aksine',
#  'aktarmalı',
#  'aktarmasız',
#  'alakart',
#  'alarga',
#  'alay alay',
#  'alay malay',
#  'alaz alaz',
#  'alçakça',
#  'alelacele',
#  'alelhesap',
#  'alelhusus',
#  'alelıtlak',
#  'alelumum',
#  'alelusul',
#  'alenen',
#  'alessabah',
#  'alev alev',
#  'alık salık',
#  'âlimane',
#  'alkolsüz',
#  'allegretto',
#  'allegro',
#  'alt alta',
#  'altlı üstlü',
#  'alttan alta',
#  'amabile',
#  'amansızca',
#  'amatörce',
#  'ambalajlı',
#  'ambalajsız',
#  'amirane',
#  'amirce',
#  'anaca',
#  'anadan doğma',
#  'anafordan',
#  'anal',
#  'anasıl',
#  'anasız',
#  'anbean',
#  'ancak',
#  'andante',
#  'andantino',
#  'anha minha',
#  'ani',
#  'anide',
#  'aniden',
#  'anif',
#  'animato',
#  'anında',
#  'anlaşılan',
#  'ansız',
#  'ansızın',
#  'antagonist',
#  'antrparantez',
#  'apansız',
#  'apansızın',
#  'apar topar',
#  'apazlama',
#  'appassionato',
#  'aptal aptal',
#  'aptalca',
#  'aptalcasına',
#  'apul apul',
#  'ara sıra',
#  'ara yerde',
#  'araba araba',
#  'arabasız',
#  'aracılığıyla',
#  'araçsız',
#  'arada bir',
#  'arada sırada',
#  'aralıklı',
#  'aralıksız',
#  'aralıkta',
#  'arasız',
#  'ardı ardına',
#  'ardı sıra',
#  'ardın ardın',
#  'ardınca',
#  'argolu',
#  'argosuz',
#  'arifane',
#  'ariyeten',
#  'ariz amik',
#  'arka arka',
#  'arka arkaya',
#  'arka üstü',
#  'arkadan arkaya',
#  'arkadaşça',
#  'arkası sıra',
#  'arsız arsız',
#  'arsızca',
#  'art arda',
#  'art elden',
#  'artık',
#  'artistçe',
#  'aşağı yukarı',
#  'aşağı',
#  'asaleten',
#  'âşıkane',
#  'aşikâre',
#  'aşırı taşırı',
#  'aşırı',
#  'asırlarca',
#  'askerce',
#  'asla',
#  'aslanca',
#  'aslen',
#  'aslında',
#  'ateşli ateşli',
#  'atfen',
#  'atlaya zıplaya',
#  'aval aval',
#  'avanakça',
#  'avantadan',
#  'avuç avuç',
#  'ayakta',
#  'ayaküstü',
#  'ayaküzeri',
#  'aybeay',
#  'ayda yılda bir',
#  'aydan aya',
#  'ayık',
#  'aylık',
#  'aynen',
#  'aynı zamanda',
#  'aynıyla',
#  'ayrı ayrı',
#  'ayrı',
#  'ayrıca',
#  'ayrıcasız',
#  'ayrıksız',
#  'ayrıyeten',
#  'az az',
#  'az çok',
#  'az daha',
#  'az',
#  'azade',
#  'azar azar',
#  'azca',
#  'azıcık',
#  'azimkârane',
#  'babacanca',
#  'badehu',
#  'badema',
#  'bağrış çağrış',
#  'bağrışa çağrışa',
#  'bahusus',
#  'bakarak',
#  'bakımdan',
#  'bakımından',
#  'balıklama',
#  'bana',
#  'bangır bangır',
#  'banko',
#  'bar bar',
#  'barbarca',
#  'bari',
#  'baş aşağı',
#  'bas bas',
#  'baş başa',
#  'başa baş',
#  'basamak basamak',
#  'başarılı',
#  'başarısız',
#  'basbayağı',
#  'başı dertte',
#  'başıboş',
#  'başıkabak',
#  'basitçe',
#  'başkaca',
#  'başlı başına',
#  'başta',
#  'baştan aşağı',
#  'baştan başa',
#  'baştan savma',
#  'baştan sona',
#  'baştan',
#  'bata çıka',
#  'batsat',
#  'bayağı',
#  'bayıla bayıla',
#  'bayır aşağı',
#  'bayır yukarı',
#  'bayramda seyranda',
#  'bayramdan bayrama',
#  'bayramüstü',
#  'bayramüzeri',
#  'bazen',
#  'bazı bazı',
#  'bazı',
#  'bedaheten',
#  'bedava',
#  'bedavadan',
#  'bedavasına',
#  'bedavaya',
#  'bedence',
#  'bedenen',
#  'begayet',
#  'behemehâl',
#  'bel bel',
#  'beleşten',
#  'belki',
#  'belli belirsiz',
#  'bembeyaz',
#  'bence',
#  'bencilce',
#  'bencileyin',
#  'beraber',
#  'beraberce',
#  'beraberinde',
#  'bereket',
#  'berenarı',
#  'bermutat',
#  'bertafsil',
#  'beş vakit',
#  'besbelli',
#  'besmelesiz',
#  'beyhude yere',
#  'beyhude',
#  'beyninde',
#  'biçimli',
#  'biçimsiz',
#  'bıcır bıcır',
#  'bihakkın',
#  'bilahare',
#  'bilaistisna',
#  'bilakayduşart',
#  'bilakis',
#  'bile bile',
#  'bile',
#  'bilfiil',
#  'bilgece',
#  'bilgili',
#  'bilgince',
#  'bilhassa',
#  'bililtizam',
#  'bilistifade',
#  'bilmukabele',
#  'bilmünasebe',
#  'bilvasıta',
#  'bin kere',
#  'bin kez',
#  'bin türlü',
#  'binaen',
#  'binaenaleyh',
#  'binde bir',
#  'binkat',
#  'binnetice',
#  'biperva',
#  'bir ağızdan',
#  'bir an önce',
#  'bir an',
#  'bir anda',
#  'bir ara',
#  'bir arada',
#  'bir aralık',
#  'bir aşağı bir yukarı',
#  'bir bakıma',
#  'bir başına',
#  'bir bir',
#  'bir boy',
#  'bir çırpıda',
#  'bir daha',
#  'bir defa',
#  'bir defada',
#  'bir defalık',
#  'bir dikişte',
#  'bir düziye',
#  'bir elden',
#  'bir güzel',
#  'bir hamlede',
#  'bir hayli',
#  'bir kalem',
#  'bir kalemde',
#  'bir karar',
#  'bir kere',
#  'bir kerecik',
#  'bir kerelik',
#  'bir koşu',
#  'bir lahza',
#  'bir lahzacık',
#  'bir lahzada',
#  'bir nebze',
#  'bir nefes',
#  'bir nefeste',
#  'bir ölçüde',
#  'bir parça',
#  'bir sıra',
#  'bir solukta',
#  'bir tahtada',
#  'bir temiz',
#  'bir türlü',
#  'bir vakitler',
#  'bir yana',
#  'bir yanda',
#  'bir yandan',
#  'bir yol',
#  'bir zaman',
#  'bir zamanlar',
#  'bir',
#  'biraz',
#  'birazcık',
#  'birazdan',
#  'birden',
#  'birdenbire',
#  'bire bir',
#  'birer ikişer',
#  'birlikte',
#  'bitevi',
#  'biteviye',
#  'bittabi',
#  'biz bize',
#  'bizatihi',
#  'bizce',
#  'bizcileyin',
#  'bizzat',
#  'böcül böcül',
#  'bodoslamadan',
#  'boğaz tokluğuna',
#  'boğula boğula',
#  'boku bokuna',
#  'bol bol',
#  'bol bulamaç',
#  'bol kepçeden',
#  'bol keseden',
#  'bolca',
#  'bölük bölük',
#  'bölük pörçük',
#  'bönce',
#  'boncuk boncuk',
#  'borç harç',
#  'borçsuz harçsız',
#  'boş yere',
#  'boş',
#  'boşu boşuna',
#  'boşuna',
#  'boyca',
#  'boydan boya',
#  'boylamasına',
#  'böyle böyle',
#  'böyle',
#  'böylece',
#  'böylecene',
#  'böylelikle',
#  'böylemesine',
#  'böylesine',
#  'boylu boyunca',
#  'boynu bükük',
#  'boyuna',
#  'boyunca',
#  'boz bulanık',
#  'bu arada',
#  'bu cümleden',
#  'bu denli',
#  'bu gidişle',
#  'bu gözle',
#  'bu haysiyetle',
#  'bu kabilden',
#  'bu merkezde',
#  'bu meyanda',
#  'bu sefer',
#  'bu seferlik',
#  'bu türlü',
#  'bu yüzden',
#  'bucak bucak',
#  'budalacasına',
#  'buğul buğul',
#  'bugün yarın',
#  'bugün',
#  'bugüne bugün',
#  'bugünlerde',
#  'bugünlük',
#  'bunakça',
#  'bunca',
#  'bundan böyle',
#  'bunsuz',
#  'bununla birlikte',
#  'bünyece',
#  'buracıkta',
#  'burada',
#  'buradan',
#  'buram buram',
#  'burcu burcu',
#  'burjuvaca',
#  'buruk buruk',
#  'burum burum',
#  'burun buruna',
#  'büsbütün',
#  'bütün bütün',
#  'bütün bütüne',
#  'caba',
#  'cabadan',
#  'çabucacık',
#  'çabucak',
#  'çabuk',
#  'çabukça',
#  'çaçaronca',
#  'çağanak',
#  'çağıl çağıl',
#  'çakıl çukul',
#  'çakır çukur',
#  'çakmak çakmak',
#  'çaktırmadan',
#  'çalakalem',
#  'çalakamçı',
#  'çalakaşık',
#  'çalakılıç',
#  'çalakürek',
#  'çalapaça',
#  'çalgı çağanak',
#  'çalımlı çalımlı',
#  'çalyaka',
#  'çamçak çamçak',
#  'çan çan',
#  'can pahasına',
#  'canavarca',
#  'candan yürekten',
#  'candan',
#  'çangıl çungul',
#  'çangır çungur',
#  'canice',
#  'canıgönülden',
#  'canıyürekten',
#  'canla başla',
#  'canlı canlı',
#  'cansiparane',
#  'cansız',
#  'çap',
#  'capcanlı',
#  'çapkınca',
#  'çapraz',
#  'çaprazlama',
#  'çaprazlamasına',
#  'çaprazvari',
#  'car car',
#  'çarçabuk',
#  'carcur',
#  'çaresiz',
#  'çarnaçar',
#  'çarpıcı',
#  'çarpık',
#  'cartadak',
#  'cartadan',
#  'çat pat',
#  'çatalsız',
#  'çatır çatır',
#  'çatır çutur',
#  'çatra patra',
#  'cayır cayır',
#  'çaylakça',
#  'cazır cazır',
#  'cebren',
#  'ceffelkalem',
#  'çehrece',
#  'çekingence',
#  'çekişmeli',
#  'çelebice',
#  'çelmece',
#  'ceman yekûn',
#  'ceman',
#  'çeneye kuvvet',
#  'cengâverce',
#  'çengüçağanak',
#  'centilmence',
#  'çepeçevre',
#  'ceste ceste',
#  'cesurane',
#  'cesurca',
#  'cetbecet',
#  'çetince',
#  'cevaben',
#  'cevapsız',
#  'çevikçe',
#  'ceylanca',
#  'cidden',
#  'ciddi',
#  'çifter çifter',
#  'çiğ çiğ',
#  'çığlık çığlığa',
#  'cihangirane',
#  'cihetiyle',
#  'çıkır çıkır',
#  'çıldır çıldır',
#  'çıldırasıya',
#  'çılgıncasına',
#  'çim çim',
#  'cimrice',
#  'çın çın',
#  'çıngır çıngır',
#  'cins cins',
#  'çınsabah',
#  'çıpıl çıpıl',
#  'cır cır',
#  'çır çır',
#  'çirkefçe',
#  'çirkince',
#  'cırlak cırlak',
#  'cismen',
#  'çıtır pıtır',
#  'cıvıl cıvıl',
#  'ciyak ciyak',
#  'cıyak cıyak',
#  'çizin çizin',
#  'cızır cızır',
#  'çocukça',
#  'çoğu kez',
#  'çoğun',
#  'çoğunlukla',
#  'çok geçmeden',
#  'çok',
#  'çokça',
#  'çoklarınca',
#  'çokluk',
#  'çoklukla',
#  'çoktan',
#  'cömertçe',
#  'coşkunca',
#  'cuk',
#  'cumbul cumbul',
#  'cümbür cemaat',
#  'cumhur cemaat',
#  'cumhurca',
#  'cümleten',
#  'dağ taş',
#  'daha daha',
#  'daha',
#  'dâhice',
#  'dâhil',
#  'dâhilen',
#  'daim',
#  'daima',
#  'dakika başı',
#  'dakikane',
#  'dakikası dakikasına',
#  'dakikasında',
#  'daldan dala',
#  'dalga dalga',
#  'dalgın dalgın',
#  'dalgın',
#  'dalgündüz',
#  'dalkavukça',
#  'dalkılıç',
#  'damla damla',
#  'damsız',
#  'dan dan',
#  'dangadak',
#  'dangıl dungul',
#  'dar darına',
#  'dar',
#  'dara dar',
#  'darasız',
#  'darı darına',
#  'decrescendo',
#  'defacto',
#  'defalarca',
#  'defaten',
#  'dehşetli',
#  'delep delep',
#  'deli dolu',
#  'delice',
#  'delicesine',
#  'dembedem',
#  'demin',
#  'demincek',
#  'deminden',
#  'deneysiz',
#  'derakap',
#  'derbederce',
#  'dere tepe',
#  'derece derece',
#  'derhâl',
#  'derhatır',
#  'derin derin',
#  'derinden derine',
#  'derinden',
#  'derinlemesine',
#  'derinliğine',
#  'derken',
#  'derli toplu',
#  'dertop',
#  'dervişane',
#  'dervişçe',
#  'despotça',
#  'devamlı',
#  'devce',
#  'devre',
#  'devren',
#  'dıbır dıbır',
#  'didik didik',
#  'dikçe',
#  'dikenlice',
#  'dikensiz',
#  'dikey',
#  'dikine',
#  'diklemesine',
#  'diktatörce',
#  'dilden dile',
#  'dilim dilim',
#  'dimdik',
#  'diminuendo',
#  'dince',
#  'dinen',
#  'dip bucak',
#  'dip dibe',
#  'dip doruk',
#  'diplomatça',
#  'direkt',
#  'dirhem dirhem',
#  'diri diri',
#  'dirsek dirseğe',
#  'diş diş',
#  'dışarı',
#  'dişiyle tırnağıyla',
#  'diye diye',
#  'diye',
#  'diz boyu',
#  'diz dize',
#  'diz üstü',
#  'dizi dizi',
#  'dizim dizim',
#  'dobra dobra',
#  'doğaçlama',
#  'doğaçtan',
#  'doğallıkla',
#  'doğma büyüme',
#  'doğmaca',
#  'doğru',
#  'doğruca',
#  'doğrudan doğruya',
#  'doğrudan',
#  'doğrusu',
#  'döke döke',
#  'döke saça',
#  'dolayı dolayı',
#  'dolayı',
#  'dolayısıyla',
#  'dolaysız',
#  'doludizgin',
#  'domur domur',
#  'domuzuna',
#  'don gömlek',
#  'donuk donuk',
#  'dönüşümlü',
#  'dört ayak',
#  'dörtnala',
#  'doruklama',
#  'dosdoğru',
#  'dostane',
#  'dostça',
#  'doyasıya',
#  'düğünsüz',
#  'dün',
#  'dünden bugüne',
#  'dünden',
#  'dünyada',
#  'düpedüz',
#  'duraksız',
#  'durduğu yerde',
#  'durmadan',
#  'dürüm dürüm',
#  'durumca',
#  'durup dinlenmeden',
#  'durup durup',
#  'durup dururken',
#  'düşe kalka',
#  'duyguca',
#  'düzgün',
#  'düzüm düzüm',
#  'ebediyen',
#  'ebesiz',
#  'edepli edepli',
#  'edepli',
#  'edepsizce',
#  'edepsizcesine',
#  'edibane',
#  'efece',
#  'efendi efendi',
#  'efendice',
#  'efil efil',
#  'eğreti',
#  'eğri',
#  'ekmeksiz',
#  'ekseri',
#  'ekseriya',
#  'ekseriyetle',
#  'eksik artık',
#  'eksiksiz',
#  'ekstra',
#  'el altında',
#  'el altından',
#  'el ele',
#  'elan',
#  'elbet',
#  'elbette',
#  'elden ele',
#  'elden',
#  'elhak',
#  'elhasıl',
#  'elifi elifine',
#  'elinden',
#  'eliyle',
#  'elverdiğince',
#  'emaneten',
#  'emprovize',
#  'en aşağı',
#  'en azından',
#  'en',
#  'enayice',
#  'enayicesine',
#  'ender',
#  'enikonu',
#  'eninde sonunda',
#  'enine boyuna',
#  'enlemesine',
#  'epey',
#  'epeyce',
#  'epeyi',
#  'epeyice',
#  'er geç',
#  'er',
#  'erce',
#  'ercecik',
#  'erim erim',
#  'erkek erkeğe',
#  'erkekli kadınlı',
#  'erkeksiz',
#  'erken',
#  'erkence',
#  'erkenden',
#  'esasen',
#  'esaslı',
#  'esefle',
#  'eşekçe',
#  'eser miktarda',
#  'eskiden',
#  'eşkin',
#  'eşli',
#  'esnasında',
#  'etek etek',
#  'etraflı',
#  'etraflıca',
#  'evce',
#  'evcek',
#  'evire çevire',
#  'evleviyetle',
#  'evvel ahir',
#  'evvel zaman',
#  'evvel',
#  'evvela',
#  'evvelce',
#  'evvelden',
#  'evvelemirde',
#  'evveli',
#  'evvelleri',
#  'ezberden',
#  'ezbere',
#  'ezcümle',
#  'ezel ebet',
#  'ezgince',
#  'ezile büzüle',
#  'ezim ezim',
#  'ezkaza',
#  'fakirce',
#  'faraza',
#  'farklıca',
#  'farzımuhal',
#  'faşır faşır',
#  'fasla fasla',
#  'fatihane',
#  'faullü',
#  'faulsüz',
#  'fazla',
#  'fazlaca',
#  'fazladan',
#  'fazlasıyla',
#  'fedaice',
#  'fehvasınca',
#  'fellek fellek',
#  'fellik fellik',
#  'fena hâlde',
#  'fena',
#  'ferah fahur',
#  'ferah ferah',
#  'ferden ferda',
#  'ferih fahur',
#  'fersah fersah',
#  'feryat figan',
#  'fettanca',
#  'fevç fevç',
#  'fi tarihinde',
#  'fiilen',
#  'fıkır fıkır',
#  'fikren',
#  'filhakika',
#  'filozofça',
#  'filvaki',
#  'fincan fincan',
#  'fır fır',
#  'fır',
#  'fırdolayı',
#  'fırıl fırıl',
#  'fırt fırt',
#  'fıs fıs',
#  'fış fış',
#  'fisebilillah',
#  'fısıl fısıl',
#  'fısır fısır',
#  'fışır fışır',
#  'fıtraten',
#  'fizikçe',
#  'fokur fokur',
#  'fondip',
#  'forte',
#  'fortepiano',
#  'fortissimo',
#  'fosur fosur',
#  'fücceten',
#  'fütursuzca',
#  'fuzuli',
#  'gacır gacır',
#  'gacır gucur',
#  'gafilane',
#  'gâh',
#  'gâhi',
#  'gâhice',
#  'galiba',
#  'gani gani',
#  'garanti',
#  'garazsız ivazsız',
#  'gâvurca',
#  'gâvurcasına',
#  'gayet',
#  'gayetle',
#  'gayri',
#  'gayrı',
#  'gayriihtiyari',
#  'geç saatler',
#  'geç',
#  'geççe',
#  'gece gündüz',
#  'gece',
#  'geçe',
#  'geceleri',
#  'geceleyin',
#  'geçende',
#  'geçenlerde',
#  'gene',
#  'genellikle',
#  'geniş çaplı',
#  ...]

# %%
processed_docs = []
# !pip install progressbar2
from progressbar import ProgressBar
bar = ProgressBar()

for doc in bar(df):
    processed_docs.append(preprocess(doc))
# Out:
# Requirement already satisfied: progressbar2 in /usr/local/lib/python3.7/dist-packages (3.38.0)
# Requirement already satisfied: python-utils>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from progressbar2) (2.5.6)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from progressbar2) (1.15.0)
# 100% (287821 of 287821) |################| Elapsed Time: 3:03:05 Time:  3:03:05

# %% [markdown]
# # Dictionary

# %%
dictionary = gensim.corpora.Dictionary(processed_docs)

# %%
count = 0                         #Testing if it is created
for k, v in dictionary.iteritems():
    print(k, v)
    count += 1
    if count > 10:
        break
# Out:
# 0
# 1 a
# 2 abak
# 3 abdde
# 4 abdurrahma
# 5 ablas
# 6 acıl
# 7 acımadık
# 8 acımamış
# 9 ad
# 10 ada

# %%
'''
Remove very rare and very common words: (Probably not working for Turkish but I tried)
'''
dictionary.filter_extremes(no_below=15, no_above=0.1, keep_n= 100000)

# %%
'''
Create the Bag-of-words model for each document i.e for each document we create a dictionary reporting how many
words and how many times those words appear. Save this to 'bow_corpus'
'''
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]

# %%
'''
Preview BOW for our sample preprocessed document
'''
document_num = 20
bow_doc_x = bow_corpus[document_num]

for i in range(len(bow_doc_x)):
    print("Word {} (\"{}\") appears {} time.".format(bow_doc_x[i][0], 
                                                     dictionary[bow_doc_x[i][0]], 
                                                     bow_doc_x[i][1]))
# Out:
# Word 7 ("ada") appears 2 time.
# Word 8 ("adam") appears 2 time.
# Word 16 ("aile") appears 3 time.
# Word 18 ("ak") appears 10 time.
# Word 21 ("akrabalık") appears 2 time.
# Word 33 ("akış") appears 1 time.
# Word 40 ("alan") appears 11 time.
# Word 44 ("aldık") appears 1 time.
# Word 49 ("alma") appears 34 time.
# Word 54 ("alt") appears 14 time.
# Word 58 ("alına") appears 4 time.
# Word 59 ("alınabilir") appears 1 time.
# Word 61 ("alır") appears 5 time.
# Word 65 ("amaç") appears 4 time.
# Word 68 ("america") appears 1 time.
# Word 69 ("an") appears 2 time.
# Word 73 ("anla") appears 35 time.
# Word 74 ("anlam") appears 16 time.
# Word 84 ("anlaşma") appears 6 time.
# Word 96 ("aracılık") appears 1 time.
# Word 101 ("arap") appears 2 time.
# Word 102 ("aras") appears 14 time.
# Word 106 ("araştırma") appears 6 time.
# Word 108 ("araştırır") appears 3 time.
# Word 110 ("ardı") appears 1 time.
# Word 111 ("ardıl") appears 1 time.
# Word 112 ("arka") appears 2 time.
# Word 113 ("arkadaş") appears 2 time.
# Word 125 ("asker") appears 2 time.
# Word 131 ("asıl") appears 3 time.
# Word 162 ("avrupa") appears 2 time.
# Word 165 ("ay") appears 2 time.
# Word 169 ("ayr") appears 1 time.
# Word 174 ("ayrılır") appears 2 time.
# Word 183 ("açı") appears 6 time.
# Word 203 ("bacak") appears 1 time.
# Word 211 ("bak") appears 4 time.
# Word 222 ("basit") appears 2 time.
# Word 224 ("baskı") appears 2 time.
# Word 226 ("baskıs") appears 1 time.
# Word 230 ("bat") appears 1 time.
# Word 238 ("bağla") appears 4 time.
# Word 243 ("bağlanma") appears 2 time.
# Word 245 ("bağlılık") appears 1 time.
# Word 246 ("bağımlılık") appears 1 time.
# Word 247 ("bağımsız") appears 2 time.
# Word 249 ("baş") appears 4 time.
# Word 265 ("başlamış") appears 1 time.
# Word 268 ("başlatıla") appears 1 time.
# Word 270 ("başlaya") appears 1 time.
# Word 282 ("belge") appears 1 time.
# Word 285 ("belirlemek") appears 1 time.
# Word 288 ("belli") appears 6 time.
# Word 295 ("bey") appears 1 time.
# Word 300 ("bil") appears 21 time.
# Word 306 ("bilgi") appears 7 time.
# Word 308 ("bilimci") appears 5 time.
# Word 309 ("biline") appears 5 time.
# Word 313 ("bilinmeye") appears 2 time.
# Word 315 ("biliyor") appears 1 time.
# Word 316 ("bilmedik") appears 1 time.
# Word 318 ("bin") appears 2 time.
# Word 323 ("bir") appears 4 time.
# Word 324 ("birader") appears 1 time.
# Word 325 ("birbir") appears 9 time.
# Word 326 ("birer") appears 1 time.
# Word 327 ("birim") appears 8 time.
# Word 328 ("birleş") appears 2 time.
# Word 331 ("birleştire") appears 1 time.
# Word 339 ("biz") appears 1 time.
# Word 340 ("biç") appears 21 time.
# Word 342 ("bo") appears 1 time.
# Word 350 ("boyut") appears 5 time.
# Word 358 ("bugu") appears 1 time.
# Word 359 ("bugünkü") appears 1 time.
# Word 371 ("bulunamamış") appears 1 time.
# Word 374 ("bulunduk") appears 3 time.
# Word 375 ("bulunmak") appears 4 time.
# Word 379 ("bun") appears 2 time.
# Word 380 ("bur") appears 1 time.
# Word 381 ("bura") appears 2 time.
# Word 388 ("bölges") appears 1 time.
# Word 402 ("canlı") appears 5 time.
# Word 425 ("dair") appears 2 time.
# Word 427 ("dal") appears 1 time.
# Word 439 ("davranış") appears 6 time.
# Word 465 ("demek") appears 2 time.
# Word 470 ("dene") appears 2 time.
# Word 471 ("denile") appears 1 time.
# Word 476 ("derece") appears 2 time.
# Word 477 ("dergi") appears 1 time.
# Word 483 ("destek") appears 2 time.
# Word 488 ("deva") appears 4 time.
# Word 492 ("devlet") appears 2 time.
# Word 495 ("değer") appears 3 time.
# Word 498 ("değil") appears 10 time.
# Word 499 ("değiş") appears 26 time.
# Word 500 ("değişik") appears 3 time.
# Word 508 ("dikkat") appears 4 time.
# Word 510 ("dil") appears 369 time.
# Word 521 ("diz") appears 2 time.
# Word 524 ("dok") appears 2 time.
# Word 525 ("doktor") appears 1 time.
# Word 528 ("dol") appears 1 time.
# Word 535 ("doğal") appears 21 time.
# Word 537 ("doğruluk") appears 2 time.
# Word 538 ("doğu") appears 1 time.
# Word 543 ("doğuş") appears 1 time.
# Word 544 ("dur") appears 44 time.
# Word 550 ("durum") appears 14 time.
# Word 554 ("duya") appears 2 time.
# Word 556 ("duygu") appears 3 time.
# Word 557 ("duyma") appears 5 time.
# Word 561 ("dö") appears 1 time.
# Word 568 ("döne") appears 1 time.
# Word 570 ("dönem") appears 2 time.
# Word 582 ("düzenle") appears 3 time.
# Word 584 ("düzenlene") appears 1 time.
# Word 587 ("düzenli") appears 3 time.
# Word 588 ("düzey") appears 1 time.
# Word 589 ("düş") appears 9 time.
# Word 590 ("düşe") appears 1 time.
# Word 599 ("düşünce") appears 10 time.
# Word 606 ("düşünür") appears 1 time.
# Word 607 ("düşünüyor") appears 1 time.
# Word 610 ("dış") appears 7 time.
# Word 611 ("dışarı") appears 2 time.
# Word 614 ("edebilir") appears 1 time.
# Word 615 ("edebiyat") appears 4 time.
# Word 621 ("eder") appears 10 time.
# Word 623 ("edil") appears 1 time.
# Word 624 ("edildik") appears 1 time.
# Word 625 ("edile") appears 7 time.
# Word 628 ("edilir") appears 5 time.
# Word 630 ("edilme") appears 1 time.
# Word 641 ("egemenlik") appears 1 time.
# Word 644 ("el") appears 12 time.
# Word 675 ("eser") appears 2 time.
# Word 678 ("et") appears 2 time.
# Word 680 ("etki") appears 12 time.
# Word 681 ("etkil") appears 1 time.
# Word 682 ("etkile") appears 1 time.
# Word 684 ("etkilemiş") appears 1 time.
# Word 687 ("etkis") appears 7 time.
# Word 688 ("etme") appears 5 time.
# Word 690 ("etmek") appears 7 time.
# Word 694 ("etmez") appears 1 time.
# Word 696 ("etmiş") appears 1 time.
# Word 697 ("etnik") appears 2 time.
# Word 706 ("ev") appears 1 time.
# Word 720 ("evrak") appears 1 time.
# Word 726 ("eğit") appears 8 time.
# Word 727 ("eğitimli") appears 1 time.
# Word 739 ("fark") appears 5 time.
# Word 740 ("farklı") appears 22 time.
# Word 745 ("faydalanarak") appears 1 time.
# Word 747 ("fazlas") appears 1 time.
# Word 748 ("federasyo") appears 2 time.
# Word 764 ("fiziksel") appears 2 time.
# Word 777 ("gel") appears 2 time.
# Word 778 ("geldik") appears 3 time.
# Word 779 ("gele") appears 3 time.
# Word 781 ("gelecek") appears 2 time.
# Word 783 ("gelenek") appears 1 time.
# Word 788 ("gelir") appears 1 time.
# Word 790 ("geliş") appears 7 time.
# Word 791 ("gelişe") appears 2 time.
# Word 792 ("gelişmes") appears 3 time.
# Word 794 ("gelme") appears 1 time.
# Word 797 ("gelmek") appears 4 time.
# Word 801 ("genetik") appears 2 time.
# Word 802 ("geniş") appears 3 time.
# Word 807 ("genç") appears 1 time.
# Word 809 ("geographiç") appears 1 time.
# Word 812 ("gerekir") appears 3 time.
# Word 814 ("gerektik") appears 1 time.
# Word 815 ("gerginlik") appears 1 time.
# Word 816 ("geri") appears 1 time.
# Word 818 ("gerçek") appears 3 time.
# Word 826 ("getiril") appears 4 time.
# Word 830 ("getirilmes") appears 1 time.
# Word 834 ("getirmek") appears 1 time.
# Word 837 ("geç") appears 1 time.
# Word 839 ("geçecek") appears 1 time.
# Word 855 ("geçirmek") appears 1 time.
# Word 859 ("geçmiş") appears 2 time.
# Word 862 ("gider") appears 1 time.
# Word 875 ("giriş") appears 2 time.
# Word 877 ("girmek") appears 1 time.
# Word 887 ("grup") appears 5 time.
# Word 890 ("göl") appears 1 time.
# Word 896 ("gör") appears 1 time.
# Word 898 ("göre") appears 2 time.
# Word 905 ("görmez") appears 1 time.
# Word 914 ("görünmez") appears 5 time.
# Word 917 ("görür") appears 1 time.
# Word 918 ("görüş") appears 7 time.
# Word 922 ("göstere") appears 3 time.
# Word 923 ("gösterecek") appears 1 time.
# Word 924 ("gösteren") appears 1 time.
# Word 928 ("gösterir") appears 5 time.
# Word 930 ("göstermek") appears 3 time.
# Word 937 ("göz") appears 2 time.
# Word 944 ("gün") appears 9 time.
# Word 946 ("güney") appears 2 time.
# Word 949 ("güvenilir") appears 1 time.
# Word 955 ("güç") appears 4 time.
# Word 958 ("güçlü") appears 1 time.
# Word 978 ("hal") appears 2 time.
# Word 983 ("hale") appears 1 time.
# Word 986 ("halk") appears 21 time.
# Word 987 ("halkı") appears 1 time.
# Word 1002 ("hareke") appears 2 time.
# Word 1003 ("hareket") appears 29 time.
# Word 1016 ("hastalık") appears 1 time.
# Word 1027 ("hayat") appears 2 time.
# Word 1029 ("hayvan") appears 1 time.
# Word 1033 ("hazine") appears 2 time.
# Word 1047 ("hesap") appears 2 time.
# Word 1051 ("hikâye") appears 1 time.
# Word 1061 ("hizmet") appears 4 time.
# Word 1101 ("ifa") appears 16 time.
# Word 1102 ("ifade") appears 15 time.
# Word 1106 ("ihtiyaç") appears 4 time.
# Word 1108 ("iki") appears 3 time.
# Word 1113 ("iktidar") appears 2 time.
# Word 1127 ("ilgilenme") appears 1 time.
# Word 1129 ("ilişki") appears 8 time.
# Word 1130 ("ilişkis") appears 1 time.
# Word 1140 ("in") appears 24 time.
# Word 1144 ("inanç") appears 1 time.
# Word 1149 ("insa") appears 15 time.
# Word 1150 ("insan") appears 3 time.
# Word 1151 ("insanlık") appears 3 time.
# Word 1160 ("is") appears 2 time.
# Word 1162 ("isimli") appears 4 time.
# Word 1165 ("ismi") appears 2 time.
# Word 1179 ("istiyor") appears 1 time.
# Word 1183 ("itibar") appears 1 time.
# Word 1191 ("iz") appears 4 time.
# Word 1196 ("iç") appears 1 time.
# Word 1199 ("içeri") appears 13 time.
# Word 1200 ("içerik") appears 4 time.
# Word 1202 ("içeris") appears 3 time.
# Word 1205 ("iş") appears 2 time.
# Word 1206 ("işaret") appears 63 time.
# Word 1210 ("işle") appears 2 time.
# Word 1214 ("japo") appears 1 time.
# Word 1220 ("kabiliyet") appears 1 time.
# Word 1221 ("kabul") appears 20 time.
# Word 1234 ("kalacak") appears 1 time.
# Word 1245 ("kale") appears 1 time.
# Word 1250 ("kalma") appears 2 time.
# Word 1251 ("kalmadık") appears 1 time.
# Word 1265 ("kanun") appears 1 time.
# Word 1277 ("kapı") appears 1 time.
# Word 1283 ("karakteris") appears 1 time.
# Word 1294 ("karmaşık") appears 1 time.
# Word 1301 ("karşı") appears 3 time.
# Word 1310 ("karşılık") appears 3 time.
# Word 1311 ("karşıs") appears 1 time.
# Word 1316 ("katkı") appears 4 time.
# Word 1330 ("kavra") appears 12 time.
# Word 1343 ("kaynak") appears 2 time.
# Word 1346 ("kayıt") appears 4 time.
# Word 1347 ("kaza") appears 1 time.
# Word 1372 ("kel") appears 31 time.
# Word 1374 ("kelimes") appears 2 time.
# Word 1379 ("kendi") appears 4 time.
# Word 1401 ("kimse") appears 2 time.
# Word 1403 ("kiş") appears 7 time.
# Word 1404 ("kişi") appears 4 time.
# Word 1406 ("kişisel") appears 6 time.
# Word 1413 ("kol") appears 2 time.
# Word 1422 ("kontrol") appears 2 time.
# Word 1423 ("konu") appears 5 time.
# Word 1426 ("konum") appears 1 time.
# Word 1427 ("konus") appears 10 time.
# Word 1428 ("konuşma") appears 61 time.
# Word 1434 ("korku") appears 1 time.
# Word 1450 ("krallık") appears 1 time.
# Word 1452 ("kulak") appears 1 time.
# Word 1454 ("kulla") appears 3 time.
# Word 1455 ("kullana") appears 2 time.
# Word 1459 ("kullandık") appears 7 time.
# Word 1460 ("kullanma") appears 2 time.
# Word 1462 ("kullanıla") appears 10 time.
# Word 1463 ("kullanıldık") appears 2 time.
# Word 1468 ("kur") appears 2 time.
# Word 1470 ("kural") appears 19 time.
# Word 1499 ("kutsal") appears 1 time.
# Word 1505 ("kuzey") appears 1 time.
# Word 1506 ("kuş") appears 1 time.
# Word 1509 ("kuşatma") appears 1 time.
# Word 1514 ("kök") appears 1 time.
# Word 1515 ("köken") appears 4 time.
# Word 1518 ("köpek") appears 2 time.
# Word 1522 ("kül") appears 5 time.
# Word 1523 ("kültür") appears 5 time.
# Word 1524 ("kültürel") appears 4 time.
# Word 1528 ("küçük") appears 9 time.
# Word 1529 ("kı") appears 1 time.
# Word 1540 ("kısmı") appears 5 time.
# Word 1546 ("kıyıs") appears 1 time.
# Word 1560 ("ma") appears 3 time.
# Word 1563 ("madde") appears 1 time.
# Word 1564 ("maddes") appears 1 time.
# Word 1573 ("makale") appears 2 time.
# Word 1576 ("mal") appears 1 time.
# Word 1578 ("malzeme") appears 1 time.
# Word 1586 ("mart") appears 4 time.
# Word 1587 ("maruz") appears 1 time.
# Word 1597 ("mağlup") appears 1 time.
# Word 1618 ("meslek") appears 1 time.
# Word 1627 ("meyda") appears 8 time.
# Word 1636 ("millet") appears 2 time.
# Word 1641 ("miras") appears 1 time.
# Word 1645 ("modern") appears 2 time.
# Word 1679 ("mümk") appears 14 time.
# Word 1697 ("national") appears 3 time.
# Word 1710 ("nesil") appears 3 time.
# Word 1711 ("nesl") appears 1 time.
# Word 1715 ("ngiltere") appears 1 time.
# Word 1718 ("nitelik") appears 2 time.
# Word 1719 ("niyet") appears 1 time.
# Word 1724 ("nokta") appears 2 time.
# Word 1725 ("noktas") appears 2 time.
# Word 1727 ("nsa") appears 2 time.
# Word 1734 ("ok") appears 2 time.
# Word 1737 ("okyanus") appears 1 time.
# Word 1739 ("ol") appears 3 time.
# Word 1741 ("olabilecek") appears 1 time.
# Word 1743 ("olacak") appears 3 time.
# Word 1747 ("olan") appears 2 time.
# Word 1748 ("olay") appears 1 time.
# Word 1750 ("olduk") appears 1 time.
# Word 1751 ("olma") appears 12 time.
# Word 1752 ("olmadık") appears 1 time.
# Word 1755 ("olmas") appears 1 time.
# Word 1756 ("olmayacak") appears 1 time.
# Word 1763 ("olur") appears 1 time.
# Word 1764 ("oluşa") appears 6 time.
# Word 1766 ("oluştuk") appears 1 time.
# Word 1767 ("oluştur") appears 1 time.
# Word 1768 ("oluştura") appears 2 time.
# Word 1770 ("oluşturduk") appears 3 time.
# Word 1771 ("oluşturma") appears 7 time.
# Word 1773 ("oluşturul") appears 4 time.
# Word 1775 ("oluşum") appears 3 time.
# Word 1786 ("orijinal") appears 1 time.
# Word 1791 ("orta") appears 26 time.
# Word 1792 ("ortak") appears 6 time.
# Word 1803 ("oynadık") appears 1 time.
# Word 1810 ("p") appears 1 time.
# Word 1814 ("paris") appears 2 time.
# Word 1818 ("parça") appears 2 time.
# Word 1821 ("parças") appears 1 time.
# Word 1822 ("pasifik") appears 1 time.
# Word 1828 ("pla") appears 1 time.
# Word 1829 ("plan") appears 1 time.
# Word 1830 ("planla") appears 1 time.
# Word 1832 ("politik") appears 4 time.
# Word 1846 ("psikolojik") appears 1 time.
# Word 1871 ("rica") appears 1 time.
# Word 1878 ("rusya") appears 1 time.
# Word 1908 ("sanat") appears 2 time.
# Word 1916 ("savaş") appears 1 time.
# Word 1927 ("sayı") appears 4 time.
# Word 1929 ("sayılabilir") appears 1 time.
# Word 1930 ("sayılır") appears 1 time.
# Word 1934 ("sağlama") appears 2 time.
# Word 1936 ("sağlamış") appears 1 time.
# Word 1939 ("se") appears 5 time.
# Word 1940 ("sebep") appears 4 time.
# Word 1966 ("ses") appears 12 time.
# Word 1971 ("seviye") appears 1 time.
# Word 1993 ("sinir") appears 1 time.
# Word 1996 ("siste") appears 16 time.
# Word 1997 ("sistem") appears 10 time.
# Word 2005 ("sokak") appears 1 time.
# Word 2009 ("sonbahar") appears 1 time.
# Word 2014 ("sonuç") appears 13 time.
# Word 2023 ("stanbul") appears 5 time.
# Word 2046 ("söylemek") appears 1 time.
# Word 2053 ("söz") appears 4 time.
# Word 2058 ("sür") appears 4 time.
# Word 2063 ("süre") appears 1 time.
# Word 2067 ("süreç") appears 12 time.
# Word 2077 ("süslü") appears 1 time.
# Word 2080 ("sık") appears 2 time.
# Word 2082 ("sınır") appears 2 time.
# Word 2084 ("sır") appears 14 time.
# Word 2085 ("sıra") appears 4 time.
# Word 2091 ("t") appears 4 time.
# Word 2092 ("ta") appears 1 time.
# Word 2094 ("taciz") appears 1 time.
# Word 2097 ("tahm") appears 1 time.
# Word 2103 ("takdir") appears 1 time.
# Word 2104 ("takip") appears 2 time.
# Word 2112 ("talep") appears 3 time.
# Word 2125 ("tanına") appears 1 time.
# Word 2133 ("taraf") appears 4 time.
# Word 2136 ("tarihî") appears 4 time.
# Word 2138 ("tartışma") appears 1 time.
# Word 2139 ("tarz") appears 1 time.
# Word 2143 ("tasvir") appears 1 time.
# Word 2153 ("taş") appears 1 time.
# Word 2158 ("taşımak") appears 1 time.
# Word 2165 ("taşıya") appears 4 time.
# Word 2166 ("taşıyıcıs") appears 1 time.
# Word 2171 ("tehdit") appears 1 time.
# Word 2173 ("tehlike") appears 3 time.
# Word 2176 ("teknik") appears 6 time.
# Word 2178 ("telaffuz") appears 3 time.
# Word 2181 ("temel") appears 12 time.
# Word 2194 ("terç") appears 4 time.
# Word 2198 ("tespit") appears 3 time.
# Word 2207 ("teşvik") appears 1 time.
# Word 2220 ("topl") appears 6 time.
# Word 2221 ("topla") appears 1 time.
# Word 2231 ("topluluk") appears 1 time.
# Word 2239 ("tut") appears 1 time.
# Word 2261 ("türkiye") appears 1 time.
# Word 2265 ("türkçe") appears 1 time.
# Word 2274 ("ulaşmak") appears 2 time.
# Word 2279 ("ulusal") appears 4 time.
# Word 2280 ("uluslararas") appears 11 time.
# Word 2285 ("unsur") appears 6 time.
# Word 2299 ("uygu") appears 4 time.
# Word 2300 ("uygula") appears 2 time.
# Word 2307 ("uzak") appears 2 time.
# Word 2323 ("uğraş") appears 1 time.
# Word 2324 ("uğraşa") appears 2 time.
# Word 2326 ("va") appears 4 time.
# Word 2337 ("varlık") appears 5 time.
# Word 2349 ("verdik") appears 1 time.
# Word 2350 ("vere") appears 2 time.
# Word 2355 ("verile") appears 3 time.
# Word 2356 ("verilme") appears 1 time.
# Word 2359 ("verir") appears 1 time.
# Word 2361 ("verme") appears 1 time.
# Word 2363 ("vermek") appears 1 time.
# Word 2378 ("ya") appears 16 time.
# Word 2380 ("yak") appears 4 time.
# Word 2387 ("yaklaş") appears 2 time.
# Word 2389 ("yaklaşık") appears 3 time.
# Word 2408 ("yapma") appears 1 time.
# Word 2415 ("yapıl") appears 1 time.
# Word 2422 ("yar") appears 1 time.
# Word 2430 ("yararla") appears 1 time.
# Word 2435 ("yardımcı") appears 3 time.
# Word 2437 ("yarı") appears 2 time.
# Word 2443 ("yasal") appears 1 time.
# Word 2455 ("yaz") appears 30 time.
# Word 2456 ("yazar") appears 3 time.
# Word 2457 ("yazma") appears 3 time.
# Word 2461 ("yazı") appears 8 time.
# Word 2462 ("yazıl") appears 10 time.
# Word 2464 ("yazılış") appears 1 time.
# Word 2465 ("yazıs") appears 9 time.
# Word 2466 ("yazışma") appears 3 time.
# Word 2471 ("yaş") appears 7 time.
# Word 2472 ("yaşa") appears 2 time.
# Word 2473 ("yaşadık") appears 1 time.
# Word 2474 ("yaşam") appears 1 time.
# Word 2481 ("yaşar") appears 3 time.
# Word 2482 ("yaşaya") appears 5 time.
# Word 2494 ("yenilik") appears 1 time.
# Word 2495 ("yer") appears 5 time.
# Word 2496 ("yerel") appears 2 time.
# Word 2498 ("yerleşik") appears 1 time.
# Word 2499 ("yerli") appears 1 time.
# Word 2511 ("yol") appears 5 time.
# Word 2525 ("yön") appears 4 time.
# Word 2528 ("yönelik") appears 3 time.
# Word 2529 ("yönet") appears 2 time.
# Word 2551 ("yüz") appears 2 time.
# Word 2554 ("yüzyıl") appears 9 time.
# Word 2559 ("yıldız") appears 1 time.
# Word 2560 ("yıllık") appears 1 time.
# Word 2563 ("z") appears 1 time.
# Word 2565 ("zaman") appears 4 time.
# Word 2566 ("zamanki") appears 1 time.
# Word 2586 ("zor") appears 4 time.
# Word 2589 ("zorluk") appears 1 time.
# Word 2593 ("ç") appears 2 time.
# Word 2602 ("çalış") appears 2 time.
# Word 2604 ("çalışma") appears 7 time.
# Word 2606 ("çalışır") appears 3 time.
# Word 2619 ("çağdaş") appears 4 time.
# Word 2632 ("çevre") appears 6 time.
# Word 2633 ("çevres") appears 1 time.
# Word 2634 ("çeşitli") appears 2 time.
# Word 2636 ("çi") appears 1 time.
# Word 2643 ("çocuk") appears 4 time.
# Word 2651 ("çık") appears 4 time.
# Word 2652 ("çıka") appears 1 time.
# Word 2653 ("çıkar") appears 6 time.
# Word 2657 ("çıkarma") appears 1 time.
# Word 2661 ("çıkarıla") appears 1 time.
# Word 2663 ("çıkma") appears 1 time.
# Word 2664 ("çıktık") appears 4 time.
# Word 2666 ("çıkış") appears 1 time.
# Word 2674 ("öl") appears 2 time.
# Word 2681 ("öldürme") appears 1 time.
# Word 2695 ("ölçü") appears 3 time.
# Word 2696 ("ölüm") appears 5 time.
# Word 2699 ("ön") appears 4 time.
# Word 2700 ("öncek") appears 2 time.
# Word 2701 ("öncü") appears 1 time.
# Word 2704 ("öne") appears 3 time.
# Word 2705 ("önemli") appears 14 time.
# Word 2712 ("örnek") appears 20 time.
# Word 2717 ("özel") appears 10 time.
# Word 2718 ("özellik") appears 12 time.
# Word 2721 ("öğre") appears 3 time.
# Word 2723 ("öğrendik") appears 1 time.
# Word 2725 ("öğrenme") appears 2 time.
# Word 2730 ("ülke") appears 10 time.
# Word 2732 ("ünlü") appears 2 time.
# Word 2742 ("üzer") appears 1 time.
# Word 2743 ("üçüncü") appears 1 time.
# Word 2764 ("şart") appears 1 time.
# Word 2769 ("şehir") appears 1 time.
# Word 2774 ("şekl") appears 2 time.
# Word 2775 ("şekli") appears 2 time.
# Word 2777 ("şey") appears 1 time.
# Word 2786 ("şubat") appears 1 time.
# Word 2792 ("film") appears 1 time.
# Word 2793 ("gelebilir") appears 1 time.
# Word 2804 ("birinci") appears 2 time.
# Word 2814 ("ders") appears 1 time.
# Word 2818 ("doğrultu") appears 1 time.
# Word 2827 ("gazete") appears 1 time.
# Word 2834 ("görüle") appears 2 time.
# Word 2851 ("katılır") appears 1 time.
# Word 2853 ("kinci") appears 2 time.
# Word 2873 ("olmak") appears 3 time.
# Word 2890 ("tan") appears 3 time.
# Word 2902 ("türki") appears 2 time.
# Word 2910 ("yürütme") appears 1 time.
# Word 2915 ("öğrenim") appears 2 time.
# Word 2916 ("üstlenir") appears 1 time.
# Word 2919 ("adlandırılır") appears 1 time.
# Word 2925 ("alınarak") appears 1 time.
# Word 2930 ("araç") appears 21 time.
# Word 2934 ("ayrıntıl") appears 1 time.
# Word 2935 ("aça") appears 2 time.
# Word 2937 ("aşama") appears 2 time.
# Word 2940 ("başarıs") appears 1 time.
# Word 2943 ("belir") appears 5 time.
# Word 2944 ("belirleyiç") appears 1 time.
# Word 2947 ("benzer") appears 5 time.
# Word 2949 ("bilgisayar") appears 6 time.
# Word 2950 ("bilinir") appears 1 time.
# Word 2951 ("biliş") appears 1 time.
# Word 2954 ("bulunmamak") appears 1 time.
# Word 2962 ("dayal") appears 1 time.
# Word 2971 ("değişiklik") appears 5 time.
# Word 2980 ("düşük") appears 1 time.
# Word 2995 ("gelişim") appears 7 time.
# Word 2996 ("gelişme") appears 5 time.
# Word 3012 ("gösterilebilir") appears 4 time.
# Word 3013 ("hakkı") appears 4 time.
# Word 3041 ("kelime") appears 30 time.
# Word 3042 ("kit") appears 3 time.
# Word 3045 ("kon") appears 2 time.
# Word 3046 ("konferans") appears 2 time.
# Word 3050 ("kullanıcı") appears 2 time.
# Word 3051 ("kullanılabilir") appears 1 time.
# Word 3053 ("kullanım") appears 7 time.
# Word 3054 ("kullanır") appears 3 time.
# Word 3065 ("kısıtlı") appears 3 time.
# Word 3085 ("mevcut") appears 8 time.
# Word 3094 ("model") appears 2 time.
# Word 3099 ("nesne") appears 1 time.
# Word 3101 ("ngiliz") appears 5 time.
# Word 3102 ("ngilizce") appears 1 time.
# Word 3106 ("oluşturula") appears 1 time.
# Word 3107 ("oluşur") appears 6 time.
# Word 3109 ("ora") appears 3 time.
# Word 3117 ("oyun") appears 1 time.
# Word 3128 ("popü") appears 2 time.
# Word 3130 ("proje") appears 1 time.
# Word 3131 ("projes") appears 1 time.
# Word 3135 ("richardı") appears 1 time.
# Word 3144 ("sağlaya") appears 3 time.
# Word 3146 ("sembol") appears 1 time.
# Word 3154 ("sorun") appears 1 time.
# Word 3158 ("standart") appears 5 time.
# Word 3173 ("sözcük") appears 9 time.
# Word 3179 ("sınırsız") appears 2 time.
# Word 3182 ("tanım") appears 1 time.
# Word 3194 ("tür") appears 3 time.
# Word 3195 ("ulaşılabilir") appears 1 time.
# Word 3198 ("uygulama") appears 1 time.
# Word 3200 ("uzma") appears 4 time.
# Word 3209 ("yapıs") appears 1 time.
# Word 3212 ("yaygı") appears 1 time.
# Word 3223 ("çap") appears 1 time.
# Word 3230 ("özgür") appears 1 time.
# Word 3234 ("üre") appears 1 time.
# Word 3238 ("üretilmes") appears 1 time.
# Word 3240 ("ürün") appears 1 time.
# Word 3246 ("adlandırıla") appears 7 time.
# Word 3247 ("aktif") appears 1 time.
# Word 3248 ("aleksandr") appears 1 time.
# Word 3261 ("azınlık") appears 1 time.
# Word 3263 ("açık") appears 1 time.
# Word 3265 ("birleşik") appears 1 time.
# Word 3271 ("bölünme") appears 2 time.
# Word 3278 ("değişmez") appears 1 time.
# Word 3280 ("diğer") appears 3 time.
# Word 3283 ("edebilecek") appears 1 time.
# Word 3288 ("esnek") appears 1 time.
# Word 3294 ("felsefe") appears 2 time.
# Word 3295 ("fiil") appears 2 time.
# Word 3296 ("fikir") appears 3 time.
# Word 3297 ("filozof") appears 3 time.
# Word 3305 ("hazira") appears 1 time.
# Word 3312 ("işleyiş") appears 1 time.
# Word 3324 ("kendilik") appears 5 time.
# Word 3330 ("kongres") appears 1 time.
# Word 3334 ("kurulma") appears 1 time.
# Word 3372 ("sosyal") appears 7 time.
# Word 3378 ("sınıf") appears 4 time.
# Word 3384 ("temsilcis") appears 1 time.
# Word 3391 ("tutum") appears 1 time.
# Word 3404 ("yapar") appears 2 time.
# Word 3406 ("yapı") appears 11 time.
# Word 3413 ("çaba") appears 4 time.
# Word 3416 ("çerçeve") appears 5 time.
# Word 3417 ("çoğunluk") appears 1 time.
# Word 3435 ("adorno") appears 1 time.
# Word 3437 ("ajanlık") appears 1 time.
# Word 3447 ("almanya") appears 3 time.
# Word 3450 ("alınma") appears 2 time.
# Word 3456 ("amerika") appears 4 time.
# Word 3461 ("anayasal") appears 1 time.
# Word 3463 ("anlama") appears 2 time.
# Word 3464 ("anlamak") appears 1 time.
# Word 3465 ("anlamlı") appears 1 time.
# Word 3472 ("ar") appears 2 time.
# Word 3485 ("asıllı") appears 1 time.
# Word 3493 ("avusturya") appears 3 time.
# Word 3508 ("aşa") appears 1 time.
# Word 3509 ("aşağı") appears 3 time.
# Word 3514 ("bap") appears 2 time.
# Word 3526 ("başlık") appears 2 time.
# Word 3530 ("belirgi") appears 3 time.
# Word 3533 ("belirli") appears 11 time.
# Word 3536 ("belirttik") appears 1 time.
# Word 3548 ("bilim") appears 5 time.
# Word 3549 ("bilimsel") appears 8 time.
# Word 3553 ("bireysel") appears 1 time.
# Word 3558 ("biçim") appears 9 time.
# Word 3563 ("bozulma") appears 1 time.
# Word 3570 ("bulgu") appears 1 time.
# Word 3572 ("bulunur") appears 2 time.
# Word 3579 ("bölüm") appears 2 time.
# Word 3582 ("büt") appears 1 time.
# Word 3583 ("bütün") appears 1 time.
# Word 3590 ("canlılık") appears 1 time.
# Word 3605 ("cümle") appears 6 time.
# Word 3615 ("dayana") appears 1 time.
# Word 3631 ("denir") appears 1 time.
# Word 3642 ("değişim") appears 13 time.
# Word 3645 ("dikka") appears 1 time.
# Word 3660 ("dönük") appears 1 time.
# Word 3662 ("dönüşme") appears 1 time.
# Word 3667 ("düze") appears 2 time.
# Word 3674 ("düşünüle") appears 1 time.
# Word 3677 ("edilebilecek") appears 1 time.
# Word 3679 ("edip") appears 1 time.
# Word 3683 ("ediç") appears 1 time.
# Word 3688 ("ekono") appears 1 time.
# Word 3695 ("eleştir") appears 1 time.
# Word 3698 ("eleştiri") appears 2 time.
# Word 3702 ("eleştirmek") appears 1 time.
# Word 3712 ("enstitü") appears 1 time.
# Word 3713 ("enstitüs") appears 1 time.
# Word 3717 ("eriç") appears 1 time.
# Word 3722 ("etkinlik") appears 1 time.
# Word 3726 ("eyle") appears 1 time.
# Word 3727 ("eylem") appears 2 time.
# Word 3728 ("eğil") appears 3 time.
# Word 3729 ("eğilim") appears 2 time.
# Word 3736 ("farklılık") appears 8 time.
# Word 3740 ("felsefes") appears 1 time.
# Word 3746 ("form") appears 1 time.
# Word 3752 ("fransa") appears 1 time.
# Word 3753 ("fransız") appears 4 time.
# Word 3757 ("friedrich") appears 1 time.
# Word 3761 ("gaze") appears 2 time.
# Word 3764 ("geliştir") appears 2 time.
# Word 3766 ("geliştirmiş") appears 1 time.
# Word 3771 ("gerekli") appears 1 time.
# Word 3774 ("gereksiz") appears 1 time.
# Word 3777 ("gerçekleşe") appears 1 time.
# Word 3781 ("gerçeklik") appears 3 time.
# Word 3785 ("geçerli") appears 3 time.
# Word 3787 ("geçiç") appears 1 time.
# Word 3788 ("geçiş") appears 1 time.
# Word 3792 ("girer") appears 1 time.
# Word 3804 ("göreç") appears 1 time.
# Word 3806 ("görmek") appears 1 time.
# Word 3807 ("görülmes") appears 1 time.
# Word 3813 ("günlük") appears 6 time.
# Word 3814 ("güve") appears 1 time.
# Word 3825 ("has") appears 1 time.
# Word 3836 ("heinrich") appears 1 time.
# Word 3859 ("ifades") appears 2 time.
# Word 3866 ("iletiş") appears 28 time.
# Word 3870 ("ilişkil") appears 2 time.
# Word 3871 ("ilke") appears 2 time.
# Word 3872 ("ilkel") appears 1 time.
# Word 3894 ("içsel") appears 1 time.
# Word 3896 ("işlev") appears 2 time.
# Word 3916 ("kanıt") appears 2 time.
# Word 3917 ("kap") appears 1 time.
# Word 3918 ("kapasite") appears 1 time.
# Word 3919 ("kapasites") appears 1 time.
# Word 3925 ("kapsamlı") appears 1 time.
# Word 3927 ("karl") appears 1 time.
# Word 3929 ("karşılamak") appears 1 time.
# Word 3935 ("kavram") appears 4 time.
# Word 3938 ("kavramsal") appears 2 time.
# Word 3940 ("kaybı") appears 1 time.
# Word 3943 ("kaynaklana") appears 1 time.
# Word 3955 ("kitap") appears 1 time.
# Word 3969 ("konuşa") appears 9 time.
# Word 3976 ("koşul") appears 5 time.
# Word 3980 ("kullan") appears 3 time.
# Word 3982 ("kura") appears 1 time.
# Word 4000 ("kılma") appears 1 time.
# Word 4003 ("kısm") appears 4 time.
# Word 4017 ("ludwigi") appears 2 time.
# Word 4059 ("neden") appears 1 time.
# Word 4060 ("nesnel") appears 2 time.
# Word 4064 ("ngil") appears 1 time.
# Word 4074 ("normal") appears 1 time.
# Word 4075 ("not") appears 2 time.
# Word 4076 ("nsan") appears 6 time.
# Word 4082 ("okuma") appears 2 time.
# Word 4083 ("okunuş") appears 1 time.
# Word 4086 ("olgu") appears 8 time.
# Word 4087 ("olmaksız") appears 1 time.
# Word 4088 ("oluş") appears 6 time.
# Word 4094 ("oluşturur") appears 5 time.
# Word 4097 ("organizasyo") appears 1 time.
# Word 4107 ("paul") appears 2 time.
# Word 4108 ("periyodik") appears 1 time.
# Word 4114 ("planlama") appears 1 time.
# Word 4115 ("plansız") appears 1 time.
# Word 4121 ("potansiyel") appears 1 time.
# Word 4122 ("pozisyo") appears 1 time.
# Word 4124 ("pratik") appears 1 time.
# Word 4125 ("prensip") appears 1 time.
# Word 4129 ("progra") appears 3 time.
# Word 4130 ("program") appears 2 time.
# Word 4149 ("safha") appears 1 time.
# Word 4167 ("savunulmas") appears 1 time.
# Word 4168 ("sayılabilecek") appears 1 time.
# Word 4184 ("seyahat") appears 1 time.
# Word 4228 ("sıralama") appears 1 time.
# Word 4232 ("talya") appears 1 time.
# Word 4234 ("tamamlandık") appears 1 time.
# Word 4236 ("tanımlaya") appears 2 time.
# Word 4245 ("tartışmal") appears 2 time.
# Word 4248 ("tartışılır") appears 1 time.
# Word 4249 ("tarzı") appears 2 time.
# Word 4262 ("teor") appears 3 time.
# Word 4263 ("teori") appears 9 time.
# Word 4264 ("teorik") appears 2 time.
# Word 4268 ("tez") appears 1 time.
# Word 4277 ("toplumsal") appears 6 time.
# Word 4283 ("u") appears 3 time.
# Word 4291 ("uyarı") appears 1 time.
# Word 4295 ("uğramas") appears 1 time.
# Word 4310 ("wilhelm") appears 3 time.
# Word 4318 ("yapa") appears 2 time.
# Word 4329 ("yayımla") appears 2 time.
# Word 4332 ("yayımlana") appears 2 time.
# Word 4344 ("yazılma") appears 1 time.
# Word 4373 ("yöntem") appears 1 time.
# Word 4375 ("yürütmek") appears 1 time.
# Word 4384 ("zih") appears 1 time.
# Word 4389 ("zorunluluk") appears 2 time.
# Word 4390 ("çabas") appears 1 time.
# Word 4391 ("çak") appears 2 time.
# Word 4402 ("çeker") appears 1 time.
# Word 4412 ("çeşit") appears 2 time.
# Word 4436 ("öz") appears 1 time.
# Word 4437 ("özgü") appears 11 time.
# Word 4438 ("özne") appears 1 time.
# Word 4439 ("öğe") appears 5 time.
# Word 4440 ("öğrenci") appears 1 time.
# Word 4445 ("üniversite") appears 1 time.
# Word 4446 ("üret") appears 1 time.
# Word 4447 ("üretile") appears 1 time.
# Word 4455 ("şair") appears 1 time.
# Word 4459 ("şiddet") appears 1 time.
# Word 4460 ("şiir") appears 1 time.
# Word 4466 ("atıl") appears 3 time.
# Word 4490 ("gerçekleşme") appears 1 time.
# Word 4501 ("gösterme") appears 1 time.
# Word 4515 ("karakter") appears 1 time.
# Word 4518 ("kuşak") appears 4 time.
# Word 4532 ("radyo") appears 1 time.
# Word 4537 ("sağ") appears 1 time.
# Word 4560 ("yönelme") appears 1 time.
# Word 4569 ("üniversites") appears 2 time.
# Word 4570 ("üretim") appears 2 time.
# Word 4571 ("üstle") appears 1 time.
# Word 4578 ("bilgis") appears 7 time.
# Word 4596 ("htiyaç") appears 1 time.
# Word 4602 ("katma") appears 1 time.
# Word 4605 ("kılavuz") appears 2 time.
# Word 4607 ("olabilir") appears 9 time.
# Word 4612 ("res") appears 1 time.
# Word 4617 ("sunar") appears 2 time.
# Word 4618 ("tasar") appears 1 time.
# Word 4678 ("başka") appears 1 time.
# Word 4689 ("belirle") appears 2 time.
# Word 4709 ("biris") appears 1 time.
# Word 4736 ("dalga") appears 1 time.
# Word 4773 ("düzenlenme") appears 2 time.
# Word 4784 ("elektronik") appears 1 time.
# Word 4788 ("engelli") appears 12 time.
# Word 4794 ("etkilemek") appears 2 time.
# Word 4796 ("etmen") appears 1 time.
# Word 4812 ("fikr") appears 1 time.
# Word 4845 ("güncel") appears 3 time.
# Word 4846 ("güneş") appears 1 time.
# Word 4849 ("güvenlik") appears 1 time.
# Word 4866 ("hizme") appears 1 time.
# Word 4916 ("kaybol") appears 2 time.
# Word 4937 ("kullanıl") appears 1 time.
# Word 4979 ("met") appears 1 time.
# Word 5029 ("oynamak") appears 1 time.
# Word 5034 ("oyuncu") appears 1 time.
# Word 5059 ("resmî") appears 6 time.
# Word 5064 ("rume") appears 1 time.
# Word 5137 ("televizyo") appears 3 time.
# Word 5155 ("tutmak") appears 1 time.
# Word 5169 ("vazgeçil") appears 1 time.
# Word 5181 ("yabancı") appears 10 time.
# Word 5192 ("yayınlamış") appears 1 time.
# Word 5194 ("yazılmak") appears 1 time.
# Word 5198 ("yenil") appears 1 time.
# Word 5203 ("yuna") appears 4 time.
# Word 5205 ("yö") appears 1 time.
# Word 5207 ("yürürlük") appears 2 time.
# Word 5215 ("çarşı") appears 1 time.
# Word 5218 ("çeyrek") appears 1 time.
# Word 5228 ("ünle") appears 1 time.
# Word 5254 ("gerektire") appears 1 time.
# Word 5289 ("metin") appears 3 time.
# Word 5290 ("obje") appears 1 time.
# Word 5291 ("olanak") appears 3 time.
# Word 5312 ("alınmas") appears 2 time.
# Word 5325 ("biyolojik") appears 1 time.
# Word 5334 ("ekip") appears 1 time.
# Word 5359 ("kraliyet") appears 2 time.
# Word 5361 ("kurs") appears 1 time.
# Word 5385 ("sonras") appears 1 time.
# Word 5387 ("sözlük") appears 3 time.
# Word 5398 ("uzmanlık") appears 4 time.
# Word 5429 ("deyiş") appears 1 time.
# Word 5436 ("edilebilmes") appears 1 time.
# Word 5444 ("gösterilme") appears 2 time.
# Word 5473 ("ngilter") appears 1 time.
# Word 5491 ("sahne") appears 1 time.
# Word 5530 ("başlangıç") appears 3 time.
# Word 5534 ("büyüyerek") appears 1 time.
# Word 5541 ("ne") appears 1 time.
# Word 5566 ("ayıra") appears 3 time.
# Word 5567 ("ayırt") appears 2 time.
# Word 5568 ("aşağıdaki") appears 2 time.
# Word 5577 ("boşluk") appears 1 time.
# Word 5590 ("düzenleye") appears 1 time.
# Word 5601 ("etke") appears 1 time.
# Word 5607 ("gereksinim") appears 2 time.
# Word 5608 ("getirir") appears 2 time.
# Word 5610 ("gidermek") appears 1 time.
# Word 5623 ("imal") appears 1 time.
# Word 5627 ("içerir") appears 1 time.
# Word 5635 ("karş") appears 1 time.
# Word 5638 ("kaydetmek") appears 1 time.
# Word 5643 ("koordinasyo") appears 1 time.
# Word 5646 ("kullanılır") appears 4 time.
# Word 5655 ("matematiksel") appears 2 time.
# Word 5662 ("okunabile") appears 1 time.
# Word 5664 ("okunma") appears 1 time.
# Word 5670 ("programla") appears 2 time.
# Word 5681 ("simge") appears 1 time.
# Word 5682 ("sinyal") appears 4 time.
# Word 5684 ("sviçre") appears 2 time.
# Word 5693 ("telefo") appears 1 time.
# Word 5706 ("world") appears 2 time.
# Word 5714 ("yürütüle") appears 1 time.
# Word 5717 ("çalışıp") appears 1 time.
# Word 5764 ("başlayarak") appears 1 time.
# Word 5795 ("elektrik") appears 1 time.
# Word 5808 ("ernst") appears 1 time.
# Word 5812 ("evre") appears 2 time.
# Word 5816 ("formül") appears 1 time.
# Word 5820 ("geliştiril") appears 2 time.
# Word 5823 ("georgu") appears 1 time.
# Word 5836 ("hâller") appears 1 time.
# Word 5840 ("ilgilenir") appears 1 time.
# Word 5870 ("konuşula") appears 10 time.
# Word 5880 ("latince") appears 2 time.
# Word 5883 ("mekanizma") appears 1 time.
# Word 5901 ("olas") appears 1 time.
# Word 5902 ("olasılık") appears 3 time.
# Word 5941 ("tanımla") appears 3 time.
# Word 5942 ("tanımlama") appears 2 time.
# Word 5943 ("teoris") appears 2 time.
# Word 5965 ("yayımlamış") appears 1 time.
# Word 5970 ("yunanis") appears 1 time.
# Word 5978 ("önce") appears 2 time.
# Word 5979 ("önerme") appears 1 time.
# Word 5989 ("alındık") appears 1 time.
# Word 5990 ("anlayış") appears 2 time.
# Word 5993 ("ayrılabilir") appears 1 time.
# Word 6000 ("birtak") appears 1 time.
# Word 6009 ("edebî") appears 1 time.
# Word 6016 ("gözlem") appears 1 time.
# Word 6021 ("hintavrup") appears 3 time.
# Word 6022 ("ilişk") appears 1 time.
# Word 6037 ("lati") appears 3 time.
# Word 6048 ("roma") appears 3 time.
# Word 6049 ("romal") appears 1 time.
# Word 6055 ("sözlü") appears 12 time.
# Word 6057 ("tanımlanmas") appears 1 time.
# Word 6060 ("tecrübe") appears 1 time.
# Word 6064 ("türemiş") appears 1 time.
# Word 6066 ("türkçes") appears 5 time.
# Word 6077 ("yapıt") appears 1 time.
# Word 6078 ("yaza") appears 1 time.
# Word 6082 ("öykü") appears 1 time.
# Word 6086 ("arthur") appears 1 time.
# Word 6106 ("kurum") appears 2 time.
# Word 6123 ("acı") appears 1 time.
# Word 6124 ("afrika") appears 2 time.
# Word 6125 ("ait") appears 1 time.
# Word 6126 ("aktar") appears 3 time.
# Word 6127 ("aktarıl") appears 1 time.
# Word 6128 ("aktarılabilir") appears 1 time.
# Word 6129 ("aktarıldık") appears 1 time.
# Word 6130 ("aktarılma") appears 1 time.
# Word 6131 ("aktarılmas") appears 1 time.
# Word 6132 ("aktarılır") appears 1 time.
# Word 6133 ("aktüel") appears 1 time.
# Word 6134 ("alet") appears 1 time.
# Word 6135 ("algol") appears 1 time.
# Word 6136 ("algılana") appears 1 time.
# Word 6137 ("algılanabilir") appears 1 time.
# Word 6138 ("algılanma") appears 1 time.
# Word 6139 ("algılayarak") appears 1 time.
# Word 6140 ("algısal") appears 2 time.
# Word 6141 ("alman") appears 1 time.
# Word 6142 ("almancas") appears 1 time.
# Word 6143 ("alçalmas") appears 1 time.
# Word 6144 ("alınabil") appears 1 time.
# Word 6145 ("alınmaz") appears 1 time.
# Word 6146 ("alıç") appears 3 time.
# Word 6147 ("alıştırma") appears 2 time.
# Word 6148 ("amaçlanıyor") appears 1 time.
# Word 6149 ("anadil") appears 4 time.
# Word 6150 ("analoji") appears 1 time.
# Word 6151 ("anayasa") appears 1 time.
# Word 6152 ("anlamlılık") appears 1 time.
# Word 6153 ("anlamsal") appears 3 time.
# Word 6154 ("anlatılmak") appears 1 time.
# Word 6155 ("anlaya") appears 1 time.
# Word 6156 ("anlayabilmek") appears 1 time.
# Word 6157 ("anlayacak") appears 1 time.
# Word 6158 ("anlayamaz") appears 1 time.
# Word 6159 ("anlaşmak") appears 2 time.
# Word 6160 ("anlaşıl") appears 1 time.
# Word 6161 ("anlaşılabilir") appears 4 time.
# Word 6162 ("anlaşılma") appears 1 time.
# Word 6163 ("anlaşılmas") appears 1 time.
# Word 6164 ("anlaşılır") appears 3 time.
# Word 6165 ("antropologu") appears 1 time.
# Word 6166 ("arabuluculuk") appears 1 time.
# Word 6167 ("aracıl") appears 1 time.
# Word 6168 ("aramiç") appears 1 time.
# Word 6169 ("araştırarak") appears 2 time.
# Word 6170 ("araştırmacıs") appears 1 time.
# Word 6171 ("arttırılabilir") appears 1 time.
# Word 6172 ("attik") appears 1 time.
# Word 6173 ("atıf") appears 1 time.
# Word 6174 ("avcı") appears 1 time.
# Word 6175 ("aydınlatma") appears 1 time.
# Word 6176 ("ayin") appears 1 time.
# Word 6177 ("aymar") appears 1 time.
# Word 6178 ("ayrılmaz") appears 1 time.
# Word 6179 ("ayrılış") appears 1 time.
# Word 6180 ("az") appears 2 time.
# Word 6181 ("azaltmak") appears 1 time.
# Word 6182 ("açar") appears 1 time.
# Word 6183 ("açıkla") appears 2 time.
# Word 6184 ("açıklamak") appears 2 time.
# Word 6185 ("açıklanabilir") appears 1 time.
# Word 6186 ("açıklaya") appears 1 time.
# Word 6187 ("açıklayıç") appears 1 time.
# Word 6188 ("açıs") appears 2 time.
# Word 6189 ("ağlama") appears 1 time.
# Word 6190 ("ağz") appears 3 time.
# Word 6191 ("aşamas") appears 1 time.
# Word 6192 ("bakıldık") appears 3 time.
# Word 6193 ("bakış") appears 5 time.
# Word 6194 ("bale") appears 3 time.
# Word 6195 ("bales") appears 1 time.
# Word 6196 ("basiç") appears 1 time.
# Word 6197 ("bastırılmas") appears 1 time.
# Word 6198 ("basım") appears 1 time.
# Word 6199 ("bazı") appears 1 time.
# Word 6200 ("bağlam") appears 3 time.
# Word 6201 ("bağlantıl") appears 2 time.
# Word 6202 ("bağlantıs") appears 1 time.
# Word 6203 ("bebeklik") appears 1 time.
# Word 6204 ("belgelendirme") appears 1 time.
# Word 6205 ("belirleme") appears 2 time.
# Word 6206 ("belirlemes") appears 1 time.
# Word 6207 ("belirleye") appears 1 time.
# Word 6208 ("belirsizlik") appears 1 time.
# Word 6209 ("belirti") appears 1 time.
# Word 6210 ("belirtilmel") appears 1 time.
# Word 6211 ("belirtilmes") appears 1 time.
# Word 6212 ("benimsemek") appears 1 time.
# Word 6213 ("benimsemes") appears 1 time.
# Word 6214 ("benlik") appears 3 time.
# Word 6215 ("benzerlik") appears 3 time.
# Word 6216 ("benzetilerek") appears 1 time.
# Word 6217 ("bildirilmes") appears 1 time.
# Word 6218 ("bildirim") appears 2 time.
# Word 6219 ("bildirir") appears 1 time.
# Word 6220 ("bilen") appears 1 time.
# Word 6221 ("bilinemez") appears 1 time.
# Word 6222 ("bilinç") appears 5 time.
# Word 6223 ("bilinçli") appears 3 time.
# Word 6224 ("bilip") appears 1 time.
# Word 6225 ("bilir") appears 1 time.
# Word 6226 ("birey") appears 3 time.
# Word 6227 ("bireysellik") appears 1 time.
# Word 6228 ("birikerek") appears 1 time.
# Word 6229 ("birikimli") appears 1 time.
# Word 6230 ("birisidir") appears 1 time.
# Word 6231 ("biyoloji") appears 1 time.
# Word 6232 ("biçimsel") appears 3 time.
# Word 6233 ("blair") appears 1 time.
# Word 6234 ("bolivya") appears 1 time.
# Word 6235 ("bosto") appears 1 time.
# Word 6236 ("bozulmas") appears 1 time.
# Word 6237 ("branice") appears 1 time.
# Word 6238 ("braniç") appears 1 time.
# Word 6239 ("breto") appears 3 time.
# Word 6240 ("brother") appears 1 time.
# Word 6241 ("bulucu") appears 1 time.
# Word 6242 ("bulundurarak") appears 1 time.
# Word 6243 ("bulundurulur") appears 1 time.
# Word 6244 ("bulunmal") appears 1 time.
# Word 6245 ("bâzı") appears 7 time.
# Word 6246 ("bö") appears 1 time.
# Word 6247 ("bölgesel") appears 3 time.
# Word 6248 ("bük") appears 1 time.
# Word 6249 ("bütünleşmes") appears 1 time.
# Word 6250 ("bütünsel") appears 1 time.
# Word 6251 ("bırakmak") appears 1 time.
# Word 6252 ("bırakılmas") appears 1 time.
# Word 6253 ("bırakır") appears 2 time.
# Word 6254 ("cami") appears 1 time.
# Word 6255 ("canlandırmak") appears 1 time.
# Word 6256 ("canlanma") appears 2 time.
# Word 6257 ("chien") appears 1 time.
# Word 6258 ("cinsiyet") appears 1 time.
# Word 6259 ("cinsiyetçi") appears 2 time.
# Word 6260 ("computer") appears 1 time.
# Word 6261 ("cornwall") appears 1 time.
# Word 6262 ("daktilo") appears 1 time.
# Word 6263 ("danimarka") appears 2 time.
# Word 6264 ("dans") appears 5 time.
# Word 6265 ("dayanmak") appears 1 time.
# Word 6266 ("dayanır") appears 3 time.
# Word 6267 ("dağcı") appears 1 time.
# Word 6268 ("destekliyor") appears 1 time.
# Word 6269 ("deyim") appears 1 time.
# Word 6270 ("değişir") appears 2 time.
# Word 6271 ("değişkenlik") appears 2 time.
# Word 6272 ("değişmek") appears 1 time.
# Word 6273 ("değişmes") appears 2 time.
# Word 6274 ("değişmezlik") appears 1 time.
# Word 6275 ("değiştirir") appears 1 time.
# Word 6276 ("di") appears 1 time.
# Word 6277 ("dikkatli") appears 1 time.
# Word 6278 ("dilsel") appears 17 time.
# Word 6279 ("dilsiz") appears 5 time.
# Word 6280 ("dinleyici") appears 2 time.
# Word 6281 ("dinleyiç") appears 7 time.
# Word 6282 ("diyalekt") appears 1 time.
# Word 6283 ("dizim") appears 2 time.
# Word 6284 ("diş") appears 2 time.
# Word 6285 ("dokunma") appears 1 time.
# Word 6286 ("dola") appears 1 time.
# Word 6287 ("donör") appears 1 time.
# Word 6288 ("doğar") appears 2 time.
# Word 6289 ("doğma") appears 1 time.
# Word 6290 ("doğmak") appears 1 time.
# Word 6291 ("doğurur") appears 1 time.
# Word 6292 ("du") appears 1 time.
# Word 6293 ("dudak") appears 6 time.
# Word 6294 ("durağa") appears 1 time.
# Word 6295 ("duruş") appears 1 time.
# Word 6296 ("duyar") appears 1 time.
# Word 6297 ("duymadık") appears 1 time.
# Word 6298 ("duymaya") appears 4 time.
# Word 6299 ("duyul") appears 1 time.
# Word 6300 ("dâhil") appears 1 time.
# Word 6301 ("dönüşür") appears 1 time.
# Word 6302 ("dürtü") appears 1 time.
# Word 6303 ("düsseldorf") appears 1 time.
# Word 6304 ("düzeltil") appears 1 time.
# Word 6305 ("düzeltme") appears 3 time.
# Word 6306 ("düzeltmek") appears 1 time.
# Word 6307 ("düzenlenir") appears 1 time.
# Word 6308 ("düzenlenmemiş") appears 1 time.
# Word 6309 ("düzenlilik") appears 1 time.
# Word 6310 ("düzensizlik") appears 2 time.
# Word 6311 ("düzyaz") appears 1 time.
# Word 6312 ("düşünsel") appears 2 time.
# Word 6313 ("düşünülemez") appears 1 time.
# Word 6314 ("düşürme") appears 1 time.
# Word 6315 ("ebeveyn") appears 1 time.
# Word 6316 ("edebilmek") appears 1 time.
# Word 6317 ("edilebilir") appears 4 time.
# Word 6318 ("edilmemiş") appears 1 time.
# Word 6319 ("edilmez") appears 1 time.
# Word 6320 ("edin") appears 2 time.
# Word 6321 ("eklenerek") appears 1 time.
# Word 6322 ("elfçe") appears 1 time.
# Word 6323 ("elips") appears 1 time.
# Word 6324 ("englandı") appears 1 time.
# Word 6325 ("esna") appears 1 time.
# Word 6326 ("esnaf") appears 1 time.
# Word 6327 ("esperanto") appears 7 time.
# Word 6328 ("etken") appears 3 time.
# Word 6329 ("etkilendik") appears 1 time.
# Word 6330 ("etkileye") appears 1 time.
# Word 6331 ("etmedik") appears 1 time.
# Word 6332 ("etmel") appears 1 time.
# Word 6333 ("etnoloj") appears 1 time.
# Word 6334 ("eyalet") appears 3 time.
# Word 6335 ("eşanlamlı") appears 1 time.
# Word 6336 ("eşya") appears 1 time.
# Word 6337 ("eşzamanlı") appears 3 time.
# Word 6338 ("faktör") appears 1 time.
# Word 6339 ("farklılaşma") appears 1 time.
# Word 6340 ("fazlalık") appears 1 time.
# Word 6341 ("federal") appears 1 time.
# Word 6342 ("federation") appears 2 time.
# Word 6343 ("ferdinandı") appears 2 time.
# Word 6344 ("filme") appears 1 time.
# Word 6345 ("finansal") appears 1 time.
# Word 6346 ("fone") appears 2 time.
# Word 6347 ("fonetik") appears 2 time.
# Word 6348 ("fortra") appears 1 time.
# Word 6349 ("fransan") appears 1 time.
# Word 6350 ("fransızca") appears 1 time.
# Word 6351 ("fıkra") appears 2 time.
# Word 6352 ("fısıl") appears 1 time.
# Word 6353 ("gelişerek") appears 1 time.
# Word 6354 ("geliştire") appears 1 time.
# Word 6355 ("gelmez") appears 1 time.
# Word 6356 ("george") appears 3 time.
# Word 6357 ("gerekmek") appears 1 time.
# Word 6358 ("gereksin") appears 1 time.
# Word 6359 ("geril") appears 2 time.
# Word 6360 ("gerçekleşmek") appears 1 time.
# Word 6361 ("geçebilir") appears 1 time.
# Word 6362 ("große") appears 1 time.
# Word 6363 ("gurup") appears 2 time.
# Word 6364 ("göndere") appears 1 time.
# Word 6365 ("görsel") appears 4 time.
# Word 6366 ("görülebile") appears 2 time.
# Word 6367 ("görülebilir") appears 1 time.
# Word 6368 ("görülmez") appears 1 time.
# Word 6369 ("görülür") appears 2 time.
# Word 6370 ("görünüş") appears 3 time.
# Word 6371 ("gösterebilir") appears 1 time.
# Word 6372 ("gösterge") appears 9 time.
# Word 6373 ("gösterile") appears 3 time.
# Word 6374 ("gösteriyor") appears 2 time.
# Word 6375 ("gövdes") appears 2 time.
# Word 6376 ("gözle") appears 1 time.
# Word 6377 ("gözlemlene") appears 2 time.
# Word 6378 ("güneybat") appears 1 time.
# Word 6379 ("gürül") appears 1 time.
# Word 6380 ("güvence") appears 3 time.
# Word 6381 ("gırtlak") appears 2 time.
# Word 6382 ("hamburgu") appears 2 time.
# Word 6383 ("hapisha") appears 1 time.
# Word 6384 ("hareketlilik") appears 2 time.
# Word 6385 ("hareketsiz") appears 1 time.
# Word 6386 ("hartmut") appears 1 time.
# Word 6387 ("havai") appears 1 time.
# Word 6388 ("hayali") appears 1 time.
# Word 6389 ("hayva") appears 9 time.
# Word 6390 ("hazines") appears 2 time.
# Word 6391 ("hece") appears 1 time.
# Word 6392 ("heidegger") appears 1 time.
# Word 6393 ("helenis") appears 1 time.
# Word 6394 ("hesaplanabilir") appears 1 time.
# Word 6395 ("hipotez") appears 2 time.
# Word 6396 ("hissedilebilir") appears 1 time.
# Word 6397 ("hoffmann") appears 1 time.
# Word 6398 ("humboldt") appears 3 time.
# Word 6399 ("hutto") appears 1 time.
# Word 6400 ("hâkim") appears 1 time.
# Word 6401 ("hıristiyan") appears 1 time.
# Word 6402 ("iletebilir") appears 1 time.
# Word 6403 ("iletim") appears 1 time.
# Word 6404 ("iletişim") appears 1 time.
# Word 6405 ("iletişimsel") appears 4 time.
# Word 6406 ("ilgil") appears 1 time.
# Word 6407 ("imges") appears 1 time.
# Word 6408 ("imla") appears 1 time.
# Word 6409 ("imlâ") appears 3 time.
# Word 6410 ("incele") appears 1 time.
# Word 6411 ("inme") appears 1 time.
# Word 6412 ("institu") appears 1 time.
# Word 6413 ("international") appears 1 time.
# Word 6414 ("israel") appears 1 time.
# Word 6415 ("iste") appears 1 time.
# Word 6416 ("itiç") appears 1 time.
# Word 6417 ("iyileştirme") appears 2 time.
# Word 6418 ("izlenebilir") appears 1 time.
# Word 6419 ("içgüdüsel") appears 1 time.
# Word 6420 ("işitme") appears 5 time.
# Word 6421 ("jack") appears 1 time.
# Word 6422 ("jav") appears 1 time.
# Word 6423 ("jest") appears 2 time.
# Word 6424 ("kabartma") appears 1 time.
# Word 6425 ("kabulü") appears 1 time.
# Word 6426 ("kade") appears 2 time.
# Word 6427 ("kalıcılık") appears 1 time.
# Word 6428 ("kalıt") appears 6 time.
# Word 6429 ("kamusal") appears 1 time.
# Word 6430 ("kana") appears 1 time.
# Word 6431 ("kanto") appears 1 time.
# Word 6432 ("karşılaştırmal") appears 1 time.
# Word 6433 ("kattık") appears 1 time.
# Word 6434 ("kaybedilme") appears 1 time.
# Word 6435 ("kaybolma") appears 1 time.
# Word 6436 ("kaybolmas") appears 1 time.
# Word 6437 ("kaymas") appears 2 time.
# Word 6438 ("kazanmak") appears 2 time.
# Word 6439 ("kelt") appears 2 time.
# Word 6440 ("kenar") appears 1 time.
# Word 6441 ("kendis") appears 1 time.
# Word 6442 ("kesiç") appears 2 time.
# Word 6443 ("keyfi") appears 1 time.
# Word 6444 ("kim") appears 1 time.
# Word 6445 ("kiril") appears 1 time.
# Word 6446 ("kleist") appears 1 time.
# Word 6447 ("kodlama") appears 1 time.
# Word 6448 ("koin") appears 4 time.
# Word 6449 ("kolay") appears 1 time.
# Word 6450 ("kolaylaştırmak") appears 1 time.
# Word 6451 ("kombinasyo") appears 1 time.
# Word 6452 ("komisyo") appears 4 time.
# Word 6453 ("konsepti") appears 1 time.
# Word 6454 ("kontluk") appears 1 time.
# Word 6455 ("kontrolü") appears 1 time.
# Word 6456 ("konul") appears 3 time.
# Word 6457 ("konuşan") appears 1 time.
# Word 6458 ("konuşmadık") appears 1 time.
# Word 6459 ("konuşmaç") appears 13 time.
# Word 6460 ("konuştuk") appears 3 time.
# Word 6461 ("konuşulduk") appears 1 time.
# Word 6462 ("konuşuyor") appears 1 time.
# Word 6463 ("koordinel") appears 1 time.
# Word 6464 ("kopenhagı") appears 2 time.
# Word 6465 ("koreograf") appears 1 time.
# Word 6466 ("koreografi") appears 1 time.
# Word 6467 ("korkus") appears 1 time.
# Word 6468 ("korunma") appears 1 time.
# Word 6469 ("koruya") appears 1 time.
# Word 6470 ("koymuş") appears 1 time.
# Word 6471 ("kriter") appears 1 time.
# Word 6472 ("kullanamaz") appears 1 time.
# Word 6473 ("kullanmaktadıri") appears 1 time.
# Word 6474 ("kullanılmaya") appears 2 time.
# Word 6475 ("kullanılıyor") appears 1 time.
# Word 6476 ("kurgusal") appears 1 time.
# Word 6477 ("kursu") appears 2 time.
# Word 6478 ("köke") appears 4 time.
# Word 6479 ("kısıtlama") appears 1 time.
# Word 6480 ("kıyasla") appears 1 time.
# Word 6481 ("kıyaslanabilir") appears 1 time.
# Word 6482 ("language") appears 4 time.
# Word 6483 ("larinks") appears 1 time.
# Word 6484 ("lars") appears 2 time.
# Word 6485 ("lehçe") appears 7 time.
# Word 6486 ("lehçes") appears 1 time.
# Word 6487 ("letiş") appears 1 time.
# Word 6488 ("linguis") appears 2 time.
# Word 6489 ("lisa") appears 1 time.
# Word 6490 ("lisp") appears 1 time.
# Word 6491 ("lorenz") appears 1 time.
# Word 6492 ("ludwik") appears 1 time.
# Word 6493 ("luther") appears 3 time.
# Word 6494 ("malze") appears 1 time.
# Word 6495 ("mantık") appears 1 time.
# Word 6496 ("mantıkçı") appears 2 time.
# Word 6497 ("maori") appears 1 time.
# Word 6498 ("masraf") appears 1 time.
# Word 6499 ("matematikçi") appears 1 time.
# Word 6500 ("maym") appears 1 time.
# Word 6501 ("mecaz") appears 1 time.
# Word 6502 ("medeniyet") appears 1 time.
# Word 6503 ("medial") appears 1 time.
# Word 6504 ("melodis") appears 1 time.
# Word 6505 ("memeli") appears 1 time.
# Word 6506 ("mimik") appears 5 time.
# Word 6507 ("mola") appears 2 time.
# Word 6508 ("montague") appears 1 time.
# Word 6509 ("morfolojik") appears 1 time.
# Word 6510 ("mu") appears 1 time.
# Word 6511 ("müesses") appears 1 time.
# Word 6512 ("nasihat") appears 1 time.
# Word 6513 ("ncil") appears 4 time.
# Word 6514 ("nedensel") appears 1 time.
# Word 6515 ("negatif") appears 2 time.
# Word 6516 ("nes") appears 1 time.
# Word 6517 ("nietzsche") appears 1 time.
# Word 6518 ("nikaragua") appears 1 time.
# Word 6519 ("nok") appears 1 time.
# Word 6520 ("normalde") appears 1 time.
# Word 6521 ("nov") appears 1 time.
# Word 6522 ("nsanlık") appears 2 time.
# Word 6523 ("okuna") appears 1 time.
# Word 6524 ("olgus") appears 1 time.
# Word 6525 ("olmal") appears 1 time.
# Word 6526 ("olmalıdırbu") appears 1 time.
# Word 6527 ("olmaya") appears 1 time.
# Word 6528 ("olmuşturbir") appears 1 time.
# Word 6529 ("olurbir") appears 1 time.
# Word 6530 ("oluşturmadık") appears 1 time.
# Word 6531 ("oluşturulmas") appears 1 time.
# Word 6532 ("oluşturup") appears 1 time.
# Word 6533 ("omuz") appears 1 time.
# Word 6534 ("onar") appears 1 time.
# Word 6535 ("ortaçak") appears 2 time.
# Word 6536 ("orto") appears 1 time.
# Word 6537 ("orwell") appears 3 time.
# Word 6538 ("osnabrück") appears 3 time.
# Word 6539 ("otori") appears 1 time.
# Word 6540 ("paleo") appears 1 time.
# Word 6541 ("pao") appears 1 time.
# Word 6542 ("papağa") appears 1 time.
# Word 6543 ("paralel") appears 1 time.
# Word 6544 ("parlamentos") appears 1 time.
# Word 6545 ("perl") appears 1 time.
# Word 6546 ("personal") appears 1 time.
# Word 6547 ("peru") appears 1 time.
# Word 6548 ("peter") appears 1 time.
# Word 6549 ("piktogra") appears 2 time.
# Word 6550 ("politikas") appears 2 time.
# Word 6551 ("polonyal") appears 1 time.
# Word 6552 ("portekiz") appears 1 time.
# Word 6553 ("primat") appears 1 time.
# Word 6554 ("prologu") appears 1 time.
# Word 6555 ("psikologu") appears 1 time.
# Word 6556 ("puşki") appears 1 time.
# Word 6557 ("rahatsız") appears 2 time.
# Word 6558 ("referans") appears 1 time.
# Word 6559 ("repertuar") appears 1 time.
# Word 6560 ("resmetme") appears 1 time.
# Word 6561 ("retorik") appears 2 time.
# Word 6562 ("rolf") appears 2 time.
# Word 6563 ("rome") appears 1 time.
# Word 6564 ("rudi") appears 3 time.
# Word 6565 ("salla") appears 1 time.
# Word 6566 ("sani") appears 1 time.
# Word 6567 ("sanskritçe") appears 1 time.
# Word 6568 ("saussure") appears 2 time.
# Word 6569 ("sayılmak") appears 1 time.
# Word 6570 ("sağlamlaştırma") appears 1 time.
# Word 6571 ("sağlanamaz") appears 1 time.
# Word 6572 ("sağlarbu") appears 1 time.
# Word 6573 ("sağlayabilecek") appears 1 time.
# Word 6574 ("sağır") appears 4 time.
# Word 6575 ("schopenhauer") appears 1 time.
# Word 6576 ("scotia") appears 1 time.
# Word 6577 ("seferberlik") appears 1 time.
# Word 6578 ("semboliz") appears 1 time.
# Word 6579 ("sergeyeviç") appears 1 time.
# Word 6580 ("sevinç") appears 1 time.
# Word 6581 ("seviyes") appears 1 time.
# Word 6582 ("seyr") appears 1 time.
# Word 6583 ("sign") appears 4 time.
# Word 6584 ("sino") appears 1 time.
# Word 6585 ("sistematik") appears 1 time.
# Word 6586 ("sistemli") appears 2 time.
# Word 6587 ("skoçya") appears 1 time.
# Word 6588 ("somut") appears 5 time.
# Word 6589 ("sosyolojik") appears 2 time.
# Word 6590 ("soylu") appears 1 time.
# Word 6591 ("srail") appears 2 time.
# Word 6592 ("standartlaş") appears 1 time.
# Word 6593 ("statüs") appears 1 time.
# Word 6594 ("sutto") appears 7 time.
# Word 6595 ("svahil") appears 1 time.
# Word 6596 ("sömürgecilik") appears 1 time.
# Word 6597 ("söylene") appears 1 time.
# Word 6598 ("söylenecek") appears 1 time.
# Word 6599 ("söylenti") appears 1 time.
# Word 6600 ("söylev") appears 1 time.
# Word 6601 ("sözdizimsel") appears 8 time.
# Word 6602 ("sürdürmektedir") appears 1 time.
# Word 6603 ("süreklilik") appears 1 time.
# Word 6604 ("süryaniç") appears 1 time.
# Word 6605 ("sınıflandırma") appears 7 time.
# Word 6606 ("sınıflandırıla") appears 1 time.
# Word 6607 ("sınıflandırılır") appears 2 time.
# Word 6608 ("sınıflandırır") appears 1 time.
# Word 6609 ("tabu") appears 1 time.
# Word 6610 ("taklit") appears 4 time.
# Word 6611 ("talyanca") appears 1 time.
# Word 6612 ("tamamlanmamış") appears 1 time.
# Word 6613 ("tansiyo") appears 1 time.
# Word 6614 ("tanı") appears 1 time.
# Word 6615 ("tanımlanabile") appears 1 time.
# Word 6616 ("tanımlanabilir") appears 1 time.
# Word 6617 ("tanımlanır") appears 2 time.
# Word 6618 ("tanınma") appears 1 time.
# Word 6619 ("tanınmas") appears 1 time.
# Word 6620 ("taraflı") appears 1 time.
# Word 6621 ("tarafsız") appears 1 time.
# Word 6622 ("tasarlamış") appears 1 time.
# Word 6623 ("tasarlanmas") appears 1 time.
# Word 6624 ("tasarı") appears 1 time.
# Word 6625 ("taslak") appears 1 time.
# Word 6626 ("technical") appears 1 time.
# Word 6627 ("tehdidi") appears 1 time.
# Word 6628 ("tekdüzelik") appears 2 time.
# Word 6629 ("tekil") appears 1 time.
# Word 6630 ("tema") appears 1 time.
# Word 6631 ("tempo") appears 1 time.
# Word 6632 ("temsil") appears 2 time.
# Word 6633 ("terbiyes") appears 1 time.
# Word 6634 ("tercümes") appears 4 time.
# Word 6635 ("teşhis") appears 1 time.
# Word 6636 ("theater") appears 1 time.
# Word 6637 ("tipik") appears 2 time.
# Word 6638 ("tiyatro") appears 1 time.
# Word 6639 ("tiyatros") appears 1 time.
# Word 6640 ("to") appears 1 time.
# Word 6641 ("toki") appears 1 time.
# Word 6642 ("toplumsallık") appears 2 time.
# Word 6643 ("totaliter") appears 1 time.
# Word 6644 ("transkripsiyo") appears 1 time.
# Word 6645 ("tutarsızlık") appears 1 time.
# Word 6646 ("tutulur") appears 1 time.
# Word 6647 ("türeye") appears 1 time.
# Word 6648 ("tıbbî") appears 1 time.
# Word 6649 ("unutulma") appears 1 time.
# Word 6650 ("unutulmamal") appears 1 time.
# Word 6651 ("uy") appears 1 time.
# Word 6652 ("uyar") appears 1 time.
# Word 6653 ("uyarıs") appears 1 time.
# Word 6654 ("uygulamal") appears 2 time.
# Word 6655 ("uça") appears 1 time.
# Word 6656 ("uğrar") appears 1 time.
# Word 6657 ("valerie") appears 1 time.
# Word 6658 ("varoluş") appears 1 time.
# Word 6659 ("varsa") appears 1 time.
# Word 6660 ("varsay") appears 1 time.
# Word 6661 ("varsayım") appears 1 time.
# Word 6662 ("vater") appears 1 time.
# Word 6663 ("vekâlet") appears 1 time.
# Word 6664 ("verilebilir") appears 1 time.
# Word 6665 ("verilecek") appears 1 time.
# Word 6666 ("veriç") appears 1 time.
# Word 6667 ("vermeksiz") appears 1 time.
# Word 6668 ("virgül") appears 1 time.
# Word 6669 ("voltaj") appears 1 time.
# Word 6670 ("vura") appears 1 time.
# Word 6671 ("vücudu") appears 1 time.
# Word 6672 ("vücut") appears 1 time.
# Word 6673 ("yans") appears 3 time.
# Word 6674 ("yansıma") appears 1 time.
# Word 6675 ("yapay") appears 15 time.
# Word 6676 ("yapılabil") appears 1 time.
# Word 6677 ("yapılandırıl") appears 1 time.
# Word 6678 ("yapılandırıla") appears 1 time.
# Word 6679 ("yapılmak") appears 1 time.
# Word 6680 ("yapılır") appears 1 time.
# Word 6681 ("yapısal") appears 2 time.
# Word 6682 ("yararlanmas") appears 1 time.
# Word 6683 ("yaratıç") appears 1 time.
# Word 6684 ("yardım") appears 4 time.
# Word 6685 ("yayımlanmas") appears 1 time.
# Word 6686 ("yazılmas") appears 4 time.
# Word 6687 ("yaşayış") appears 1 time.
# Word 6688 ("yeni") appears 1 time.
# Word 6689 ("yeryüz") appears 2 time.
# Word 6690 ("yeterlilik") appears 1 time.
# Word 6691 ("yetişkin") appears 1 time.
# Word 6692 ("yetiştirdik") appears 1 time.
# Word 6693 ("yozlaşma") appears 2 time.
# Word 6694 ("yozlaşmas") appears 5 time.
# Word 6695 ("yunus") appears 2 time.
# Word 6696 ("yönelim") appears 1 time.
# Word 6697 ("yöresel") appears 2 time.
# Word 6698 ("yükle") appears 1 time.
# Word 6699 ("yükselmes") appears 1 time.
# Word 6700 ("yıldırmak") appears 1 time.
# Word 6701 ("zamansal") appears 3 time.
# Word 6702 ("zayıfla") appears 1 time.
# Word 6703 ("zekâsı") appears 1 time.
# Word 6704 ("zela") appears 2 time.
# Word 6705 ("zelanda") appears 1 time.
# Word 6706 ("zenginleştire") appears 1 time.
# Word 6707 ("zihinsel") appears 4 time.
# Word 6708 ("zorlaştırabilir") appears 1 time.
# Word 6709 ("zorunlu") appears 4 time.
# Word 6710 ("çalışıla") appears 1 time.
# Word 6711 ("çalışılmak") appears 1 time.
# Word 6712 ("çalışılmas") appears 1 time.
# Word 6713 ("çarpar") appears 1 time.
# Word 6714 ("çarpmak") appears 1 time.
# Word 6715 ("çekim") appears 2 time.
# Word 6716 ("çerçev") appears 3 time.
# Word 6717 ("çevirme") appears 1 time.
# Word 6718 ("çevirmen") appears 4 time.
# Word 6719 ("çeşitlilik") appears 5 time.
# Word 6720 ("çiftçi") appears 1 time.
# Word 6721 ("çokluk") appears 1 time.
# Word 6722 ("çözümlenme") appears 1 time.
# Word 6723 ("çıkabilir") appears 2 time.
# Word 6724 ("çıkarılmal") appears 1 time.
# Word 6725 ("ödünç") appears 26 time.
# Word 6726 ("öge") appears 1 time.
# Word 6727 ("önem") appears 1 time.
# Word 6728 ("öngör") appears 2 time.
# Word 6729 ("öngörür") appears 1 time.
# Word 6730 ("önle") appears 2 time.
# Word 6731 ("örneklem") appears 1 time.
# Word 6732 ("örül") appears 2 time.
# Word 6733 ("özetlene") appears 1 time.
# Word 6734 ("özürlü") appears 1 time.
# Word 6735 ("öğrenen") appears 2 time.
# Word 6736 ("öğrenilir") appears 2 time.
# Word 6737 ("öğrenilmes") appears 1 time.
# Word 6738 ("öğrenir") appears 1 time.
# Word 6739 ("öğrenmes") appears 1 time.
# Word 6740 ("öğretmen") appears 1 time.
# Word 6741 ("ünlüs") appears 1 time.
# Word 6742 ("üslup") appears 1 time.
# Word 6743 ("ı") appears 1 time.
# Word 6744 ("şaret") appears 29 time.
# Word 6745 ("şarlma") appears 1 time.
# Word 6746 ("şekille") appears 1 time.
# Word 6747 ("şi") appears 1 time.
# Word 6748 ("şitme") appears 4 time.
# Word 6749 ("şive") appears 3 time.
# Word 6750 ("şunlardırbu") appears 1 time.
# Word 6751 ("şüphel") appears 1 time.
# Word 6752 ("şüphes") appears 1 time.

# %% [markdown]
# # Saving Corpus and Dictionary

# %%
import pickle
pickle.dump(bow_corpus, open('/content/drive/MyDrive/aaa/corpus_full_data.pkl', 'wb'))
dictionary.save('/content/drive/MyDrive/aaa/dictionary_full_data.gensim')

# %% [markdown]
# # LDA Model

# %%
lda_model =  gensim.models.LdaMulticore(bow_corpus, 
                                   num_topics = 99, 
                                   id2word = dictionary,                                    
                                   passes = 10,
                                   workers = 2)
# Out:
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1023: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)

# %%
'''
For each topic, we will explore the words occuring in that topic and its relative weight
'''
for idx, topic in lda_model.print_topics(-1):
    print("Topic: {} \nWords: {}".format(idx, topic ))
    print("\n")
lda_model.save('/content/drive/MyDrive/model_99_topic.gensim')
# Out:
# Topic: 0
# Words: 0.091*"de" + 0.043*"gemi" + 0.024*"ge" + 0.020*"lima" + 0.019*"donanma" + 0.018*"filo" + 0.015*"gemis" + 0.015*"körfez" + 0.015*"sahil" + 0.015*"gem"
#
#
# Topic: 1
# Words: 0.134*"windows" + 0.086*"microsoft" + 0.076*"bulgar" + 0.040*"bulgarista" + 0.023*"sofya" + 0.022*"bulgaris" + 0.019*"edirne" + 0.018*"offiç" + 0.015*"phone" + 0.015*"sür"
#
#
# Topic: 2
# Words: 0.084*"sovyet" + 0.082*"rusya" + 0.040*"birlik" + 0.031*"gürcista" + 0.024*"cumhuriyet" + 0.022*"gürcü" + 0.019*"ukrayna" + 0.014*"moskov" + 0.013*"rusça" + 0.012*"devlet"
#
#
# Topic: 3
# Words: 0.046*"kral" + 0.019*"oğlu" + 0.015*"krallık" + 0.009*"savaş" + 0.009*"prens" + 0.009*"tah" + 0.008*"ölüm" + 0.008*"saray" + 0.008*"mparator" + 0.008*"mparatorluk"
#
#
# Topic: 4
# Words: 0.091*"bebek" + 0.074*"dahil" + 0.061*"mal" + 0.039*"takv" + 0.037*"alt" + 0.034*"kategoris" + 0.031*"atla" + 0.025*"görüntüle" + 0.025*"edil" + 0.021*"ağrı"
#
#
# Topic: 5
# Words: 0.153*"nüfus" + 0.080*"şehir" + 0.057*"eyalet" + 0.047*"şehr" + 0.046*"lçe" + 0.036*"şehri" + 0.032*"sayım" + 0.027*"yüzölç" + 0.025*"ilçes" + 0.024*"itibar"
#
#
# Topic: 6
# Words: 0.061*"kitap" + 0.046*"yazar" + 0.030*"eser" + 0.022*"dergi" + 0.021*"şiir" + 0.021*"adlı" + 0.018*"yaz" + 0.017*"roma" + 0.017*"edebiyat" + 0.011*"şair"
#
#
# Topic: 7
# Words: 0.047*"g" + 0.022*"ev" + 0.019*"aynal" + 0.018*"ay" + 0.016*"gün" + 0.012*"dük" + 0.011*"töre" + 0.010*"bayra" + 0.009*"tatil" + 0.009*"tören"
#
#
# Topic: 8
# Words: 0.011*"kullanıla" + 0.009*"malzeme" + 0.008*"parça" + 0.007*"kullanılır" + 0.007*"plastik" + 0.007*"küçük" + 0.005*"şekl" + 0.005*"çubuk" + 0.005*"kap" + 0.005*"alt"
#
#
# Topic: 9
# Words: 0.148*"alma" + 0.138*"almanya" + 0.041*"sviçre" + 0.039*"avusturya" + 0.035*"berl" + 0.030*"nazi" + 0.015*"münih" + 0.013*"set" + 0.011*"tenis" + 0.011*"bavyer"
#
#
# Topic: 10
# Words: 0.457*"ada" + 0.047*"adas" + 0.023*"a" + 0.019*"solomo" + 0.013*"girit" + 0.010*"plaj" + 0.009*"hawai" + 0.008*"rio" + 0.008*"turist" + 0.007*"adana"
#
#
# Topic: 11
# Words: 0.070*"yahudi" + 0.059*"srail" + 0.029*"arap" + 0.025*"t" + 0.025*"slam" + 0.025*"mısır" + 0.018*"müslüma" + 0.014*"arapça" + 0.012*"filis" + 0.011*"mısırlı"
#
#
# Topic: 12
# Words: 0.135*"kadı" + 0.097*"çocuk" + 0.061*"erkek" + 0.040*"kadın" + 0.039*"yaş" + 0.037*"kız" + 0.033*"kardeş" + 0.028*"aile" + 0.026*"anne" + 0.021*"evlilik"
#
#
# Topic: 13
# Words: 0.169*"japo" + 0.132*"japonya" + 0.035*"nisa" + 0.034*"tokyo" + 0.030*"mario" + 0.028*"eylül" + 0.025*"hazira" + 0.025*"mayıs" + 0.023*"temmuz" + 0.021*"ağustos"
#
#
# Topic: 14
# Words: 0.020*"anıt" + 0.018*"mezar" + 0.013*"antik" + 0.013*"taş" + 0.012*"çak" + 0.012*"tapınak" + 0.012*"yazıt" + 0.011*"heykel" + 0.009*"arkeolojik" + 0.009*"miras"
#
#
# Topic: 15
# Words: 0.011*"orta" + 0.009*"sosyal" + 0.007*"farklı" + 0.007*"in" + 0.006*"temel" + 0.006*"konu" + 0.006*"insa" + 0.005*"görüş" + 0.005*"ilişki" + 0.005*"çalışma"
#
#
# Topic: 16
# Words: 0.013*"parti" + 0.008*"devlet" + 0.008*"siyas" + 0.007*"hükûmet" + 0.007*"hareket" + 0.007*"halk" + 0.006*"komünist" + 0.006*"lider" + 0.006*"örgüt" + 0.006*"hükümet"
#
#
# Topic: 17
# Words: 0.070*"stanbul" + 0.030*"türkiye" + 0.030*"türki" + 0.012*"ankar" + 0.011*"kemal" + 0.009*"ankara" + 0.009*"mehmet" + 0.008*"ahmet" + 0.008*"mustaf" + 0.008*"atatürk"
#
#
# Topic: 18
# Words: 0.069*"bil" + 0.055*"araştırma" + 0.054*"çalışma" + 0.039*"kıbrıs" + 0.030*"fizik" + 0.025*"bilimsel" + 0.021*"alan" + 0.013*"deney" + 0.012*"kimya" + 0.012*"teori"
#
#
# Topic: 19
# Words: 0.054*"bitki" + 0.049*"ağaç" + 0.026*"toprak" + 0.025*"orma" + 0.021*"tür" + 0.017*"yaprak" + 0.017*"çiçek" + 0.011*"sap" + 0.010*"kok" + 0.008*"bahçe"
#
#
# Topic: 20
# Words: 0.113*"dil" + 0.042*"sveç" + 0.034*"yerli" + 0.031*"danimarka" + 0.028*"halk" + 0.027*"norveç" + 0.024*"grup" + 0.017*"aile" + 0.012*"asyal" + 0.011*"finlandi"
#
#
# Topic: 21
# Words: 0.034*"hastane" + 0.022*"sinir" + 0.020*"bey" + 0.019*"kalp" + 0.017*"cerrah" + 0.017*"kemik" + 0.015*"safra" + 0.014*"ka" + 0.012*"tedav" + 0.012*"kas"
#
#
# Topic: 22
# Words: 0.135*"güney" + 0.092*"kore" + 0.061*"park" + 0.061*"ulusal" + 0.056*"kuzey" + 0.043*"bayrak" + 0.033*"korel" + 0.020*"koreç" + 0.014*"resmi" + 0.012*"arma"
#
#
# Topic: 23
# Words: 0.321*"center" + 0.318*"align" + 0.051*"ora" + 0.045*"sonuç" + 0.043*"topla" + 0.042*"sayıs" + 0.034*"parti" + 0.034*"aday" + 0.025*"katıl" + 0.008*"resmî"
#
#
# Topic: 24
# Words: 0.070*"oy" + 0.027*"model" + 0.020*"motor" + 0.019*"oyun" + 0.014*"video" + 0.014*"otomobil" + 0.014*"piyasa" + 0.012*"araç" + 0.012*"oyuncu" + 0.012*"üretile"
#
#
# Topic: 25
# Words: 0.027*"muhammedi" + 0.018*"moğol" + 0.017*"ha" + 0.008*"şeyh" + 0.008*"uygur" + 0.008*"oğlu" + 0.007*"slam" + 0.006*"hasa" + 0.006*"abdullah" + 0.006*"ömer"
#
#
# Topic: 26
# Words: 0.162*"amerika" + 0.077*"york" + 0.065*"amerikal" + 0.040*"mart" + 0.022*"angeles" + 0.021*"kaliforni" + 0.021*"kas" + 0.021*"washingto" + 0.019*"kaliforniya" + 0.015*"nisa"
#
#
# Topic: 27
# Words: 0.036*"inşa" + 0.025*"bina" + 0.020*"edil" + 0.013*"duvar" + 0.013*"kale" + 0.012*"cami" + 0.010*"köprü" + 0.010*"mimar" + 0.008*"metre" + 0.008*"yapıl"
#
#
# Topic: 28
# Words: 0.095*"osmanlı" + 0.040*"paş" + 0.026*"sul" + 0.019*"stanbul" + 0.017*"mehmedi" + 0.017*"paşa" + 0.016*"devlet" + 0.012*"brah" + 0.012*"ahmedi" + 0.011*"efe"
#
#
# Topic: 29
# Words: 0.067*"yıldız" + 0.059*"galaksi" + 0.051*"keşfedil" + 0.048*"takımyıldız" + 0.044*"teleskop" + 0.044*"yön" + 0.042*"bulunur" + 0.041*"tip" + 0.038*"gökyüz" + 0.038*"çaplı"
#
#
# Topic: 30
# Words: 0.070*"alp" + 0.066*"şarkı" + 0.027*"müzik" + 0.020*"albüm" + 0.019*"liste" + 0.017*"parça" + 0.015*"şarkıç" + 0.015*"stüdyo" + 0.015*"klip" + 0.012*"video"
#
#
# Topic: 31
# Words: 0.042*"basketbol" + 0.034*"sezo" + 0.033*"sa" + 0.028*"takım" + 0.024*"tak" + 0.016*"oyuncus" + 0.015*"sezon" + 0.014*"oyuncu" + 0.013*"final" + 0.013*"profesyonel"
#
#
# Topic: 32
# Words: 0.066*"eğit" + 0.050*"öğrenci" + 0.033*"üniversites" + 0.026*"üniversite" + 0.023*"mühendislik" + 0.020*"üniversi" + 0.015*"meslek" + 0.014*"bilim" + 0.014*"sınıf" + 0.013*"kurul"
#
#
# Topic: 33
# Words: 0.036*"geçersiz" + 0.023*"karar" + 0.021*"ceza" + 0.021*"hak" + 0.018*"hukuk" + 0.018*"kan" + 0.017*"mahkeme" + 0.013*"yasa" + 0.013*"suç" + 0.011*"dava"
#
#
# Topic: 34
# Words: 0.110*"azerbayca" + 0.056*"erme" + 0.046*"ra" + 0.038*"ermenista" + 0.027*"bakü" + 0.026*"kır" + 0.023*"tatar" + 0.021*"ranlı" + 0.018*"cocacol" + 0.018*"farsça"
#
#
# Topic: 35
# Words: 0.095*"ç" + 0.075*"çi" + 0.058*"fotoğraf" + 0.042*"düze" + 0.034*"çinli" + 0.028*"kılıç" + 0.026*"hong" + 0.019*"pek" + 0.018*"us" + 0.016*"robot"
#
#
# Topic: 36
# Words: 0.016*"ışık" + 0.014*"güneş" + 0.012*"dalga" + 0.010*"hareket" + 0.009*"hız" + 0.008*"manyetik" + 0.008*"yüzey" + 0.007*"etki" + 0.006*"sinyal" + 0.006*"küçük"
#
#
# Topic: 37
# Words: 0.049*"böl" + 0.048*"kanal" + 0.039*"televizyo" + 0.034*"yay" + 0.031*"diz" + 0.025*"progra" + 0.023*"yayınlana" + 0.018*"radyo" + 0.018*"yayınla" + 0.018*"bölüm"
#
#
# Topic: 38
# Words: 0.115*"birleşik" + 0.086*"amerik" + 0.083*"devlet" + 0.045*"county" + 0.039*"ngil" + 0.024*"krallık" + 0.022*"londra" + 0.022*"ngiltere" + 0.015*"ngilter" + 0.014*"eyalet"
#
#
# Topic: 39
# Words: 0.045*"yüzyıl" + 0.022*"döne" + 0.020*"yuna" + 0.020*"dönem" + 0.016*"mparatorluk" + 0.016*"savaş" + 0.012*"önemli" + 0.011*"gün" + 0.010*"kent" + 0.009*"baş"
#
#
# Topic: 40
# Words: 0.029*"anadol" + 0.021*"konya" + 0.021*"selçuklu" + 0.017*"bey" + 0.014*"beylik" + 0.014*"gazi" + 0.013*"türkme" + 0.013*"trabzo" + 0.013*"skender" + 0.012*"be"
#
#
# Topic: 41
# Words: 0.039*"madalya" + 0.038*"şampiyona" + 0.036*"yarış" + 0.028*"avrup" + 0.024*"olimpiyat" + 0.022*"şampiyonas" + 0.020*"erkek" + 0.020*"sporcu" + 0.020*"kaza" + 0.019*"metre"
#
#
# Topic: 42
# Words: 0.093*"kar" + 0.086*"hindista" + 0.059*"evre" + 0.038*"hint" + 0.019*"delik" + 0.014*"budist" + 0.012*"varlık" + 0.010*"tibet" + 0.009*"trans" + 0.009*"döngü"
#
#
# Topic: 43
# Words: 0.096*"ülke" + 0.035*"afrik" + 0.028*"devlet" + 0.027*"asya" + 0.024*"avrup" + 0.024*"güney" + 0.023*"avustralya" + 0.021*"holla" + 0.020*"afrika" + 0.017*"kuzey"
#
#
# Topic: 44
# Words: 0.105*"uçak" + 0.095*"hav" + 0.047*"havalima" + 0.045*"uçuş" + 0.026*"havaliman" + 0.025*"uluslararas" + 0.025*"yolcu" + 0.020*"havayol" + 0.018*"pilot" + 0.018*"hizmet"
#
#
# Topic: 45
# Words: 0.049*"kulüp" + 0.042*"futbolcu" + 0.042*"millî" + 0.033*"takım" + 0.030*"kariyer" + 0.027*"tak" + 0.027*"başladı" + 0.026*"sezo" + 0.024*"futbol" + 0.023*"forma"
#
#
# Topic: 46
# Words: 0.027*"savaş" + 0.021*"silah" + 0.020*"kuvvet" + 0.017*"saldırı" + 0.015*"hit" + 0.013*"saldır" + 0.013*"savunma" + 0.013*"birlik" + 0.011*"alma" + 0.010*"tank"
#
#
# Topic: 47
# Words: 0.133*"beyaz" + 0.064*"renk" + 0.050*"siyah" + 0.047*"kırmız" + 0.036*"mavi" + 0.032*"yeşil" + 0.030*"sar" + 0.030*"ko" + 0.027*"renkli" + 0.026*"çikola"
#
#
# Topic: 48
# Words: 0.048*"yaş" + 0.046*"fransız" + 0.035*"komü" + 0.034*"öl" + 0.033*"fransa" + 0.027*"dok" + 0.022*"paris" + 0.021*"mart" + 0.017*"şubat" + 0.016*"fra"
#
#
# Topic: 49
# Words: 0.115*"maç" + 0.033*"tak" + 0.025*"final" + 0.023*"turnuva" + 0.020*"kupa" + 0.018*"şampiyo" + 0.018*"şampiyonluk" + 0.017*"kupas" + 0.014*"tur" + 0.013*"şampiyon"
#
#
# Topic: 50
# Words: 0.082*"köy" + 0.022*"erzinca" + 0.021*"kö" + 0.019*"uzaklık" + 0.014*"yerleş" + 0.013*"tar" + 0.012*"kayıt" + 0.011*"yer" + 0.010*"mahalle" + 0.010*"sınır"
#
#
# Topic: 51
# Words: 0.144*"kürt" + 0.046*"diyarbakır" + 0.046*"denizli" + 0.042*"mahalle" + 0.030*"antalya" + 0.030*"irak" + 0.030*"kütahya" + 0.023*"kürtçe" + 0.019*"aşiret" + 0.019*"balıkesir"
#
#
# Topic: 52
# Words: 0.070*"hücre" + 0.036*"protein" + 0.024*"oluştuk" + 0.021*"zincir" + 0.013*"genetik" + 0.011*"molekü" + 0.010*"grup" + 0.010*"farklı" + 0.010*"yapı" + 0.009*"canlı"
#
#
# Topic: 53
# Words: 0.022*"siste" + 0.014*"sistem" + 0.010*"dur" + 0.008*"durum" + 0.007*"farklı" + 0.006*"belirli" + 0.005*"kontrol" + 0.005*"sonuç" + 0.005*"teknik" + 0.005*"kullanıla"
#
#
# Topic: 54
# Words: 0.033*"demiryol" + 0.030*"yol" + 0.030*"tren" + 0.029*"hat" + 0.024*"zmir" + 0.021*"stasyo" + 0.019*"istasyo" + 0.014*"hizmet" + 0.013*"metro" + 0.011*"mahalle"
#
#
# Topic: 55
# Words: 0.034*"üniversites" + 0.032*"üniversite" + 0.023*"mez" + 0.018*"çalışma" + 0.017*"eğit" + 0.016*"bölüm" + 0.015*"dok" + 0.014*"çalış" + 0.013*"eğitim" + 0.013*"doktor"
#
#
# Topic: 56
# Words: 0.117*"sağlık" + 0.081*"mahalle" + 0.061*"su" + 0.057*"şebekes" + 0.047*"elektrik" + 0.046*"içme" + 0.044*"ulaş" + 0.041*"sağlaya" + 0.041*"telefo" + 0.041*"şubes"
#
#
# Topic: 57
# Words: 0.064*"grup" + 0.009*"rock" + 0.007*"liv" + 0.006*"adlı" + 0.006*"üye" + 0.005*"black" + 0.005*"metal" + 0.005*"with" + 0.004*"love" + 0.004*"üyes"
#
#
# Topic: 58
# Words: 0.124*"enerji" + 0.051*"parçacık" + 0.037*"bira" + 0.036*"nükleer" + 0.027*"elektro" + 0.026*"elektrik" + 0.024*"ato" + 0.021*"çekirdek" + 0.017*"enerjis" + 0.015*"potansiyel"
#
#
# Topic: 59
# Words: 0.137*"müzik" + 0.025*"eser" + 0.018*"oper" + 0.018*"müzisye" + 0.018*"konser" + 0.017*"sanatçı" + 0.017*"sahne" + 0.013*"besteç" + 0.013*"dans" + 0.013*"orkestra"
#
#
# Topic: 60
# Words: 0.114*"ro" + 0.039*"roma" + 0.016*"mparator" + 0.015*"romal" + 0.012*"imparator" + 0.012*"pandemis" + 0.011*"campania" + 0.011*"romalı" + 0.011*"sezar" + 0.011*"tira"
#
#
# Topic: 61
# Words: 0.342*"colspa" + 0.037*"league" + 0.026*"unitedi" + 0.024*"oyuncu" + 0.024*"city" + 0.016*"premier" + 0.014*"manchester" + 0.013*"turnuva" + 0.011*"mart" + 0.010*"concacaf"
#
#
# Topic: 62
# Words: 0.026*"dak" + 0.024*"göl" + 0.022*"kuzey" + 0.018*"güney" + 0.017*"nehri" + 0.013*"nehir" + 0.012*"sınır" + 0.011*"metre" + 0.009*"doğu" + 0.009*"dok"
#
#
# Topic: 63
# Words: 0.073*"şirket" + 0.021*"sat" + 0.016*"üret" + 0.016*"marka" + 0.014*"ürün" + 0.014*"kurul" + 0.013*"do" + 0.012*"ür" + 0.011*"markas" + 0.011*"merkezli"
#
#
# Topic: 64
# Words: 0.042*"başka" + 0.031*"seçim" + 0.030*"parti" + 0.030*"başkanlık" + 0.020*"bakanlık" + 0.019*"baka" + 0.018*"siyasetçi" + 0.017*"seç" + 0.017*"partis" + 0.017*"meclis"
#
#
# Topic: 65
# Words: 0.051*"tanrı" + 0.016*"ruh" + 0.014*"mitoloji" + 0.012*"in" + 0.012*"efsane" + 0.011*"melek" + 0.011*"tanrıs" + 0.010*"güç" + 0.009*"şeyta" + 0.008*"hikâye"
#
#
# Topic: 66
# Words: 0.025*"yemek" + 0.021*"şeker" + 0.017*"köydürköy" + 0.015*"içecek" + 0.015*"meyve" + 0.015*"mutfak" + 0.013*"gı" + 0.011*"şarap" + 0.010*"yiyecek" + 0.010*"dondurma"
#
#
# Topic: 67
# Words: 0.016*"ordu" + 0.014*"kale" + 0.014*"bizans" + 0.013*"sefer" + 0.011*"asker" + 0.010*"ordus" + 0.008*"haçlı" + 0.008*"suri" + 0.008*"savaş" + 0.007*"el"
#
#
# Topic: 68
# Words: 0.083*"ligi" + 0.063*"futbol" + 0.056*"tak" + 0.048*"kulüp" + 0.047*"spor" + 0.027*"grup" + 0.025*"mücadel" + 0.022*"stady" + 0.022*"miss" + 0.020*"univer"
#
#
# Topic: 69
# Words: 0.017*"uluslararas" + 0.017*"ülke" + 0.013*"kurul" + 0.011*"kuruluş" + 0.011*"amaç" + 0.010*"birlik" + 0.009*"hizmet" + 0.009*"proje" + 0.009*"ulusal" + 0.009*"avrup"
#
#
# Topic: 70
# Words: 0.065*"grande" + 0.049*"disney" + 0.045*"mağara" + 0.043*"da" + 0.039*"charlie" + 0.026*"mağar" + 0.025*"flori" + 0.020*"petra" + 0.020*"florida" + 0.018*"mağaras"
#
#
# Topic: 71
# Words: 0.050*"arnavutluk" + 0.038*"sırp" + 0.032*"macar" + 0.030*"makedonya" + 0.028*"yugoslavya" + 0.027*"arnavut" + 0.026*"karadak" + 0.025*"yunanis" + 0.023*"cumhuriyet" + 0.023*"macaris"
#
#
# Topic: 72
# Words: 0.030*"formula_" + 0.019*"değer" + 0.012*"fonksiyo" + 0.011*"sayı" + 0.010*"ifa" + 0.009*"bir" + 0.009*"nokta" + 0.008*"denklem" + 0.008*"sa" + 0.007*"denkle"
#
#
# Topic: 73
# Words: 0.026*"hastalık" + 0.010*"ilaç" + 0.010*"etki" + 0.010*"koronavirüs" + 0.009*"sağlık" + 0.009*"hasta" + 0.007*"tedav" + 0.007*"bozukluk" + 0.006*"orta" + 0.006*"virüs"
#
#
# Topic: 74
# Words: 0.017*"kemer" + 0.012*"john" + 0.011*"amerikal" + 0.009*"michael" + 0.008*"james" + 0.008*"etkinlik" + 0.007*"davidi" + 0.006*"güreşçi" + 0.006*"peter" + 0.006*"jack"
#
#
# Topic: 75
# Words: 0.083*"estonya" + 0.081*"kura" + 0.048*"ker" + 0.032*"la" + 0.019*"rahma" + 0.019*"klan" + 0.015*"arian" + 0.014*"esto" + 0.011*"pa" + 0.011*"sure"
#
#
# Topic: 76
# Words: 0.570*"ek" + 0.089*"ma" + 0.036*"romanya" + 0.017*"rume" + 0.013*"fiil" + 0.010*"pur" + 0.010*"cümle" + 0.010*"asla" + 0.008*"hele" + 0.008*"kelebek"
#
#
# Topic: 77
# Words: 0.054*"tür" + 0.018*"hayva" + 0.016*"diş" + 0.015*"balık" + 0.013*"kuş" + 0.013*"köpek" + 0.011*"hayvan" + 0.010*"küçük" + 0.009*"cins" + 0.009*"familya"
#
#
# Topic: 78
# Words: 0.198*"saat" + 0.047*"bar" + 0.045*"blok" + 0.029*"mil" + 0.027*"dakik" + 0.026*"çelik" + 0.017*"üçge" + 0.017*"kenar" + 0.016*"saatler" + 0.016*"köşe"
#
#
# Topic: 79
# Words: 0.022*"madde" + 0.019*"kimyasal" + 0.017*"asit" + 0.013*"gaz" + 0.013*"bileşik" + 0.011*"sıv" + 0.011*"sıcaklık" + 0.010*"karbo" + 0.009*"organik" + 0.009*"reaksiyo"
#
#
# Topic: 80
# Words: 0.014*"bilgisayar" + 0.013*"kullanıç" + 0.013*"yazıl" + 0.012*"cihaz" + 0.011*"uygulama" + 0.008*"özellik" + 0.008*"kullanıcı" + 0.008*"hizmet" + 0.008*"sistem" + 0.007*"ver"
#
#
# Topic: 81
# Words: 0.092*"yarışma" + 0.076*"şarkı" + 0.059*"final" + 0.033*"eurovision" + 0.025*"ülke" + 0.020*"puan" + 0.016*"adlı" + 0.015*"sıra" + 0.014*"katılımcı" + 0.013*"mayıs"
#
#
# Topic: 82
# Words: 0.029*"pos" + 0.022*"noel" + 0.022*"norma" + 0.016*"pul" + 0.013*"abraha" + 0.012*"ayna" + 0.011*"leonardo" + 0.011*"post" + 0.010*"kafka" + 0.009*"kano"
#
#
# Topic: 83
# Words: 0.083*"spanya" + 0.070*"polonya" + 0.060*"spanyol" + 0.039*"meksika" + 0.027*"portekiz" + 0.021*"portek" + 0.020*"polonyal" + 0.020*"madridi" + 0.015*"ülke" + 0.014*"tunus"
#
#
# Topic: 84
# Words: 0.095*"savaş" + 0.050*"asker" + 0.024*"kuvvet" + 0.018*"sıra" + 0.018*"ordu" + 0.016*"esir" + 0.012*"komuta" + 0.011*"komutanlık" + 0.009*"rütbe" + 0.008*"işgal"
#
#
# Topic: 85
# Words: 0.079*"mo" + 0.077*"stil" + 0.046*"carl" + 0.035*"şekerle" + 0.027*"lisa" + 0.024*"maske" + 0.019*"kuk" + 0.019*"rüya" + 0.017*"re" + 0.017*"gölge"
#
#
# Topic: 86
# Words: 0.082*"kilise" + 0.052*"kilis" + 0.047*"kilises" + 0.035*"manastır" + 0.032*"aziz" + 0.028*"katolik" + 0.025*"yüzyıl" + 0.025*"hristiya" + 0.022*"ortodoks" + 0.017*"katedral"
#
#
# Topic: 87
# Words: 0.085*"uzay" + 0.045*"araç" + 0.035*"roket" + 0.024*"gezege" + 0.020*"yörünge" + 0.018*"u" + 0.017*"mar" + 0.016*"mars" + 0.014*"fırlatma" + 0.013*"uçuş"
#
#
# Topic: 88
# Words: 0.055*"brezilya" + 0.036*"brezilyal" + 0.026*"arjant" + 0.016*"meksikal" + 0.014*"meksika" + 0.014*"carlos" + 0.014*"arjantinli" + 0.012*"lat" + 0.012*"josé" + 0.012*"santos"
#
#
# Topic: 89
# Words: 0.106*"bilgi" + 0.065*"site" + 0.044*"sayfa" + 0.036*"met" + 0.033*"internet" + 0.031*"sites" + 0.024*"içerik" + 0.023*"si" + 0.022*"başlık" + 0.011*"listele"
#
#
# Topic: 90
# Words: 0.010*"eder" + 0.009*"baş" + 0.008*"arkadaş" + 0.006*"hayat" + 0.006*"sıra" + 0.005*"olay" + 0.005*"yer" + 0.004*"an" + 0.004*"etme" + 0.004*"ev"
#
#
# Topic: 91
# Words: 0.106*"film" + 0.044*"oyuncu" + 0.031*"filmi" + 0.021*"sinema" + 0.021*"tiyatro" + 0.018*"karakter" + 0.015*"yönetme" + 0.013*"adlı" + 0.012*"televizyo" + 0.012*"dizi"
#
#
# Topic: 92
# Words: 0.359*"talya" + 0.225*"kom" + 0.055*"listes" + 0.043*"venedik" + 0.016*"napoli" + 0.015*"milano" + 0.014*"sicilya" + 0.011*"palm" + 0.011*"giovanni" + 0.011*"toska"
#
#
# Topic: 93
# Words: 0.164*"meyda" + 0.072*"depre" + 0.040*"gele" + 0.036*"şil" + 0.035*"peru" + 0.032*"çanakkale" + 0.027*"meridye" + 0.023*"hershey" + 0.019*"p" + 0.017*"ekvador"
#
#
# Topic: 94
# Words: 0.255*"ödül" + 0.060*"adaylık" + 0.040*"kaza" + 0.039*"aday" + 0.028*"festival" + 0.022*"dal" + 0.021*"akade" + 0.020*"gösteril" + 0.020*"uluslararas" + 0.018*"layık"
#
#
# Topic: 95
# Words: 0.131*"anlam" + 0.041*"anla" + 0.035*"kelime" + 0.032*"soyad" + 0.032*"ismi" + 0.030*"türkçe" + 0.027*"sözcük" + 0.025*"aşağı" + 0.023*"ter" + 0.022*"kullanıla"
#
#
# Topic: 96
# Words: 0.121*"kana" + 0.109*"kanada" + 0.095*"bur" + 0.075*"kanadal" + 0.030*"toronto" + 0.030*"batma" + 0.025*"ontario" + 0.024*"montreal" + 0.019*"elmas" + 0.018*"ubisoft"
#
#
# Topic: 97
# Words: 0.087*"sanat" + 0.034*"res" + 0.032*"eser" + 0.024*"sanatçı" + 0.023*"müze" + 0.021*"sergi" + 0.018*"müzes" + 0.018*"çalışma" + 0.016*"tablo" + 0.015*"müz"
#
#
# Topic: 98
# Words: 0.071*"dövüş" + 0.038*"hugo" + 0.029*"payne" + 0.029*"mori" + 0.023*"heinz" + 0.015*"karate" + 0.013*"luka" + 0.012*"minnesota" + 0.012*"cass" + 0.011*"büyükustas"

# %% [markdown]
# # Testing Unseen Text

# %%
unseen_document = "Farklı tarzda bir şey izlemek istersen Tarantino'nun yapıtlarına bakabilirsin. Aldığı ödülleri gerçekten de hak ediyor."
unseen_document = re.sub(r'[^\w\s]','',unseen_document)

unseen_sentence=""
for i in unseen_document.split():
  if (i not in stop_word_list and len(i)>=3):
    i=lemmatize_stemming(i)
    unseen_sentence=unseen_sentence+" "+i
  else:
    pass
print(unseen_sentence)

# Data preprocessing step for the unseen document
bow_vector = dictionary.doc2bow(preprocess(unseen_sentence))

for index, score in sorted(lda_model[bow_vector], key=lambda tup: -1*tup[1]):
    if(score>0.1):
      print("Score: {}\t Topic: {}".format(score, lda_model.print_topic(index, 100)))
# Out:
#  Farklı tarz izlemek ister Tarantino yapıt bakabilir Aldık ödül hak
# Score: 0.2728349566459656	 Topic: 0.087*"sanat" + 0.034*"res" + 0.032*"eser" + 0.024*"sanatçı" + 0.023*"müze" + 0.021*"sergi" + 0.018*"müzes" + 0.018*"çalışma" + 0.016*"tablo" + 0.015*"müz" + 0.012*"resim" + 0.009*"mimar" + 0.009*"heykel" + 0.008*"koleksiyo" + 0.007*"mimarlık" + 0.007*"dali" + 0.007*"figür" + 0.006*"tasar" + 0.006*"önemli" + 0.006*"koleksiyon" + 0.006*"gogh" + 0.006*"portre" + 0.006*"döne" + 0.006*"atölye" + 0.005*"modern" + 0.005*"çiz" + 0.005*"çağdaş" + 0.005*"fotoğraf" + 0.005*"ressa" + 0.004*"sanatçıs" + 0.004*"galeri" + 0.004*"kül" + 0.004*"resmi" + 0.004*"kişisel" + 0.004*"akademi" + 0.004*"galeris" + 0.004*"çizim" + 0.004*"sanatsal" + 0.003*"görsel" + 0.003*"ulusal" + 0.003*"heykeltıraş" + 0.003*"başladı" + 0.003*"sergis" + 0.003*"teknik" + 0.003*"bella" + 0.003*"paris" + 0.003*"fuar" + 0.003*"resm" + 0.003*"grafik" + 0.003*"ünlü" + 0.003*"adlı" + 0.003*"tasarımcı" + 0.003*"tasarım" + 0.003*"tasarımcıs" + 0.003*"ga" + 0.003*"aç" + 0.003*"sergile" + 0.003*"kabul" + 0.003*"minyatür" + 0.003*"yapıt" + 0.003*"seramik" + 0.003*"bo" + 0.003*"tema" + 0.003*"özel" + 0.002*"çeşitli" + 0.002*"tarz" + 0.002*"peyzaj" + 0.002*"niko" + 0.002*"gör" + 0.002*"yapma" + 0.002*"ilgi" + 0.002*"ya" + 0.002*"alan" + 0.002*"akım" + 0.002*"yağlı" + 0.002*"çalış" + 0.002*"akademis" + 0.002*"tasvir" + 0.002*"sahne" + 0.002*"sergilene" + 0.002*"eğit" + 0.002*"ler" + 0.002*"deva" + 0.002*"ön" + 0.002*"ver" + 0.002*"stil" + 0.002*"örnek" + 0.002*"ziyaretçi" + 0.002*"geleneksel" + 0.002*"proje" + 0.002*"baskı" + 0.002*"ilha" + 0.002*"ressam" + 0.002*"tablos" + 0.002*"dönem" + 0.002*"gele" + 0.002*"museum" + 0.002*"katıl" + 0.002*"sayı" + 0.002*"salon"
# Score: 0.24346616864204407	 Topic: 0.010*"eder" + 0.009*"baş" + 0.008*"arkadaş" + 0.006*"hayat" + 0.006*"sıra" + 0.005*"olay" + 0.005*"yer" + 0.004*"an" + 0.004*"etme" + 0.004*"ev" + 0.004*"kendi" + 0.004*"olma" + 0.004*"doktor" + 0.004*"karar" + 0.004*"söy" + 0.004*"yol" + 0.004*"kiş" + 0.004*"yar" + 0.004*"verir" + 0.004*"orta" + 0.003*"gelir" + 0.003*"sür" + 0.003*"el" + 0.003*"etmek" + 0.003*"karakter" + 0.003*"öl" + 0.003*"deva" + 0.003*"gerçek" + 0.003*"olduk" + 0.003*"gider" + 0.003*"çıkar" + 0.003*"bir" + 0.003*"çalışır" + 0.003*"ister" + 0.003*"dur" + 0.003*"fark" + 0.003*"alır" + 0.002*"yan" + 0.002*"istedik" + 0.002*"zor" + 0.002*"geldik" + 0.002*"ada" + 0.002*"on" + 0.002*"gele" + 0.002*"iş" + 0.002*"olacak" + 0.002*"olmadık" + 0.002*"yapma" + 0.002*"iz" + 0.002*"hikâye" + 0.002*"göz" + 0.002*"kız" + 0.002*"polis" + 0.002*"birbir" + 0.002*"yapar" + 0.002*"iç" + 0.002*"böl" + 0.002*"genç" + 0.002*"baba" + 0.002*"kabul" + 0.002*"terk" + 0.002*"verdik" + 0.002*"kala" + 0.002*"oda" + 0.002*"teklif" + 0.002*"konu" + 0.002*"sebep" + 0.002*"ardı" + 0.002*"yolculuk" + 0.002*"yak" + 0.002*"yaşadık" + 0.002*"aile" + 0.002*"ol" + 0.002*"döner" + 0.002*"üzer" + 0.002*"arka" + 0.002*"bulur" + 0.002*"kardeş" + 0.002*"ölüm" + 0.002*"görür" + 0.002*"haber" + 0.002*"aşık" + 0.002*"girer" + 0.002*"gelecek" + 0.002*"kalır" + 0.002*"ver" + 0.002*"küçük" + 0.001*"et" + 0.001*"gör" + 0.001*"cinayet" + 0.001*"konuşma" + 0.001*"takip" + 0.001*"alt" + 0.001*"hal" + 0.001*"ön" + 0.001*"karşı" + 0.001*"gördük" + 0.001*"söyledi" + 0.001*"in" + 0.001*"çocuk"
# Score: 0.14071816205978394	 Topic: 0.255*"ödül" + 0.060*"adaylık" + 0.040*"kaza" + 0.039*"aday" + 0.028*"festival" + 0.022*"dal" + 0.021*"akade" + 0.020*"gösteril" + 0.020*"uluslararas" + 0.018*"layık" + 0.015*"kategori" + 0.015*"verile" + 0.015*"görül" + 0.013*"pepsi" + 0.011*"kazana" + 0.010*"töre" + 0.009*"onur" + 0.008*"düzenlene" + 0.008*"kadı" + 0.008*"yabancı" + 0.007*"veril" + 0.007*"kür" + 0.006*"akademis" + 0.006*"eleştirmen" + 0.005*"başar" + 0.005*"seçil" + 0.005*"kapsam" + 0.005*"dernek" + 0.005*"performansı" + 0.004*"grammy" + 0.004*"oscar" + 0.004*"yardımcı" + 0.004*"kazanan" + 0.004*"tören" + 0.004*"gösterile" + 0.004*"verilmek" + 0.004*"nobel" + 0.003*"kazandık" + 0.003*"oslo" + 0.003*"clair" + 0.003*"jüri" + 0.003*"erkek" + 0.003*"awards" + 0.003*"anket" + 0.003*"ya" + 0.003*"liste" + 0.003*"nino" + 0.003*"forza" + 0.003*"brit" + 0.002*"bilim" + 0.002*"seç" + 0.002*"şubat" + 0.002*"bo" + 0.002*"değer" + 0.002*"ol" + 0.002*"kişi" + 0.002*"ulusal" + 0.002*"verilme" + 0.002*"takdı" + 0.002*"pulitzer" + 0.002*"verilir" + 0.002*"awardı" + 0.002*"aralık" + 0.002*"nisa" + 0.002*"ödüllü" + 0.002*"özel" + 0.002*"başarı" + 0.002*"akademi" + 0.002*"kiş" + 0.002*"yıllık" + 0.002*"dağıtıla" + 0.002*"yenilebilir" + 0.002*"biseksüel" + 0.002*"nina" + 0.002*"el" + 0.002*"prestijli" + 0.002*"satılıyor" + 0.002*"madalyas" + 0.002*"tatlandırıç" + 0.002*"üs" + 0.002*"dergis" + 0.001*"aliso" + 0.001*"ömür" + 0.001*"kaptık" + 0.001*"farklı" + 0.001*"yazar" + 0.001*"sunula" + 0.001*"katkı" + 0.001*"açıkla" + 0.001*"aşağı" + 0.001*"aro" + 0.001*"genç" + 0.001*"foster" + 0.001*"belirlene" + 0.001*"grey" + 0.001*"kategor" + 0.001*"performans" + 0.001*"çeşitli" + 0.001*"mart" + 0.001*"ödüllendiril"
# Score: 0.12524783611297607	 Topic: 0.106*"film" + 0.044*"oyuncu" + 0.031*"filmi" + 0.021*"sinema" + 0.021*"tiyatro" + 0.018*"karakter" + 0.015*"yönetme" + 0.013*"adlı" + 0.012*"televizyo" + 0.012*"dizi" + 0.012*"oyunculuk" + 0.011*"aldık" + 0.010*"yönetmenlik" + 0.009*"rol" + 0.009*"yapım" + 0.008*"dizis" + 0.008*"sahne" + 0.008*"rolü" + 0.007*"canlandırdık" + 0.007*"senaryo" + 0.007*"festival" + 0.007*"başrol" + 0.007*"komedi" + 0.006*"yönettik" + 0.006*"diz" + 0.005*"göster" + 0.005*"kariyer" + 0.005*"oyuncus" + 0.005*"oy" + 0.004*"oyun" + 0.004*"aktör" + 0.004*"senarist" + 0.004*"yapımcı" + 0.004*"dra" + 0.004*"oynadık" + 0.003*"çekim" + 0.003*"tür" + 0.003*"amerikal" + 0.003*"vizyo" + 0.003*"sanatçıs" + 0.003*"sayılabilir" + 0.003*"belgesel" + 0.003*"oynadı" + 0.003*"ta" + 0.003*"çek" + 0.003*"yapımcıs" + 0.003*"roller" + 0.003*"isimli" + 0.003*"canlandır" + 0.003*"aktris" + 0.003*"seslendirme" + 0.003*"yazar" + 0.003*"yazdık" + 0.003*"ünlü" + 0.003*"tiyatros" + 0.003*"animasyo" + 0.003*"dok" + 0.003*"cannes" + 0.003*"eylül" + 0.002*"yapımcılık" + 0.002*"komedye" + 0.002*"başroller" + 0.002*"mart" + 0.002*"dram" + 0.002*"gir" + 0.002*"oynamış" + 0.002*"sanat" + 0.002*"deva" + 0.002*"paylaştık" + 0.002*"üstlendik" + 0.002*"özgü" + 0.002*"çekile" + 0.002*"başladı" + 0.002*"müzikal" + 0.002*"ağustos" + 0.002*"yönetile" + 0.002*"gör" + 0.002*"mayıs" + 0.002*"ko" + 0.002*"yıldız" + 0.002*"senaristlik" + 0.002*"nisa" + 0.002*"metrajlı" + 0.002*"kadı" + 0.002*"aralık" + 0.002*"şubat" + 0.002*"yardımcı" + 0.002*"çıkışlı" + 0.002*"hazira" + 0.002*"roman" + 0.002*"korku" + 0.002*"kadro" + 0.002*"çekil" + 0.002*"şarkıç" + 0.002*"sanatçı" + 0.002*"uyarla" + 0.002*"hayat" + 0.002*"temmuz" + 0.002*"aksiyo" + 0.002*"almak"
# Score: 0.11223343759775162	 Topic: 0.106*"bilgi" + 0.065*"site" + 0.044*"sayfa" + 0.036*"met" + 0.033*"internet" + 0.031*"sites" + 0.024*"içerik" + 0.023*"si" + 0.022*"başlık" + 0.011*"listele" + 0.010*"facebook" + 0.010*"http" + 0.010*"hatay" + 0.008*"vikipedi" + 0.008*"yu" + 0.008*"kaynakça" + 0.008*"madde" + 0.007*"belge" + 0.007*"gmbh" + 0.007*"link" + 0.007*"sayfas" + 0.007*"metn" + 0.007*"çevir" + 0.006*"https" + 0.006*"resmi" + 0.006*"blog" + 0.005*"reviz" + 0.005*"index" + 0.005*"blogu" + 0.005*"isbn" + 0.005*"yor" + 0.005*"alfabetik" + 0.005*"editör" + 0.005*"bosch" + 0.005*"bulunmak" + 0.005*"sevi" + 0.005*"metni" + 0.005*"metin" + 0.005*"alpha" + 0.005*"eriş" + 0.004*"ngiliz" + 0.004*"sür" + 0.004*"kaynak" + 0.004*"çerik" + 0.003*"makale" + 0.003*"inceleme" + 0.003*"sayı" + 0.003*"expression" + 0.003*"confere" + 0.003*"wep" + 0.003*"barındırmak" + 0.003*"wikipedia" + 0.003*"rehber" + 0.003*"kayıtlı" + 0.003*"çevirme" + 0.003*"şifreleme" + 0.003*"revizyo" + 0.003*"eastern" + 0.003*"ayrıntıl" + 0.003*"pages" + 0.003*"ümraniyespor" + 0.003*"book" + 0.003*"zümrüt" + 0.002*"change" + 0.002*"ingiliz" + 0.002*"geçerli" + 0.002*"ziyaretçi" + 0.002*"haritala" + 0.002*"touringi" + 0.002*"page" + 0.002*"core" + 0.002*"versiyo" + 0.002*"sint" + 0.002*"görüntülenir" + 0.002*"çevr" + 0.002*"doküma" + 0.002*"groupe" + 0.002*"ziyaret" + 0.002*"agency" + 0.002*"çıktıs" + 0.002*"dolgus" + 0.002*"publishers" + 0.002*"çeviris" + 0.002*"işaretle" + 0.002*"argı" + 0.002*"oluşturul" + 0.002*"snlik" + 0.002*"chiro" + 0.002*"maddes" + 0.002*"level" + 0.002*"basılarak" + 0.002*"medea" + 0.002*"etiket" + 0.002*"almaya" + 0.002*"lave" + 0.002*"ansiklopedi" + 0.002*"grid" + 0.002*"creativ" + 0.002*"wik" + 0.002*"nterne"

# %%
# Data preprocessing step for the unseen document
bow_vector = dictionary.doc2bow(preprocess(unseen_sentence))

for index, score in sorted(lda_model[bow_vector], key=lambda tup: -1*tup[1]):
    if(score>0.1):
      print("Score: {}\t Topic: {}".format(score, lda_model.print_topic(index, 100)))
# Out:
# Score: 0.27289173007011414	 Topic: 0.087*"sanat" + 0.034*"res" + 0.032*"eser" + 0.024*"sanatçı" + 0.023*"müze" + 0.021*"sergi" + 0.018*"müzes" + 0.018*"çalışma" + 0.016*"tablo" + 0.015*"müz" + 0.012*"resim" + 0.009*"mimar" + 0.009*"heykel" + 0.008*"koleksiyo" + 0.007*"mimarlık" + 0.007*"dali" + 0.007*"figür" + 0.006*"tasar" + 0.006*"önemli" + 0.006*"koleksiyon" + 0.006*"gogh" + 0.006*"portre" + 0.006*"döne" + 0.006*"atölye" + 0.005*"modern" + 0.005*"çiz" + 0.005*"çağdaş" + 0.005*"fotoğraf" + 0.005*"ressa" + 0.004*"sanatçıs" + 0.004*"galeri" + 0.004*"kül" + 0.004*"resmi" + 0.004*"kişisel" + 0.004*"akademi" + 0.004*"galeris" + 0.004*"çizim" + 0.004*"sanatsal" + 0.003*"görsel" + 0.003*"ulusal" + 0.003*"heykeltıraş" + 0.003*"başladı" + 0.003*"sergis" + 0.003*"teknik" + 0.003*"bella" + 0.003*"paris" + 0.003*"fuar" + 0.003*"resm" + 0.003*"grafik" + 0.003*"ünlü" + 0.003*"adlı" + 0.003*"tasarımcı" + 0.003*"tasarım" + 0.003*"tasarımcıs" + 0.003*"ga" + 0.003*"aç" + 0.003*"sergile" + 0.003*"kabul" + 0.003*"minyatür" + 0.003*"yapıt" + 0.003*"seramik" + 0.003*"bo" + 0.003*"tema" + 0.003*"özel" + 0.002*"çeşitli" + 0.002*"tarz" + 0.002*"peyzaj" + 0.002*"niko" + 0.002*"gör" + 0.002*"yapma" + 0.002*"ilgi" + 0.002*"ya" + 0.002*"alan" + 0.002*"akım" + 0.002*"yağlı" + 0.002*"çalış" + 0.002*"akademis" + 0.002*"tasvir" + 0.002*"sahne" + 0.002*"sergilene" + 0.002*"eğit" + 0.002*"ler" + 0.002*"deva" + 0.002*"ön" + 0.002*"ver" + 0.002*"stil" + 0.002*"örnek" + 0.002*"ziyaretçi" + 0.002*"geleneksel" + 0.002*"proje" + 0.002*"baskı" + 0.002*"ilha" + 0.002*"ressam" + 0.002*"tablos" + 0.002*"dönem" + 0.002*"gele" + 0.002*"museum" + 0.002*"katıl" + 0.002*"sayı" + 0.002*"salon"
# Score: 0.2474854737520218	 Topic: 0.010*"eder" + 0.009*"baş" + 0.008*"arkadaş" + 0.006*"hayat" + 0.006*"sıra" + 0.005*"olay" + 0.005*"yer" + 0.004*"an" + 0.004*"etme" + 0.004*"ev" + 0.004*"kendi" + 0.004*"olma" + 0.004*"doktor" + 0.004*"karar" + 0.004*"söy" + 0.004*"yol" + 0.004*"kiş" + 0.004*"yar" + 0.004*"verir" + 0.004*"orta" + 0.003*"gelir" + 0.003*"sür" + 0.003*"el" + 0.003*"etmek" + 0.003*"karakter" + 0.003*"öl" + 0.003*"deva" + 0.003*"gerçek" + 0.003*"olduk" + 0.003*"gider" + 0.003*"çıkar" + 0.003*"bir" + 0.003*"çalışır" + 0.003*"ister" + 0.003*"dur" + 0.003*"fark" + 0.003*"alır" + 0.002*"yan" + 0.002*"istedik" + 0.002*"zor" + 0.002*"geldik" + 0.002*"ada" + 0.002*"on" + 0.002*"gele" + 0.002*"iş" + 0.002*"olacak" + 0.002*"olmadık" + 0.002*"yapma" + 0.002*"iz" + 0.002*"hikâye" + 0.002*"göz" + 0.002*"kız" + 0.002*"polis" + 0.002*"birbir" + 0.002*"yapar" + 0.002*"iç" + 0.002*"böl" + 0.002*"genç" + 0.002*"baba" + 0.002*"kabul" + 0.002*"terk" + 0.002*"verdik" + 0.002*"kala" + 0.002*"oda" + 0.002*"teklif" + 0.002*"konu" + 0.002*"sebep" + 0.002*"ardı" + 0.002*"yolculuk" + 0.002*"yak" + 0.002*"yaşadık" + 0.002*"aile" + 0.002*"ol" + 0.002*"döner" + 0.002*"üzer" + 0.002*"arka" + 0.002*"bulur" + 0.002*"kardeş" + 0.002*"ölüm" + 0.002*"görür" + 0.002*"haber" + 0.002*"aşık" + 0.002*"girer" + 0.002*"gelecek" + 0.002*"kalır" + 0.002*"ver" + 0.002*"küçük" + 0.001*"et" + 0.001*"gör" + 0.001*"cinayet" + 0.001*"konuşma" + 0.001*"takip" + 0.001*"alt" + 0.001*"hal" + 0.001*"ön" + 0.001*"karşı" + 0.001*"gördük" + 0.001*"söyledi" + 0.001*"in" + 0.001*"çocuk"
# Score: 0.14074034988880157	 Topic: 0.255*"ödül" + 0.060*"adaylık" + 0.040*"kaza" + 0.039*"aday" + 0.028*"festival" + 0.022*"dal" + 0.021*"akade" + 0.020*"gösteril" + 0.020*"uluslararas" + 0.018*"layık" + 0.015*"kategori" + 0.015*"verile" + 0.015*"görül" + 0.013*"pepsi" + 0.011*"kazana" + 0.010*"töre" + 0.009*"onur" + 0.008*"düzenlene" + 0.008*"kadı" + 0.008*"yabancı" + 0.007*"veril" + 0.007*"kür" + 0.006*"akademis" + 0.006*"eleştirmen" + 0.005*"başar" + 0.005*"seçil" + 0.005*"kapsam" + 0.005*"dernek" + 0.005*"performansı" + 0.004*"grammy" + 0.004*"oscar" + 0.004*"yardımcı" + 0.004*"kazanan" + 0.004*"tören" + 0.004*"gösterile" + 0.004*"verilmek" + 0.004*"nobel" + 0.003*"kazandık" + 0.003*"oslo" + 0.003*"clair" + 0.003*"jüri" + 0.003*"erkek" + 0.003*"awards" + 0.003*"anket" + 0.003*"ya" + 0.003*"liste" + 0.003*"nino" + 0.003*"forza" + 0.003*"brit" + 0.002*"bilim" + 0.002*"seç" + 0.002*"şubat" + 0.002*"bo" + 0.002*"değer" + 0.002*"ol" + 0.002*"kişi" + 0.002*"ulusal" + 0.002*"verilme" + 0.002*"takdı" + 0.002*"pulitzer" + 0.002*"verilir" + 0.002*"awardı" + 0.002*"aralık" + 0.002*"nisa" + 0.002*"ödüllü" + 0.002*"özel" + 0.002*"başarı" + 0.002*"akademi" + 0.002*"kiş" + 0.002*"yıllık" + 0.002*"dağıtıla" + 0.002*"yenilebilir" + 0.002*"biseksüel" + 0.002*"nina" + 0.002*"el" + 0.002*"prestijli" + 0.002*"satılıyor" + 0.002*"madalyas" + 0.002*"tatlandırıç" + 0.002*"üs" + 0.002*"dergis" + 0.001*"aliso" + 0.001*"ömür" + 0.001*"kaptık" + 0.001*"farklı" + 0.001*"yazar" + 0.001*"sunula" + 0.001*"katkı" + 0.001*"açıkla" + 0.001*"aşağı" + 0.001*"aro" + 0.001*"genç" + 0.001*"foster" + 0.001*"belirlene" + 0.001*"grey" + 0.001*"kategor" + 0.001*"performans" + 0.001*"çeşitli" + 0.001*"mart" + 0.001*"ödüllendiril"
# Score: 0.12114953994750977	 Topic: 0.106*"film" + 0.044*"oyuncu" + 0.031*"filmi" + 0.021*"sinema" + 0.021*"tiyatro" + 0.018*"karakter" + 0.015*"yönetme" + 0.013*"adlı" + 0.012*"televizyo" + 0.012*"dizi" + 0.012*"oyunculuk" + 0.011*"aldık" + 0.010*"yönetmenlik" + 0.009*"rol" + 0.009*"yapım" + 0.008*"dizis" + 0.008*"sahne" + 0.008*"rolü" + 0.007*"canlandırdık" + 0.007*"senaryo" + 0.007*"festival" + 0.007*"başrol" + 0.007*"komedi" + 0.006*"yönettik" + 0.006*"diz" + 0.005*"göster" + 0.005*"kariyer" + 0.005*"oyuncus" + 0.005*"oy" + 0.004*"oyun" + 0.004*"aktör" + 0.004*"senarist" + 0.004*"yapımcı" + 0.004*"dra" + 0.004*"oynadık" + 0.003*"çekim" + 0.003*"tür" + 0.003*"amerikal" + 0.003*"vizyo" + 0.003*"sanatçıs" + 0.003*"sayılabilir" + 0.003*"belgesel" + 0.003*"oynadı" + 0.003*"ta" + 0.003*"çek" + 0.003*"yapımcıs" + 0.003*"roller" + 0.003*"isimli" + 0.003*"canlandır" + 0.003*"aktris" + 0.003*"seslendirme" + 0.003*"yazar" + 0.003*"yazdık" + 0.003*"ünlü" + 0.003*"tiyatros" + 0.003*"animasyo" + 0.003*"dok" + 0.003*"cannes" + 0.003*"eylül" + 0.002*"yapımcılık" + 0.002*"komedye" + 0.002*"başroller" + 0.002*"mart" + 0.002*"dram" + 0.002*"gir" + 0.002*"oynamış" + 0.002*"sanat" + 0.002*"deva" + 0.002*"paylaştık" + 0.002*"üstlendik" + 0.002*"özgü" + 0.002*"çekile" + 0.002*"başladı" + 0.002*"müzikal" + 0.002*"ağustos" + 0.002*"yönetile" + 0.002*"gör" + 0.002*"mayıs" + 0.002*"ko" + 0.002*"yıldız" + 0.002*"senaristlik" + 0.002*"nisa" + 0.002*"metrajlı" + 0.002*"kadı" + 0.002*"aralık" + 0.002*"şubat" + 0.002*"yardımcı" + 0.002*"çıkışlı" + 0.002*"hazira" + 0.002*"roman" + 0.002*"korku" + 0.002*"kadro" + 0.002*"çekil" + 0.002*"şarkıç" + 0.002*"sanatçı" + 0.002*"uyarla" + 0.002*"hayat" + 0.002*"temmuz" + 0.002*"aksiyo" + 0.002*"almak"
# Score: 0.11223343759775162	 Topic: 0.106*"bilgi" + 0.065*"site" + 0.044*"sayfa" + 0.036*"met" + 0.033*"internet" + 0.031*"sites" + 0.024*"içerik" + 0.023*"si" + 0.022*"başlık" + 0.011*"listele" + 0.010*"facebook" + 0.010*"http" + 0.010*"hatay" + 0.008*"vikipedi" + 0.008*"yu" + 0.008*"kaynakça" + 0.008*"madde" + 0.007*"belge" + 0.007*"gmbh" + 0.007*"link" + 0.007*"sayfas" + 0.007*"metn" + 0.007*"çevir" + 0.006*"https" + 0.006*"resmi" + 0.006*"blog" + 0.005*"reviz" + 0.005*"index" + 0.005*"blogu" + 0.005*"isbn" + 0.005*"yor" + 0.005*"alfabetik" + 0.005*"editör" + 0.005*"bosch" + 0.005*"bulunmak" + 0.005*"sevi" + 0.005*"metni" + 0.005*"metin" + 0.005*"alpha" + 0.005*"eriş" + 0.004*"ngiliz" + 0.004*"sür" + 0.004*"kaynak" + 0.004*"çerik" + 0.003*"makale" + 0.003*"inceleme" + 0.003*"sayı" + 0.003*"expression" + 0.003*"confere" + 0.003*"wep" + 0.003*"barındırmak" + 0.003*"wikipedia" + 0.003*"rehber" + 0.003*"kayıtlı" + 0.003*"çevirme" + 0.003*"şifreleme" + 0.003*"revizyo" + 0.003*"eastern" + 0.003*"ayrıntıl" + 0.003*"pages" + 0.003*"ümraniyespor" + 0.003*"book" + 0.003*"zümrüt" + 0.002*"change" + 0.002*"ingiliz" + 0.002*"geçerli" + 0.002*"ziyaretçi" + 0.002*"haritala" + 0.002*"touringi" + 0.002*"page" + 0.002*"core" + 0.002*"versiyo" + 0.002*"sint" + 0.002*"görüntülenir" + 0.002*"çevr" + 0.002*"doküma" + 0.002*"groupe" + 0.002*"ziyaret" + 0.002*"agency" + 0.002*"çıktıs" + 0.002*"dolgus" + 0.002*"publishers" + 0.002*"çeviris" + 0.002*"işaretle" + 0.002*"argı" + 0.002*"oluşturul" + 0.002*"snlik" + 0.002*"chiro" + 0.002*"maddes" + 0.002*"level" + 0.002*"basılarak" + 0.002*"medea" + 0.002*"etiket" + 0.002*"almaya" + 0.002*"lave" + 0.002*"ansiklopedi" + 0.002*"grid" + 0.002*"creativ" + 0.002*"wik" + 0.002*"nterne"
